# %% [markdown]
# # Omni NLP API

# %% [markdown]
# ### 1º - Adicionar Conteúdo para Treino

# %%
# LER DADOS
import json

file = open('/home/cloves/Downloads/skill-COE_YARA_PRD.json', "r") 
workspace = json.load(file)
workspace["intents"][-1]
# Out:
# {'intent': 'Vizinho_Invadindo_Terreno',
#  'examples': [{'text': 'A unidade está sendo invadida. Quem pode ajudar?'},
#   {'text': 'Estamos com problema com vizinhos da unidade. Com quem posso falar?'},
#   {'text': 'Nosso terreno está sendo invadido pelo vizinho da unidade. O que fazer?'},
#   {'text': 'O vizinho da unidade está invadindo uma parte do imóvel da Yara. O que fazer?'}],
#  'description': ''}

# %% [markdown]
# ###### Entidades

# %%
import requests

url_api = "http://0.0.0.0:5000/"
params = {'workspace_id': 'dc1e7b3d-9137-4a20-a99c-d0d2029ef170'}
end_point = "nlp_model/entities/"

for entity in workspace["entities"]:
    if "sys" not in entity["entity"].split("-"):
        r = requests.post(url_api+end_point, params=params, json=entity)
        r = r.json()
        if r["result"] == "created":
            print("Entity %s was created with id %s"%(entity["entity"],r["_id"]))
        else:
            print("Entity %s was not created"%entity["entity"])
# Out:
# Entity Actions was created with id e1awuncBF8yx_zbJ2U0f
# Entity Assistencias was created with id fFawuncBF8yx_zbJ2U2R
# Entity CEP was created with id fVawuncBF8yx_zbJ2U29
# Entity ContactInfo was created with id flawuncBF8yx_zbJ2U3t
# Entity CulturaPlatacao was created with id f1awuncBF8yx_zbJ2k0b
# Entity DataProgramada was created with id gFawuncBF8yx_zbJ2k1F
# Entity Datas was created with id gVawuncBF8yx_zbJ2k2E
# Entity DecimoTerceiro was created with id glawuncBF8yx_zbJ2k2w
# Entity DetalheAgendamentoFerias was created with id g1awuncBF8yx_zbJ2k3Z
# Entity DetalheCartaoAlimentacaoRefeicao was created with id hFawuncBF8yx_zbJ200M
# Entity DetalheDesconto was created with id hVawuncBF8yx_zbJ2004
# Entity EntedidadesGerais was created with id hlawuncBF8yx_zbJ201k
# Entity EntidadeGeral was created with id h1awuncBF8yx_zbJ202O
# Entity ErroMercadoEletronico was created with id iFawuncBF8yx_zbJ2025
# Entity hash was created with id iVawuncBF8yx_zbJ2038
# Entity Institucional was created with id ilawuncBF8yx_zbJ3E04
# Entity JornadasYara was created with id i1awuncBF8yx_zbJ3E1h
# Entity LocalizacaoPlantacao was created with id jFawuncBF8yx_zbJ3E2B
# Entity Previdencia was created with id jVawuncBF8yx_zbJ3E2l
# Entity Questao was created with id jlawuncBF8yx_zbJ3E3J
# Entity ReceberCancelarAdiantamentoSalarial was created with id j1awuncBF8yx_zbJ3E3w
# Entity SimNao was created with id kFawuncBF8yx_zbJ3U0W
# Entity Tema was created with id kVawuncBF8yx_zbJ3U1E
# Entity ValidaWhats was created with id klawuncBF8yx_zbJ3U1k

# %% [markdown]
# ##### Intenções

# %%
end_point = "nlp_model/intents/"

for intent in workspace["intents"]:
    r = requests.post(url_api+end_point, params=params, json=intent)
    r = r.json()
    if r["result"] == "created":
        print("Intent %s was created with id %s"%(intent["intent"],r["_id"]))
    else:
        print("Intent %s was not created"%intent["intent"])
# Out:
# Intent Abono was created with id k1awuncBF8yx_zbJ-E1a
# Intent Abrir_Chamado_Salario was created with id lFawuncBF8yx_zbJ-E2F
# Intent Acessar_CMS was created with id lVawuncBF8yx_zbJ-E2o
# Intent Acessar_Concur was created with id llawuncBF8yx_zbJ-E3K
# Intent Acessar_MercadoEletronico was created with id l1awuncBF8yx_zbJ-E36
# Intent Acessar_Painel_Colaborador was created with id mFawuncBF8yx_zbJ-U0e
# Intent Acessar_SAP_MercadoEletronico was created with id mVawuncBF8yx_zbJ-U1S
# Intent Acionista_Yara_GICS was created with id mlawuncBF8yx_zbJ-U12
# Intent Acompanhar_Pedido_MercadoEletronico was created with id m1awuncBF8yx_zbJ-U2X
# Intent Acompanhar_Saldo_Previdencia_Privada was created with id nFawuncBF8yx_zbJ-U23
# Intent Acompanhar_Solicitacao was created with id nVawuncBF8yx_zbJ-U3Z
# Intent Aderir_Beneficio_Previdencia_Privada was created with id nlawuncBF8yx_zbJ-U35
# Intent Adiantamento_Duplicado was created with id n1awuncBF8yx_zbJ-k0Y
# Intent Adiantamento_e_QuandoReceber_13_Salario was created with id oFawuncBF8yx_zbJ-k09
# Intent Aditivar_Contrato was created with id oVawuncBF8yx_zbJ-k1l
# Intent Agendamento_Alteracao_Ferias was created with id olawuncBF8yx_zbJ-k2L
# Intent Agilidade_Negocios was created with id o1awuncBF8yx_zbJ-k2y
# Intent Ajuda_Manual_CMS was created with id pFawuncBF8yx_zbJ-k3Z
# Intent Ajustar_Ponto was created with id pVawuncBF8yx_zbJ-k39
# Intent Ajuste_Informacao_Convenio was created with id plawuncBF8yx_zbJ-00_
# Intent Alteracao_Beneficios_Previdencia was created with id p1awuncBF8yx_zbJ-01_
# Intent Alteracao_CargoSalario was created with id qFawuncBF8yx_zbJ-02m
# Intent Alteracao_CC was created with id qVawuncBF8yx_zbJ-03J
# Intent Alteração_ContratoProrrogacao was created with id qlawuncBF8yx_zbJ-03w
# Intent Alteração_Gestor was created with id q1awuncBF8yx_zbJ_E0S
# Intent Alterar_Aprovador was created with id rFawuncBF8yx_zbJ_E09
# Intent Alterar_Cargo was created with id rVawuncBF8yx_zbJ_E2R
# Intent Alterar_Centro_Custo was created with id rlawuncBF8yx_zbJ_E20
# Intent Alterar_Conta_Pagamento was created with id r1awuncBF8yx_zbJ_E3V
# Intent Alterar_Contrato was created with id sFawuncBF8yx_zbJ_U0A
# Intent Alterar_EnquadramentoMerito was created with id sVawuncBF8yx_zbJ_U0p
# Intent Alterar_Posicao was created with id slawuncBF8yx_zbJ_U2A
# Intent Alterar_Promocao was created with id s1awuncBF8yx_zbJ_U2s
# Intent Alterar_Tipo_Registro_Ponto was created with id tFawuncBF8yx_zbJ_k0O
# Intent Alterar_Vale_RefeicaoAlimentacao was created with id tVawuncBF8yx_zbJ_k0w
# Intent Ambicao_CoE was created with id tlawuncBF8yx_zbJ_k1S
# Intent Ambiente_ConfiancaAgradavel was created with id t1awuncBF8yx_zbJ_k2Y
# Intent Apresentacao_Institucional was created with id uFawuncBF8yx_zbJ_k3O
# Intent Aprovações_YPP was created with id uVawuncBF8yx_zbJ_00G
# Intent Aprovar_Solicitacao_Pendente_Ponto was created with id ulawuncBF8yx_zbJ_008
# Intent Arquivar_Contrato was created with id u1awuncBF8yx_zbJ_02Q
# Intent Assinar_Contrato was created with id vFawuncBF8yx_zbJ_03j
# Intent Assinar_Digitalmente_Contrato was created with id vVaxuncBF8yx_zbJAE0j
# Intent Bem_Estar was created with id vlaxuncBF8yx_zbJAE1e
# Intent Bonus_Mobilidade was created with id v1axuncBF8yx_zbJAE2H
# Intent Bot_Capabilities was created with id wFaxuncBF8yx_zbJAE25
# Intent Branding was created with id wVaxuncBF8yx_zbJAE3a
# Intent Cadastro_Concur was created with id wlaxuncBF8yx_zbJAE36
# Intent Canais_Atendimentos_CoE was created with id w1axuncBF8yx_zbJAU0Y
# Intent Cancelar_Previdencia was created with id xFaxuncBF8yx_zbJAU05
# Intent Cartao_Bloqueado_SenhaInvalida was created with id xVaxuncBF8yx_zbJAU1b
# Intent Cartao_Cancelado was created with id xlaxuncBF8yx_zbJAU2N
# Intent Cartao_Clonado_Cambial was created with id x1axuncBF8yx_zbJAU2w
# Intent Colaboracao_CoE was created with id yFaxuncBF8yx_zbJAU3R
# Intent Comprovant_CNPJ was created with id yVaxuncBF8yx_zbJAU31
# Intent Comprovante_Pagamento_Juridico was created with id ylaxuncBF8yx_zbJAk0a
# Intent Concur_Cursos was created with id y1axuncBF8yx_zbJAk08
# Intent Concur_Delegacao was created with id zFaxuncBF8yx_zbJAk1r
# Intent Consultar_Procuracao was created with id zVaxuncBF8yx_zbJAk2T
# Intent Conta_Bancaria was created with id zlaxuncBF8yx_zbJAk3M
# Intent Contato_Operadora_Previdencia_Privada was created with id z1axuncBF8yx_zbJA00A
# Intent Contracheque_Recebido_Sem_Constar_Conta was created with id 0FaxuncBF8yx_zbJA01I
# Intent Contracheque_Sem_Constar_Dependente_IRRF was created with id 0VaxuncBF8yx_zbJA02e
# Intent Contrato_Aprovado_Proximo_Passo was created with id 0laxuncBF8yx_zbJA03r
# Intent Contrato_Devolvido_Juridico was created with id 01axuncBF8yx_zbJBE0y
# Intent Contrato_Social_ou_Estatuto_Empresa was created with id 1FaxuncBF8yx_zbJBE1l
# Intent Contribuicoes_Previdencia_Privada was created with id 1VaxuncBF8yx_zbJBE2G
# Intent Controladoria_Juridica was created with id 1laxuncBF8yx_zbJBE20
# Intent Criar_Posição was created with id 11axuncBF8yx_zbJBE3p
# Intent Curiosidade_CoE was created with id 2FaxuncBF8yx_zbJBU0g
# Intent Custo_Movimentação_Estado was created with id 2VaxuncBF8yx_zbJBU1e
# Intent Data_Entrega_Veiculo_Definitivo was created with id 2laxuncBF8yx_zbJBU2i
# Intent Data_Envio_Vale_RefeicaoAlimentacao was created with id 21axuncBF8yx_zbJBU3t
# Intent Data_Limite_Ferias was created with id 3FaxuncBF8yx_zbJBk1L
# Intent Data_Pagamento_Salario was created with id 3VaxuncBF8yx_zbJBk2a
# Intent Data_Pagamento_Vale_RefeicaoAlimentação was created with id 3laxuncBF8yx_zbJBk3c
# Intent Desconto_em_Folha was created with id 31axuncBF8yx_zbJB00M
# Intent Despesa_Pessoal_Marcado_Relatorio_Concur was created with id 4FaxuncBF8yx_zbJB01Q
# Intent Detalhe_Sobre_Desconto was created with id 4VaxuncBF8yx_zbJB02q
# Intent Devolucao_Veiculo was created with id 4laxuncBF8yx_zbJB03s
# Intent Diferenca_Previdencia_Privada was created with id 41axuncBF8yx_zbJCE0V
# Intent Direcao_Defensiva was created with id 5FaxuncBF8yx_zbJCE01
# Intent Direito_ao_13 was created with id 5VaxuncBF8yx_zbJCE1W
# Intent Divisao_Ferias was created with id 5laxuncBF8yx_zbJCE12
# Intent Documento_Oficial_Justica was created with id 51axuncBF8yx_zbJCE2f
# Intent Documento_Sem_Carimbo_Juridico was created with id 6FaxuncBF8yx_zbJCE3B
# Intent Download_Aplicativo_Convenio was created with id 6VaxuncBF8yx_zbJCE3f
# Intent Duvida_Formularo_Adesao_Previdencia was created with id 6laxuncBF8yx_zbJCU0T
# Intent Duvidas_Benefícios was created with id 61axuncBF8yx_zbJCU05
# Intent Duvidas_Celular_Corporativo was created with id 7FaxuncBF8yx_zbJCU1p
# Intent Duvidas_Despesas was created with id 7VaxuncBF8yx_zbJCU2T
# Intent Duvidas_Funcoes_Cartao was created with id 7laxuncBF8yx_zbJCU23
# Intent Duvidas_Outro_CC was created with id 71axuncBF8yx_zbJCU3W
# Intent Elegibilidade_Previdencia_Privada was created with id 8FaxuncBF8yx_zbJCU32
# Intent Emissoes_Cartao was created with id 8VaxuncBF8yx_zbJCk0Z
# Intent Empresa_Seguro_Frota was created with id 8laxuncBF8yx_zbJCk1I
# Intent Erros_MercadoEletronico was created with id 81axuncBF8yx_zbJCk1w
# Intent Espirito_Servir was created with id 9FaxuncBF8yx_zbJCk2d
# Intent Esquecer_Senha_Vale_RefeicaoAlimentacao was created with id 9VaxuncBF8yx_zbJCk27
# Intent Estrategia_Aprovar was created with id 9laxuncBF8yx_zbJCk3b
# Intent Exclusoes_Concur was created with id 91axuncBF8yx_zbJCk37
# Intent Ex_Colaborador_Resgate_Previdencia was created with id -FaxuncBF8yx_zbJC00Z
# Intent Extensao_Contrato was created with id -VaxuncBF8yx_zbJC01V
# Intent Extrair_Relatorio_Ponto_Todos_Colaboradores was created with id -laxuncBF8yx_zbJC02L
# Intent Extrato_Plano was created with id -1axuncBF8yx_zbJC026
# Intent Fazer_Contrato was created with id _FaxuncBF8yx_zbJC03c
# Intent Foco_Cliente was created with id _VaxuncBF8yx_zbJDE0H
# Intent Fornecedor_ME was created with id _laxuncBF8yx_zbJDE0u
# Intent Funcoes_Cartao_Corporativo was created with id _1axuncBF8yx_zbJDE1N
# Intent Fundacao_Valores was created with id AFaxuncBF8yx_zbJDE5r
# Intent General_Ending was created with id AVaxuncBF8yx_zbJDE6K
# Intent General_Greetings was created with id AlaxuncBF8yx_zbJDE6t
# Intent General_Negative_Feedback was created with id A1axuncBF8yx_zbJDE7Q
# Intent General_Positive_Feedback was created with id BFaxuncBF8yx_zbJDU4A
# Intent Gestor_Responsavel_Departamento_Juridico was created with id BVaxuncBF8yx_zbJDU4r
# Intent Hora_Extra was created with id BlaxuncBF8yx_zbJDU5S
# Intent Imposto_Renda_Previdencia_Privada was created with id B1axuncBF8yx_zbJDU57
# Intent Inativar_Posição was created with id CFaxuncBF8yx_zbJDU68
# Intent Incluir_Colaborador_Convenio was created with id CVaxuncBF8yx_zbJDk4Q
# Intent Incluir_Dependente_Plano_Saude was created with id ClaxuncBF8yx_zbJDk5k
# Intent IncluirRemover_Colaborador was created with id C1axuncBF8yx_zbJDk6S
# Intent Inconformidades_Legais was created with id DFaxuncBF8yx_zbJDk7F
# Intent Info_Concur_SAP was created with id DVaxuncBF8yx_zbJD04G
# Intent Informacao_Geral_Sistemas was created with id DlaxuncBF8yx_zbJD053
# Intent Informacoes_Relatorio_Aberto was created with id D1axuncBF8yx_zbJD060
# Intent Informacoes_Relatorio_Gerais was created with id EFaxuncBF8yx_zbJD07c
# Intent Informacoes_Relatorio_Nao_Aprovado was created with id EVaxuncBF8yx_zbJD07_
# Intent Licenca_Mais_Ferias was created with id ElaxuncBF8yx_zbJEE4l
# Intent Localizar_Veiculo was created with id E1axuncBF8yx_zbJEE5G
# Intent Manutencoes was created with id FFaxuncBF8yx_zbJEE5k
# Intent Marcar_Falta_Colaborador was created with id FVaxuncBF8yx_zbJEE6E
# Intent ME_Conta_Contábil was created with id FlaxuncBF8yx_zbJEE6l
# Intent Mistura_Cartao_Reembolso was created with id F1axuncBF8yx_zbJEE7G
# Intent Modelo_Contrato was created with id GFaxuncBF8yx_zbJEE7r
# Intent Nossa_Missao was created with id GVaxuncBF8yx_zbJEU4N
# Intent Nossa_Visao was created with id GlaxuncBF8yx_zbJEU4w
# Intent Novo_Colaborador was created with id G1axuncBF8yx_zbJEU5U
# Intent Novo_Portal_CoE_Gostou was created with id HFaxuncBF8yx_zbJEU54
# Intent Novo_Portal_CoE_NãoGostou was created with id HVaxuncBF8yx_zbJEU6a
# Intent Orientacoes_PTP was created with id HlaxuncBF8yx_zbJEU68
# Intent Pagamento_Ferias was created with id H1axuncBF8yx_zbJEU7o
# Intent Pagamento_Licenca_Maternidade was created with id IFaxuncBF8yx_zbJEk4L
# Intent Periodo_Amamentacao_Licenca_Maternidade was created with id IVaxuncBF8yx_zbJEk4q
# Intent Periodo_Licenca_Maternidade was created with id IlaxuncBF8yx_zbJEk5P
# Intent Pessoas_Focadas_Excelencia was created with id I1axuncBF8yx_zbJEk5u
# Intent Pessoas_Responsaveis_Juridico was created with id JFaxuncBF8yx_zbJEk6Q
# Intent Ponto_Colaborar_Não_Aparece was created with id JVaxuncBF8yx_zbJEk6_
# Intent Prazo_Ajuste_Ponto was created with id JlaxuncBF8yx_zbJEk7r
# Intent Prazo_Atendimento_Juridico was created with id J1axuncBF8yx_zbJE05H
# Intent Prazo_Juridico_Responder was created with id KFaxuncBF8yx_zbJE06k
# Intent Previdencia_Privada_Desconto was created with id KVaxuncBF8yx_zbJFE4T
# Intent Priorizar_Criacao_Pedidos was created with id KlaxuncBF8yx_zbJFE5Y
# Intent Procedimento_Contrato_Assinado was created with id K1axuncBF8yx_zbJFE6g
# Intent Procedimento_Recusado_Convenio was created with id LFaxuncBF8yx_zbJFE7m
# Intent Procedimentos_Concur was created with id LVaxuncBF8yx_zbJFU4i
# Intent Procedimentos_Convenio was created with id LlaxuncBF8yx_zbJFU5q
# Intent Proposito_CoE was created with id L1axuncBF8yx_zbJFU6U
# Intent Proposta_Comercial_Juridico was created with id MFaxuncBF8yx_zbJFU6z
# Intent Proposta_Rubricada was created with id MVaxuncBF8yx_zbJFU7V
# Intent Prorrogacao_Licenca_Maternidade was created with id MlaxuncBF8yx_zbJFU7_
# Intent ReceberCancelar_Adiantamento_Salarial was created with id M1axuncBF8yx_zbJFk4j
# Intent Receber_Cartao_Convenio was created with id NFaxuncBF8yx_zbJFk5E
# Intent Receber_Oficio was created with id NVaxuncBF8yx_zbJFk5x
# Intent Recebimento_Beneficio_Previdencia_Privada was created with id NlaxuncBF8yx_zbJFk6Y
# Intent Reconhecer_Firma_Contrato was created with id N1axuncBF8yx_zbJFk6-
# Intent Reembolso_Janta_HomeOffice was created with id OFaxuncBF8yx_zbJFk7k
# Intent Reembolso_Sem_Cobertura_Convenio was created with id OVaxuncBF8yx_zbJF04P
# Intent Relatorio_Inconsistencias_Ponto was created with id OlaxuncBF8yx_zbJF05a
# Intent Relatorio_Old was created with id O1axuncBF8yx_zbJF06N
# Intent Relatorio_Programacao_Ferias was created with id PFaxuncBF8yx_zbJF07J
# Intent Renovacao_Contrato_Veiculo was created with id PVaxuncBF8yx_zbJF07q
# Intent Repassar_Gestao_Colaborador was created with id PlaxuncBF8yx_zbJGE4R
# Intent Representantes_Legais was created with id P1axuncBF8yx_zbJGE46
# Intent Resgatar_Previdencia was created with id QFaxuncBF8yx_zbJGE5p
# Intent Responsabilidade_CoE was created with id QVaxuncBF8yx_zbJGE6N
# Intent Retorno_Contrato_CMS_Não_Entendi was created with id QlaxuncBF8yx_zbJGE6u
# Intent SegundaVia_Cartao_Ticketlog was created with id Q1axuncBF8yx_zbJGE7N
# Intent SegundaVia_Vale_RefeicaoAlimentacao was created with id RFaxuncBF8yx_zbJGE7x
# Intent Solicitacao_Aprovada_Proximo_Passo was created with id RVaxuncBF8yx_zbJGU4g
# Intent Solicitacao_Negada_Documento_Aprovado was created with id RlaxuncBF8yx_zbJGU5A
# Intent Solicitar_Cartao_Combustivel was created with id R1axuncBF8yx_zbJGU5l
# Intent Solicitar_Holerite was created with id SFaxuncBF8yx_zbJGU6I
# Intent Solicitar_IRPF was created with id SVaxuncBF8yx_zbJGU7D
# Intent Solicitar_Ponto_Pos_FechamentoReembolso was created with id SlaxuncBF8yx_zbJGU70
# Intent Solicitar_Procuracao was created with id S1axuncBF8yx_zbJGk4s
# Intent Solicitar_Troca_Veiculo was created with id TFaxuncBF8yx_zbJGk5K
# Intent Status_Ferias_e_Programacao_Sem_Confirmação was created with id TVaxuncBF8yx_zbJGk5r
# Intent Status_Item_Cancelado was created with id TlaxuncBF8yx_zbJGk6O
# Intent Tecnologia_Facilitadora_Eficiencia was created with id T1axuncBF8yx_zbJGk6t
# Intent Testemunha_Contrato was created with id UFaxuncBF8yx_zbJGk7K
# Intent Tipos_Reembolso was created with id UVaxuncBF8yx_zbJG04W
# Intent Transferencia_Veiculo was created with id UlaxuncBF8yx_zbJG041
# Intent Transferir_Colaborador_Filial was created with id U1axuncBF8yx_zbJG05a
# Intent Treinamento_Juridico was created with id VFaxuncBF8yx_zbJG06C
# Intent Tributacao_Previdencia_Privada was created with id VVaxuncBF8yx_zbJG069
# Intent TrocaDevolucao_Ticketlog was created with id VlaxuncBF8yx_zbJHE4V
# Intent Usuario_Invalido_NaoCadastrado was created with id V1axuncBF8yx_zbJHE5J
# Intent Valor_13 was created with id WFaxuncBF8yx_zbJHE6A
# Intent Valor_Depositado_Vale_RefeicaoAlimentacao_Errado was created with id WVaxuncBF8yx_zbJHE6p
# Intent Valores_Geral was created with id WlaxuncBF8yx_zbJHE7U
# Intent Valores_Política was created with id W1axuncBF8yx_zbJHE74
# Intent Valores_Yara was created with id XFaxuncBF8yx_zbJHU4Y
# Intent Veiculo_Definitivo was created with id XVaxuncBF8yx_zbJHU45
# Intent Veiculo_Disponiveis was created with id XlaxuncBF8yx_zbJHU5a
# Intent Veiculo_Problema was created with id X1axuncBF8yx_zbJHU58
# Intent Veiculo_Provisorio was created with id YFaxuncBF8yx_zbJHU6g
# Intent Verificar_Banco_Horas was created with id YVaxuncBF8yx_zbJHk4Q
# Intent Verificar_Colaborador_Convenio was created with id YlaxuncBF8yx_zbJHk4z
# Intent Verificar_Historico_Previdencia was created with id Y1axuncBF8yx_zbJHk5c
# Intent Verificar_Numero_Carteirinha_Convenio was created with id ZFaxuncBF8yx_zbJHk57
# Intent Verificar_Numero_Vale_RefeicaoAlimentacao was created with id ZVaxuncBF8yx_zbJHk6h
# Intent Verificar_Status_Ferias was created with id ZlaxuncBF8yx_zbJHk7B
# Intent Verificar_Valor_Locacao_Veiculo was created with id Z1axuncBF8yx_zbJHk7l
# Intent Visao_Geral_Previdencia_Privada was created with id aFaxuncBF8yx_zbJH04E
# Intent Vizinho_Invadindo_Terreno was created with id aVaxuncBF8yx_zbJH04i

# %%
r = requests.get(url_api+end_point, params={"workspace_id": "dc1e7b3d-9137-4a20-a99c-d0d2029ef170",
                                            "intent_name": "Relatorio_Inconsistencias_Ponto"})
r = r.json()
r
# Out:
# {'_id': 'OlaxuncBF8yx_zbJF05a',
#  '_index': 'nlp_model-dc1e7b3d-9137-4a20-a99c-d0d2029ef170-19022021142434',
#  '_score': 4.9698133,
#  '_source': {'description': '',
#   'doc_type': 'intent',
#   'examples': [{'text': 'Como faço para ver os erros do meu ponto?'},
#    {'text': 'Devo abrir um chamado para solicitar um relatório de inconsistências do ponto?'},
#    {'text': 'Gostaria de saber quantas inconsistências de ponto existe na minha equipe?'},
#    {'text': 'Necessito de um relatório de inconsistências, onde posso obter?'},
#    {'text': 'preciso de um relatorio de inconsistencias do ponto dos meus colaboradores, onde eu acho isso?'},
#    {'text': 'Quantas marcações ímpares há na minha equipe?'}],
#   'intent': 'Relatorio_Inconsistencias_Ponto'},
#  '_type': '_doc'}

# %%
r = requests.get(url_api+end_point, params={"workspace_id": "dc1e7b3d-9137-4a20-a99c-d0d2029ef170",
                                            "intent_name": "Relatorio_Inconsistencias_Ponto"})
r = r.json()
r
# Out:
# {'_id': 'OlaxuncBF8yx_zbJF05a',
#  '_index': 'nlp_model-dc1e7b3d-9137-4a20-a99c-d0d2029ef170-19022021142434',
#  '_score': 5.2747073,
#  '_source': {'artificial_examples': [{'constructed': 'devo abrir um chamar parir solicitar um relatório de inconsistência do pontar',
#     'original': 'Devo abrir um chamado para solicitar um relatório de inconsistências do ponto?'},
#    {'constructed': 'necessito de um relatório de inconsistência onde poder obter',
#     'original': 'Necessito de um relatório de inconsistências, onde posso obter?'}],
#   'description': '',
#   'doc_type': 'intent',
#   'examples': [{'text': 'Como faço para ver os erros do meu ponto?'},
#    {'text': 'Devo abrir um chamado para solicitar um relatório de inconsistências do ponto?'},
#    {'text': 'Gostaria de saber quantas inconsistências de ponto existe na minha equipe?'},
#    {'text': 'Necessito de um relatório de inconsistências, onde posso obter?'},
#    {'text': 'preciso de um relatorio de inconsistencias do ponto dos meus colaboradores, onde eu acho isso?'},
#    {'text': 'Quantas marcações ímpares há na minha equipe?'}],
#   'for_test': [{'text': 'Quantas marcações ímpares há na minha equipe?'},
#    {'text': 'devo abrir um chamar parir solicitar um relatório de inconsistência do pontar'},
#    {'text': 'necessito de um relatório de inconsistência onde poder obter'}],
#   'for_train': [{'text': 'Como faço para ver os erros do meu ponto?'},
#    {'text': 'Devo abrir um chamado para solicitar um relatório de inconsistências do ponto?'},
#    {'text': 'Gostaria de saber quantas inconsistências de ponto existe na minha equipe?'},
#    {'text': 'Necessito de um relatório de inconsistências, onde posso obter?'},
#    {'text': 'preciso de um relatorio de inconsistencias do ponto dos meus colaboradores, onde eu acho isso?'}],
#   'intent': 'Relatorio_Inconsistencias_Ponto'},
#  '_type': '_doc'}

# %% [markdown]
# # Watson Assistant

# %% [markdown]
# #### 1º - Se Conectar ao Watson

# %%
import os
import json
from ibm_watson import AssistantV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

API_KEY = "nA36HqlqQkQSDf0EywIeYGPl0qI_nNvLqvBUI_zhhUmR" # os.environ['API_KEY']
SERVICE_URL = "https://api.us-south.assistant.watson.cloud.ibm.com/instances/12c017ac-1bb4-4364-8493-9cc9ba98aa26" # os.environ['SERVICE_URL']
# ASSISTANT_ID = "11cdca6b-e73e-48fc-8523-13d9ee68df8b" # os.environ['ASSISTANT_ID']

# %% [markdown]
# #### 2º - Criar Skill

# %%
# criar skill
authenticator = IAMAuthenticator(API_KEY)
assistant = AssistantV1(
    version='2020-04-01',
    authenticator = authenticator
)

# %%
def create_skill_for_test():
    response=assistant.create_workspace(
        name='teste-com-api-omni',
        language="pt-br",
        description='Skill para teste de acurácia'
    ).get_result()
    print(json.dumps(response, indent=2))
    return response["workspace_id"]
    
skill_id_test = create_skill_for_test()
# Out:
# {
#   "name": "teste-com-api-omni",
#   "language": "pt-br",
#   "metadata": {
#     "api_version": {
#       "major_version": "v1",
#       "minor_version": "2020-04-01"
#     }
#   },
#   "description": "Skill para teste de acur\u00e1cia",
#   "workspace_id": "8b1f8007-c5dd-4366-b48a-34bf295a929c",
#   "learning_opt_out": false
# }

# %% [markdown]
# #### 3º - Adicionar Conteúdo (intents e entities)

# %%
def add_intents(intents, skill_id_test):
    for intent in intents:
        response=assistant.create_intent(
            workspace_id=skill_id_test,
            intent=intent["intent"],
            examples=intent["for_train"]
        ).get_result()
        print("Intenção %s criada!"%response["intent"])
        
query = {
  "size": 1000, 
  "query": {
    "term": {
      "doc_type.keyword": "intent"
    }
  }
}

intents = es.search(index=index.index_alias, body=query)
intents = [result["_source"] for result in intents["hits"]["hits"]]
add_intents(intents, skill_id_test)
# Out:
# Intenção Informacao_Geral_Sistemas criada!
# Intenção Reembolso_Janta_HomeOffice criada!
# Intenção Responsabilidade_CoE criada!
# Intenção Tecnologia_Facilitadora_Eficiencia criada!
# Intenção Alteracao_Beneficios_Previdencia criada!
# Intenção Arquivar_Contrato criada!
# Intenção Nossa_Missao criada!
# Intenção Contracheque_Sem_Constar_Dependente_IRRF criada!
# Intenção Abrir_Chamado_Salario criada!
# Intenção Acompanhar_Saldo_Previdencia_Privada criada!
# Intenção Fazer_Contrato criada!
# Intenção Proposta_Rubricada criada!
# Intenção Cartao_Bloqueado_SenhaInvalida criada!
# Intenção Concur_Delegacao criada!
# Intenção Duvida_Formularo_Adesao_Previdencia criada!
# Intenção Aditivar_Contrato criada!
# Intenção Extrair_Relatorio_Ponto_Todos_Colaboradores criada!
# Intenção Foco_Cliente criada!
# Intenção Fornecedor_ME criada!
# Intenção Fundacao_Valores criada!
# Intenção General_Ending criada!
# Intenção General_Greetings criada!
# Intenção General_Negative_Feedback criada!
# Intenção General_Positive_Feedback criada!
# Intenção Incluir_Colaborador_Convenio criada!
# Intenção Incluir_Dependente_Plano_Saude criada!
# Intenção IncluirRemover_Colaborador criada!
# Intenção Informacoes_Relatorio_Aberto criada!
# Intenção Verificar_Status_Ferias criada!
# Intenção Transferencia_Veiculo criada!
# Intenção TrocaDevolucao_Ticketlog criada!
# Intenção Usuario_Invalido_NaoCadastrado criada!
# Intenção Valor_Depositado_Vale_RefeicaoAlimentacao_Errado criada!
# Intenção Veiculo_Disponiveis criada!
# Intenção Veiculo_Problema criada!
# Intenção Veiculo_Provisorio criada!
# Intenção Verificar_Colaborador_Convenio criada!
# Intenção Verificar_Historico_Previdencia criada!
# Intenção Verificar_Numero_Carteirinha_Convenio criada!
# Intenção Verificar_Valor_Locacao_Veiculo criada!
# Intenção Receber_Cartao_Convenio criada!
# Intenção Repassar_Gestao_Colaborador criada!
# Intenção SegundaVia_Cartao_Ticketlog criada!
# Intenção SegundaVia_Vale_RefeicaoAlimentacao criada!
# Intenção Solicitar_Cartao_Combustivel criada!
# Intenção Solicitar_Holerite criada!
# Intenção Solicitar_Ponto_Pos_FechamentoReembolso criada!
# Intenção Solicitar_Troca_Veiculo criada!
# Intenção Status_Ferias_e_Programacao_Sem_Confirmação criada!
# Intenção Data_Pagamento_Vale_RefeicaoAlimentação criada!
# Intenção Despesa_Pessoal_Marcado_Relatorio_Concur criada!
# Intenção Detalhe_Sobre_Desconto criada!
# Intenção Devolucao_Veiculo criada!
# Intenção Divisao_Ferias criada!
# Intenção Download_Aplicativo_Convenio criada!
# Intenção Duvidas_Benefícios criada!
# Intenção Duvidas_Celular_Corporativo criada!
# Intenção Duvidas_Despesas criada!
# Intenção Erros_MercadoEletronico criada!
# Intenção Esquecer_Senha_Vale_RefeicaoAlimentacao criada!
# Intenção Agendamento_Alteracao_Ferias criada!
# Intenção Ajustar_Ponto criada!
# Intenção Ajuste_Informacao_Convenio criada!
# Intenção Alterar_Aprovador criada!
# Intenção Alterar_Conta_Pagamento criada!
# Intenção Alterar_EnquadramentoMerito criada!
# Intenção Alterar_Vale_RefeicaoAlimentacao criada!
# Intenção Bem_Estar criada!
# Intenção Bot_Capabilities criada!
# Intenção ME_Conta_Contábil criada!
# Intenção Novo_Portal_CoE_Gostou criada!
# Intenção Pagamento_Ferias criada!
# Intenção Ponto_Colaborar_Não_Aparece criada!
# Intenção Priorizar_Criacao_Pedidos criada!
# Intenção Procedimento_Recusado_Convenio criada!
# Intenção Procedimentos_Concur criada!
# Intenção Procedimentos_Convenio criada!
# Intenção Cartao_Clonado_Cambial criada!
# Intenção Contracheque_Recebido_Sem_Constar_Conta criada!
# Intenção Acessar_Concur criada!
# Intenção Acessar_MercadoEletronico criada!
# Intenção Acessar_Painel_Colaborador criada!
# Intenção Acessar_SAP_MercadoEletronico criada!
# Intenção Acompanhar_Pedido_MercadoEletronico criada!
# Intenção Adiantamento_e_QuandoReceber_13_Salario criada!
# Intenção Estrategia_Aprovar criada!
# Intenção Info_Concur_SAP criada!
# Intenção Inativar_Posição criada!
# Intenção Inconformidades_Legais criada!
# Intenção Informacoes_Relatorio_Gerais criada!
# Intenção Informacoes_Relatorio_Nao_Aprovado criada!
# Intenção Licenca_Mais_Ferias criada!
# Intenção Localizar_Veiculo criada!
# Intenção ReceberCancelar_Adiantamento_Salarial criada!
# Intenção Receber_Oficio criada!
# Intenção Recebimento_Beneficio_Previdencia_Privada criada!
# Intenção Reconhecer_Firma_Contrato criada!
# Intenção Reembolso_Sem_Cobertura_Convenio criada!
# Intenção Relatorio_Inconsistencias_Ponto criada!
# Intenção Relatorio_Old criada!
# Intenção Relatorio_Programacao_Ferias criada!
# Intenção Renovacao_Contrato_Veiculo criada!
# Intenção Representantes_Legais criada!
# Intenção Resgatar_Previdencia criada!
# Intenção Retorno_Contrato_CMS_Não_Entendi criada!
# Intenção Solicitacao_Aprovada_Proximo_Passo criada!
# Intenção Solicitacao_Negada_Documento_Aprovado criada!
# Intenção Solicitar_IRPF criada!
# Intenção Solicitar_Procuracao criada!
# Intenção Status_Item_Cancelado criada!
# Intenção Alteracao_CargoSalario criada!
# Intenção Alteracao_CC criada!
# Intenção Alteração_ContratoProrrogacao criada!
# Intenção Alteração_Gestor criada!
# Intenção Alterar_Cargo criada!
# Intenção Alterar_Centro_Custo criada!
# Intenção Alterar_Contrato criada!
# Intenção Alterar_Posicao criada!
# Intenção Alterar_Promocao criada!
# Intenção Alterar_Tipo_Registro_Ponto criada!
# Intenção Ambicao_CoE criada!
# Intenção Ambiente_ConfiancaAgradavel criada!
# Intenção Apresentacao_Institucional criada!
# Intenção Aprovações_YPP criada!
# Intenção Aprovar_Solicitacao_Pendente_Ponto criada!
# Intenção Assinar_Contrato criada!
# Intenção Assinar_Digitalmente_Contrato criada!
# Intenção Bonus_Mobilidade criada!
# Intenção Manutencoes criada!
# Intenção Marcar_Falta_Colaborador criada!
# Intenção Mistura_Cartao_Reembolso criada!
# Intenção Modelo_Contrato criada!
# Intenção Nossa_Visao criada!
# Intenção Novo_Colaborador criada!
# Intenção Novo_Portal_CoE_NãoGostou criada!
# Intenção Orientacoes_PTP criada!
# Intenção Contrato_Aprovado_Proximo_Passo criada!
# Intenção Contrato_Devolvido_Juridico criada!
# Intenção Contrato_Social_ou_Estatuto_Empresa criada!
# Intenção Contribuicoes_Previdencia_Privada criada!
# Intenção Controladoria_Juridica criada!
# Intenção Criar_Posição criada!
# Intenção Acessar_CMS criada!
# Intenção Acionista_Yara_GICS criada!
# Intenção Acompanhar_Solicitacao criada!
# Intenção Aderir_Beneficio_Previdencia_Privada criada!
# Intenção Adiantamento_Duplicado criada!
# Intenção Abono criada!
# Intenção Branding criada!
# Intenção Exclusoes_Concur criada!
# Intenção Ex_Colaborador_Resgate_Previdencia criada!
# Intenção Extensao_Contrato criada!
# Intenção Extrato_Plano criada!
# Intenção Funcoes_Cartao_Corporativo criada!
# Intenção Gestor_Responsavel_Departamento_Juridico criada!
# Intenção Hora_Extra criada!
# Intenção Imposto_Renda_Previdencia_Privada criada!
# Intenção Pagamento_Licenca_Maternidade criada!
# Intenção Periodo_Amamentacao_Licenca_Maternidade criada!
# Intenção Periodo_Licenca_Maternidade criada!
# Intenção Pessoas_Focadas_Excelencia criada!
# Intenção Pessoas_Responsaveis_Juridico criada!
# Intenção Prazo_Ajuste_Ponto criada!
# Intenção Prazo_Atendimento_Juridico criada!
# Intenção Prazo_Juridico_Responder criada!
# Intenção Previdencia_Privada_Desconto criada!
# Intenção Procedimento_Contrato_Assinado criada!
# Intenção Proposito_CoE criada!
# Intenção Proposta_Comercial_Juridico criada!
# Intenção Prorrogacao_Licenca_Maternidade criada!
# Intenção Cadastro_Concur criada!
# Intenção Canais_Atendimentos_CoE criada!
# Intenção Cancelar_Previdencia criada!
# Intenção Cartao_Cancelado criada!
# Intenção Colaboracao_CoE criada!
# Intenção Comprovant_CNPJ criada!
# Intenção Comprovante_Pagamento_Juridico criada!
# Intenção Concur_Cursos criada!
# Intenção Consultar_Procuracao criada!
# Intenção Conta_Bancaria criada!
# Intenção Contato_Operadora_Previdencia_Privada criada!
# Intenção Curiosidade_CoE criada!
# Intenção Custo_Movimentação_Estado criada!
# Intenção Data_Entrega_Veiculo_Definitivo criada!
# Intenção Data_Envio_Vale_RefeicaoAlimentacao criada!
# Intenção Data_Limite_Ferias criada!
# Intenção Data_Pagamento_Salario criada!
# Intenção Desconto_em_Folha criada!
# Intenção Diferenca_Previdencia_Privada criada!
# Intenção Direcao_Defensiva criada!
# Intenção Direito_ao_13 criada!
# Intenção Documento_Oficial_Justica criada!
# Intenção Documento_Sem_Carimbo_Juridico criada!
# Intenção Duvidas_Funcoes_Cartao criada!
# Intenção Duvidas_Outro_CC criada!
# Intenção Elegibilidade_Previdencia_Privada criada!
# Intenção Emissoes_Cartao criada!
# Intenção Empresa_Seguro_Frota criada!
# Intenção Espirito_Servir criada!
# Intenção Agilidade_Negocios criada!
# Intenção Ajuda_Manual_CMS criada!
# Intenção Testemunha_Contrato criada!
# Intenção Tipos_Reembolso criada!
# Intenção Transferir_Colaborador_Filial criada!
# Intenção Treinamento_Juridico criada!
# Intenção Tributacao_Previdencia_Privada criada!
# Intenção Valor_13 criada!
# Intenção Valores_Geral criada!
# Intenção Valores_Política criada!
# Intenção Valores_Yara criada!
# Intenção Veiculo_Definitivo criada!
# Intenção Verificar_Banco_Horas criada!
# Intenção Verificar_Numero_Vale_RefeicaoAlimentacao criada!
# Intenção Visao_Geral_Previdencia_Privada criada!
# Intenção Vizinho_Invadindo_Terreno criada!

# %% [markdown]
# #### 4º - Função para se comunicar com Skill criada

# %%
skill_id_test = "8b1f8007-c5dd-4366-b48a-34bf295a929c"

# %%
import json
from ibm_watson import AssistantV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

authenticator = IAMAuthenticator(API_KEY)
assistant = AssistantV1(
    version='2020-04-01',
    authenticator = authenticator
)

assistant.set_service_url(SERVICE_URL)

def watson_predict(sentence):
    response = assistant.message(
        workspace_id=skill_id_test,
        input={
            'message_type': 'text',
            'text': sentence
        }
    ).get_result()
    if response.get("intents") and response["intents"]:
        return (response["intents"][0]["intent"], response["intents"][0]["confidence"])
    else:
        return "failed to identify", -1.0

# %% [markdown]
# # Battle Omni NLP API vs. Watson Assistent

# %%
from elasticsearch import Elasticsearch

query = {
      "size": 1000,
      "query": {
        "term": {
          "doc_type.keyword": "intent"
        }
      }
    }

es = Elasticsearch([{'host':"localhost",'port':9200}])

intents = es.search(index="nlp_model-dc1e7b3d-9137-4a20-a99c-d0d2029ef170", body=query)
intents = [result["_source"] for result in intents["hits"]["hits"]]
train_examples = []
test_examples = []
for intent in intents:
    intent_name = intent["intent"]
    train_examples += [(example["text"], intent_name) for example in intent["for_train"]]
    test_examples += [(example["text"], intent_name) for example in intent["for_test"]]

# %%
print(len(train_examples), len(test_examples))
# Out:
# 1039 692

# %%
692/(1039+692)
# Out:
# 0.3997689196995956

# %%
url = url_api+"nlp_model/resources/classify/"
omni_right_answer = 0
watson_right_answer = 0
for test in test_examples:
    params["sentence"] = test[0]
    r = requests.get(url, params=params)
    omni_result = r.json()
    watson_result = watson_predict(test[0])
    print("-------------------------------------------")
    print("sentence: %s"%test[0])
    print("\n")
    print("Omni NLP API\n")
    print("predict_intent: %s"%omni_result["intents"][0]["intent"])
    print("score: %.2f"%omni_result["intents"][0]["confidence"])
    print("right_intent: %s"%test[1])
    if omni_result["intents"][0]["intent"] == test[1]:
        omni_right_answer += 1
        print("is it right?: yes")
    else:
         print("is it right?: no")
    print("quantity of right answers: %s" %omni_right_answer)
    print("\n")
    
    print("Watson Assistent\n")
    print("predict_intent: %s"%watson_result[0])
    print("score: %.2f"%watson_result[1])
    print("right_intent: %s"%test[1])
    if watson_result[0] == test[1]:
        watson_right_answer += 1
        print("is it right?: yes")
    else:
         print("is it right?: no")
    print("quantity of right answers: %s" %watson_right_answer)
    print("\n")

print("-------------------------------------------\n")
print("Total of questions: %d\n"%len(test_examples))
print("Omni NLP API\n") 
print("Total of right answers: %d"%omni_right_answer)
omni_acc = round(omni_right_answer/len(test_examples), 2)*100
print("Accuracy: %s\n"%omni_acc)

print("Watson Assistent\n") 
print("Total of right answers: %d"%watson_right_answer)
watson_acc = round(watson_right_answer/len(test_examples), 2)*100
print("Accuracy: %s"%watson_acc)
# Out:
# -------------------------------------------
# sentence: Bom dia, não estou conseguindo acessar o Concur. Quando solicito alteração de senha, coloco meu email Yara e não recebo nada.
#
#
# Omni NLP API
#
# predict_intent: Acessar_Concur
# score: 0.78
# right_intent: Acessar_Concur
# is it right?: yes
# quantity of right answers: 1
#
#
# Watson Assistent
#
# predict_intent: Acessar_Concur
# score: 0.80
# right_intent: Acessar_Concur
# is it right?: yes
# quantity of right answers: 1
#
#
# -------------------------------------------
# sentence: Colaborador ligou e Informa que não está conseguindo acessar o Concur.
#
#
# Omni NLP API
#
# predict_intent: Acessar_Concur
# score: 0.73
# right_intent: Acessar_Concur
# is it right?: yes
# quantity of right answers: 2
#
#
# Watson Assistent
#
# predict_intent: Acessar_Concur
# score: 0.43
# right_intent: Acessar_Concur
# is it right?: yes
# quantity of right answers: 2
#
#
# -------------------------------------------
# sentence: Meu concur está bloqueado. Como Faço?
#
#
# Omni NLP API
#
# predict_intent: Cadastro_Concur
# score: 0.22
# right_intent: Acessar_Concur
# is it right?: no
# quantity of right answers: 2
#
#
# Watson Assistent
#
# predict_intent: Alteracao_CC
# score: 0.42
# right_intent: Acessar_Concur
# is it right?: no
# quantity of right answers: 2
#
#
# -------------------------------------------
# sentence: Como posso solicitar acesso ao ME?
#
#
# Omni NLP API
#
# predict_intent: Acessar_MercadoEletronico
# score: 0.20
# right_intent: Acessar_MercadoEletronico
# is it right?: yes
# quantity of right answers: 3
#
#
# Watson Assistent
#
# predict_intent: Acessar_MercadoEletronico
# score: 0.54
# right_intent: Acessar_MercadoEletronico
# is it right?: yes
# quantity of right answers: 3
#
#
# -------------------------------------------
# sentence: Onde solicito o acesso ao ME?
#
#
# Omni NLP API
#
# predict_intent: Solicitar_IRPF
# score: 0.42
# right_intent: Acessar_MercadoEletronico
# is it right?: no
# quantity of right answers: 3
#
#
# Watson Assistent
#
# predict_intent: Acessar_MercadoEletronico
# score: 0.67
# right_intent: Acessar_MercadoEletronico
# is it right?: yes
# quantity of right answers: 4
#
#
# -------------------------------------------
# sentence: Preciso de login e senha pro Mercado Eletrônico
#
#
# Omni NLP API
#
# predict_intent: Usuario_Invalido_NaoCadastrado
# score: 0.14
# right_intent: Acessar_MercadoEletronico
# is it right?: no
# quantity of right answers: 3
#
#
# Watson Assistent
#
# predict_intent: Usuario_Invalido_NaoCadastrado
# score: 0.37
# right_intent: Acessar_MercadoEletronico
# is it right?: no
# quantity of right answers: 4
#
#
# -------------------------------------------
# sentence: Como eu faço pra entrar no painel do colaborador?
#
#
# Omni NLP API
#
# predict_intent: Acessar_Painel_Colaborador
# score: 0.81
# right_intent: Acessar_Painel_Colaborador
# is it right?: yes
# quantity of right answers: 4
#
#
# Watson Assistent
#
# predict_intent: Acessar_Painel_Colaborador
# score: 0.72
# right_intent: Acessar_Painel_Colaborador
# is it right?: yes
# quantity of right answers: 5
#
#
# -------------------------------------------
# sentence: Estou sem acesso aos colaboradores do meu time no ponto mais.
#
#
# Omni NLP API
#
# predict_intent: IncluirRemover_Colaborador
# score: 0.87
# right_intent: Acessar_Painel_Colaborador
# is it right?: no
# quantity of right answers: 4
#
#
# Watson Assistent
#
# predict_intent: IncluirRemover_Colaborador
# score: 0.85
# right_intent: Acessar_Painel_Colaborador
# is it right?: no
# quantity of right answers: 5
#
#
# -------------------------------------------
# sentence: Não estou conseguindo acessar a gestão de ponto.
#
#
# Omni NLP API
#
# predict_intent: Ponto_Colaborar_Não_Aparece
# score: 0.74
# right_intent: Acessar_Painel_Colaborador
# is it right?: no
# quantity of right answers: 4
#
#
# Watson Assistent
#
# predict_intent: Ponto_Colaborar_Não_Aparece
# score: 0.44
# right_intent: Acessar_Painel_Colaborador
# is it right?: no
# quantity of right answers: 5
#
#
# -------------------------------------------
# sentence: Como faço pra ter acesso ao SAP e criar requisições de compras
#
#
# Omni NLP API
#
# predict_intent: Acessar_SAP_MercadoEletronico
# score: 0.84
# right_intent: Acessar_SAP_MercadoEletronico
# is it right?: yes
# quantity of right answers: 5
#
#
# Watson Assistent
#
# predict_intent: Acessar_SAP_MercadoEletronico
# score: 0.95
# right_intent: Acessar_SAP_MercadoEletronico
# is it right?: yes
# quantity of right answers: 6
#
#
# -------------------------------------------
# sentence: Como saber se posso ter acesso ao SAP?
#
#
# Omni NLP API
#
# predict_intent: Acessar_SAP_MercadoEletronico
# score: 0.84
# right_intent: Acessar_SAP_MercadoEletronico
# is it right?: yes
# quantity of right answers: 6
#
#
# Watson Assistent
#
# predict_intent: Acessar_SAP_MercadoEletronico
# score: 0.86
# right_intent: Acessar_SAP_MercadoEletronico
# is it right?: yes
# quantity of right answers: 7
#
#
# -------------------------------------------
# sentence: Preciso de login e senha do SAP.
#
#
# Omni NLP API
#
# predict_intent: Acessar_SAP_MercadoEletronico
# score: 0.81
# right_intent: Acessar_SAP_MercadoEletronico
# is it right?: yes
# quantity of right answers: 7
#
#
# Watson Assistent
#
# predict_intent: Esquecer_Senha_Vale_RefeicaoAlimentacao
# score: 0.53
# right_intent: Acessar_SAP_MercadoEletronico
# is it right?: no
# quantity of right answers: 7
#
#
# -------------------------------------------
# sentence: A entrega do meu pedido está atrasada
#
#
# Omni NLP API
#
# predict_intent: Acompanhar_Pedido_MercadoEletronico
# score: 0.66
# right_intent: Acompanhar_Pedido_MercadoEletronico
# is it right?: yes
# quantity of right answers: 8
#
#
# Watson Assistent
#
# predict_intent: Acompanhar_Pedido_MercadoEletronico
# score: 0.46
# right_intent: Acompanhar_Pedido_MercadoEletronico
# is it right?: yes
# quantity of right answers: 8
#
#
# -------------------------------------------
# sentence: Até o momento não recebi o material que solicitei.
#
#
# Omni NLP API
#
# predict_intent: General_Ending
# score: 0.67
# right_intent: Acompanhar_Pedido_MercadoEletronico
# is it right?: no
# quantity of right answers: 8
#
#
# Watson Assistent
#
# predict_intent: Pagamento_Ferias
# score: 0.39
# right_intent: Acompanhar_Pedido_MercadoEletronico
# is it right?: no
# quantity of right answers: 8
#
#
# -------------------------------------------
# sentence: Preciso de urgência na entrega do meu pedido.
#
#
# Omni NLP API
#
# predict_intent: Priorizar_Criacao_Pedidos
# score: 0.82
# right_intent: Acompanhar_Pedido_MercadoEletronico
# is it right?: no
# quantity of right answers: 8
#
#
# Watson Assistent
#
# predict_intent: Priorizar_Criacao_Pedidos
# score: 0.54
# right_intent: Acompanhar_Pedido_MercadoEletronico
# is it right?: no
# quantity of right answers: 8
#
#
# -------------------------------------------
# sentence: adiantamento @DecimoTerceiro
#
#
# Omni NLP API
#
# predict_intent: Adiantamento_e_QuandoReceber_13_Salario
# score: 0.96
# right_intent: Adiantamento_e_QuandoReceber_13_Salario
# is it right?: yes
# quantity of right answers: 9
#
#
# Watson Assistent
#
# predict_intent: Adiantamento_e_QuandoReceber_13_Salario
# score: 0.93
# right_intent: Adiantamento_e_QuandoReceber_13_Salario
# is it right?: yes
# quantity of right answers: 9
#
#
# -------------------------------------------
# sentence: Excluir o adiantamento de @DecimoTerceiro das férias programadas
#
#
# Omni NLP API
#
# predict_intent: Adiantamento_e_QuandoReceber_13_Salario
# score: 0.84
# right_intent: Adiantamento_e_QuandoReceber_13_Salario
# is it right?: yes
# quantity of right answers: 10
#
#
# Watson Assistent
#
# predict_intent: Adiantamento_e_QuandoReceber_13_Salario
# score: 0.92
# right_intent: Adiantamento_e_QuandoReceber_13_Salario
# is it right?: yes
# quantity of right answers: 10
#
#
# -------------------------------------------
# sentence: Gostaria de pedir adiantamento do meu @DecimoTerceiro das minhas férias
#
#
# Omni NLP API
#
# predict_intent: Adiantamento_e_QuandoReceber_13_Salario
# score: 0.90
# right_intent: Adiantamento_e_QuandoReceber_13_Salario
# is it right?: yes
# quantity of right answers: 11
#
#
# Watson Assistent
#
# predict_intent: Adiantamento_e_QuandoReceber_13_Salario
# score: 0.91
# right_intent: Adiantamento_e_QuandoReceber_13_Salario
# is it right?: yes
# quantity of right answers: 11
#
#
# -------------------------------------------
# sentence: Inserir o adiantamento de @DecimoTerceiro nas férias programada
#
#
# Omni NLP API
#
# predict_intent: Adiantamento_e_QuandoReceber_13_Salario
# score: 0.87
# right_intent: Adiantamento_e_QuandoReceber_13_Salario
# is it right?: yes
# quantity of right answers: 12
#
#
# Watson Assistent
#
# predict_intent: Adiantamento_e_QuandoReceber_13_Salario
# score: 0.92
# right_intent: Adiantamento_e_QuandoReceber_13_Salario
# is it right?: yes
# quantity of right answers: 12
# -------------------------------------------
# sentence: Quando receberei o adiantamento do @DecimoTerceiro salário?
#
#
# Omni NLP API
#
# predict_intent: Adiantamento_e_QuandoReceber_13_Salario
# score: 0.89
# right_intent: Adiantamento_e_QuandoReceber_13_Salario
# is it right?: yes
# quantity of right answers: 13
#
#
# Watson Assistent
#
# predict_intent: Adiantamento_e_QuandoReceber_13_Salario
# score: 0.98
# right_intent: Adiantamento_e_QuandoReceber_13_Salario
# is it right?: yes
# quantity of right answers: 13
#
#
# -------------------------------------------
# sentence: agendamento de férias
#
#
# Omni NLP API
#
# predict_intent: Agendamento_Alteracao_Ferias
# score: 0.94
# right_intent: Agendamento_Alteracao_Ferias
# is it right?: yes
# quantity of right answers: 14
#
#
# Watson Assistent
#
# predict_intent: Agendamento_Alteracao_Ferias
# score: 0.85
# right_intent: Agendamento_Alteracao_Ferias
# is it right?: yes
# quantity of right answers: 14
#
#
# -------------------------------------------
# sentence: alterar férias
#
#
# Omni NLP API
#
# predict_intent: Agendamento_Alteracao_Ferias
# score: 1.00
# right_intent: Agendamento_Alteracao_Ferias
# is it right?: yes
# quantity of right answers: 15
#
#
# Watson Assistent
#
# predict_intent: Agendamento_Alteracao_Ferias
# score: 0.79
# right_intent: Agendamento_Alteracao_Ferias
# is it right?: yes
# quantity of right answers: 15
#
#
# -------------------------------------------
# sentence: como agendo minhas férias?
#
#
# Omni NLP API
#
# predict_intent: Agendamento_Alteracao_Ferias
# score: 0.94
# right_intent: Agendamento_Alteracao_Ferias
# is it right?: yes
# quantity of right answers: 16
#
#
# Watson Assistent
#
# predict_intent: Agendamento_Alteracao_Ferias
# score: 0.90
# right_intent: Agendamento_Alteracao_Ferias
# is it right?: yes
# quantity of right answers: 16
#
#
# -------------------------------------------
# sentence: minhas férias foram agendadas para o começar dia @sys-date mas quero mudar para o dia @sys-date
#
#
# Omni NLP API
#
# predict_intent: Agendamento_Alteracao_Ferias
# score: 0.48
# right_intent: Agendamento_Alteracao_Ferias
# is it right?: yes
# quantity of right answers: 17
#
#
# Watson Assistent
#
# predict_intent: Agendamento_Alteracao_Ferias
# score: 0.51
# right_intent: Agendamento_Alteracao_Ferias
# is it right?: yes
# quantity of right answers: 17
#
#
# -------------------------------------------
# sentence: Tem algum lugar no portal do CoE onde consigo solicitar minhas férias?
#
#
# Omni NLP API
#
# predict_intent: Status_Ferias_e_Programacao_Sem_Confirmação
# score: 0.52
# right_intent: Agendamento_Alteracao_Ferias
# is it right?: no
# quantity of right answers: 17
#
#
# Watson Assistent
#
# predict_intent: Pagamento_Ferias
# score: 0.36
# right_intent: Agendamento_Alteracao_Ferias
# is it right?: no
# quantity of right answers: 17
#
#
# -------------------------------------------
# sentence: Como devo solicitar o ajuste do ponto?
#
#
# Omni NLP API
#
# predict_intent: Solicitar_Ponto_Pos_FechamentoReembolso
# score: 0.51
# right_intent: Ajustar_Ponto
# is it right?: no
# quantity of right answers: 17
#
#
# Watson Assistent
#
# predict_intent: Ajustar_Ponto
# score: 0.40
# right_intent: Ajustar_Ponto
# is it right?: yes
# quantity of right answers: 18
#
#
# -------------------------------------------
# sentence: Como eu faço pra arrumar meus pontos?
#
#
# Omni NLP API
#
# predict_intent: Ajustar_Ponto
# score: 0.84
# right_intent: Ajustar_Ponto
# is it right?: yes
# quantity of right answers: 18
#
#
# Watson Assistent
#
# predict_intent: Ajustar_Ponto
# score: 0.74
# right_intent: Ajustar_Ponto
# is it right?: yes
# quantity of right answers: 19
#
#
# -------------------------------------------
# sentence: estou com inconsistências no ponto, quem realiza o ajuste
#
#
# Omni NLP API
#
# predict_intent: Ajustar_Ponto
# score: 0.83
# right_intent: Ajustar_Ponto
# is it right?: yes
# quantity of right answers: 19
#
#
# Watson Assistent
#
# predict_intent: Ajustar_Ponto
# score: 0.64
# right_intent: Ajustar_Ponto
# is it right?: yes
# quantity of right answers: 20
#
#
# -------------------------------------------
# sentence: o COE ou RH pode realizar os ajustes no meu ponto
#
#
# Omni NLP API
#
# predict_intent: Aprovar_Solicitacao_Pendente_Ponto
# score: 0.81
# right_intent: Ajustar_Ponto
# is it right?: no
# quantity of right answers: 19
#
#
# Watson Assistent
#
# predict_intent: Ajustar_Ponto
# score: 0.53
# right_intent: Ajustar_Ponto
# is it right?: yes
# quantity of right answers: 21
#
#
# -------------------------------------------
# sentence: O que fazer esqueci de registrar o ponto?
#
#
# Omni NLP API
#
# predict_intent: Ajustar_Ponto
# score: 0.93
# right_intent: Ajustar_Ponto
# is it right?: yes
# quantity of right answers: 20
#
#
# Watson Assistent
#
# predict_intent: Ajustar_Ponto
# score: 0.95
# right_intent: Ajustar_Ponto
# is it right?: yes
# quantity of right answers: 22
#
#
# -------------------------------------------
# sentence: como vai?
#
#
# Omni NLP API
#
# predict_intent: General_Negative_Feedback
# score: 0.86
# right_intent: Bem_Estar
# is it right?: no
# quantity of right answers: 20
#
#
# Watson Assistent
#
# predict_intent: General_Negative_Feedback
# score: 0.39
# right_intent: Bem_Estar
# is it right?: no
# quantity of right answers: 22
#
#
# -------------------------------------------
# sentence: como vão as coisas?
#
#
# Omni NLP API
#
# predict_intent: Repassar_Gestao_Colaborador
# score: 0.20
# right_intent: Bem_Estar
# is it right?: no
# quantity of right answers: 20
#
#
# Watson Assistent
#
# predict_intent: Bem_Estar
# score: 0.36
# right_intent: Bem_Estar
# is it right?: yes
# quantity of right answers: 23
#
#
# -------------------------------------------
# sentence: tudo bem contigo?
#
#
# Omni NLP API
#
# predict_intent: Bem_Estar
# score: 0.85
# right_intent: Bem_Estar
# is it right?: yes
# quantity of right answers: 21
#
#
# Watson Assistent
#
# predict_intent: Bem_Estar
# score: 0.97
# right_intent: Bem_Estar
# is it right?: yes
# quantity of right answers: 24
#
#
# -------------------------------------------
# sentence: do que você sabe falar
#
#
# Omni NLP API
#
# predict_intent: Bot_Capabilities
# score: 0.86
# right_intent: Bot_Capabilities
# is it right?: yes
# quantity of right answers: 22
#
#
# Watson Assistent
#
# predict_intent: Bot_Capabilities
# score: 0.95
# right_intent: Bot_Capabilities
# is it right?: yes
# quantity of right answers: 25
#
#
# -------------------------------------------
# sentence: em que você pode me ajudar
#
#
# Omni NLP API
#
# predict_intent: Bot_Capabilities
# score: 0.83
# right_intent: Bot_Capabilities
# is it right?: yes
# quantity of right answers: 23
#
#
# Watson Assistent
#
# predict_intent: Bot_Capabilities
# score: 0.74
# right_intent: Bot_Capabilities
# is it right?: yes
# quantity of right answers: 26
#
#
# -------------------------------------------
# sentence: vc sabe falar do que
#
#
# Omni NLP API
#
# predict_intent: Bot_Capabilities
# score: 0.50
# right_intent: Bot_Capabilities
# is it right?: yes
# quantity of right answers: 24
#
#
# Watson Assistent
#
# predict_intent: Bot_Capabilities
# score: 0.63
# right_intent: Bot_Capabilities
# is it right?: yes
# quantity of right answers: 27
#
#
# -------------------------------------------
# sentence: quais os assuntos você trata
#
#
# Omni NLP API
#
# predict_intent: Bot_Capabilities
# score: 0.47
# right_intent: Bot_Capabilities
# is it right?: yes
# quantity of right answers: 25
#
#
# Watson Assistent
#
# predict_intent: Bot_Capabilities
# score: 0.57
# right_intent: Bot_Capabilities
# is it right?: yes
# quantity of right answers: 28
#
#
# -------------------------------------------
# sentence: Ao efetuar uma compra, a empresa prestadora de serviços passou a despesa errada para meu cartão. Ela estornou a compra, mas ainda aparece no concur. Como proceder.
#
#
# Omni NLP API
#
# predict_intent: Informacoes_Relatorio_Aberto
# score: 0.46
# right_intent: Cartao_Clonado_Cambial
# is it right?: no
# quantity of right answers: 25
#
#
# Watson Assistent
#
# predict_intent: Receber_Cartao_Convenio
# score: 0.29
# right_intent: Cartao_Clonado_Cambial
# is it right?: no
# quantity of right answers: 28
#
#
# -------------------------------------------
# sentence: Como carregar diferencias cambiais e iOF
#
#
# Omni NLP API
#
# predict_intent: General_Negative_Feedback
# score: 0.11
# right_intent: Cartao_Clonado_Cambial
# is it right?: no
# quantity of right answers: 25
#
#
# Watson Assistent
#
# predict_intent: Pessoas_Focadas_Excelencia
# score: 0.31
# right_intent: Cartao_Clonado_Cambial
# is it right?: no
# quantity of right answers: 28
#
#
# -------------------------------------------
# sentence: Não reconheço o débito no cartão corporativo abaixo
#
#
# Omni NLP API
#
# predict_intent: Emissoes_Cartao
# score: 0.33
# right_intent: Cartao_Clonado_Cambial
# is it right?: no
# quantity of right answers: 25
#
#
# Watson Assistent
#
# predict_intent: Emissoes_Cartao
# score: 0.72
# right_intent: Cartao_Clonado_Cambial
# is it right?: no
# quantity of right answers: 28
# -------------------------------------------
# sentence: Alteração de workflow dos centro de custos TRV2MT001 & TRV1MT027 para minha aprovação.
#
#
# Omni NLP API
#
# predict_intent: Alterar_Centro_Custo
# score: 0.70
# right_intent: Alterar_Aprovador
# is it right?: no
# quantity of right answers: 25
#
#
# Watson Assistent
#
# predict_intent: Alterar_Centro_Custo
# score: 0.74
# right_intent: Alterar_Aprovador
# is it right?: no
# quantity of right answers: 28
#
#
# -------------------------------------------
# sentence: a minha solicitação de adiantamento feito no concur, não está indo para o meu Gerente Fabiano Biasutti
#
#
# Omni NLP API
#
# predict_intent: Procedimentos_Concur
# score: 0.37
# right_intent: Alterar_Aprovador
# is it right?: no
# quantity of right answers: 25
#
#
# Watson Assistent
#
# predict_intent: Acessar_Concur
# score: 0.33
# right_intent: Alterar_Aprovador
# is it right?: no
# quantity of right answers: 28
#
#
# -------------------------------------------
# sentence: Estamos com novo gerente e as despesas do CONCUR não esta caindo para o novo gerente, necessito que regularize para as despesas ir para aprovação do GC-TAN Diego Zacarin.
#
#
# Omni NLP API
#
# predict_intent: Informacoes_Relatorio_Aberto
# score: 0.17
# right_intent: Alterar_Aprovador
# is it right?: no
# quantity of right answers: 25
#
#
# Watson Assistent
#
# predict_intent: Duvidas_Funcoes_Cartao
# score: 0.39
# right_intent: Alterar_Aprovador
# is it right?: no
# quantity of right answers: 28
#
#
# -------------------------------------------
# sentence: Estou tentando fazer uma prestação de contas, mas não foi possível pois é necessário a atualização do aprovador. Fui orientada a atualizar meus dados cadastrais, mas o sistema não reconhece o meu centro de custo. Favor verificar.
#
#
# Omni NLP API
#
# predict_intent: Informacoes_Relatorio_Aberto
# score: 0.40
# right_intent: Alterar_Aprovador
# is it right?: no
# quantity of right answers: 25
#
#
# Watson Assistent
#
# predict_intent: Info_Concur_SAP
# score: 0.27
# right_intent: Alterar_Aprovador
# is it right?: no
# quantity of right answers: 28
#
#
# -------------------------------------------
# sentence: Meus relatórios estão indo para uma pessoa porém ele não é mais meu gestor tem como corrigir para o meu gestor?
#
#
# Omni NLP API
#
# predict_intent: Alterar_Aprovador
# score: 0.58
# right_intent: Alterar_Aprovador
# is it right?: yes
# quantity of right answers: 26
#
#
# Watson Assistent
#
# predict_intent: Alterar_Aprovador
# score: 0.36
# right_intent: Alterar_Aprovador
# is it right?: yes
# quantity of right answers: 29
#
#
# -------------------------------------------
# sentence: alterar minha conta
#
#
# Omni NLP API
#
# predict_intent: Alterar_Conta_Pagamento
# score: 0.36
# right_intent: Alterar_Conta_Pagamento
# is it right?: yes
# quantity of right answers: 27
#
#
# Watson Assistent
#
# predict_intent: ME_Conta_Contábil
# score: 0.47
# right_intent: Alterar_Conta_Pagamento
# is it right?: no
# quantity of right answers: 29
#
#
# -------------------------------------------
# sentence: Como eu faço pra mudar a o banco onde é feito o deposito do meu salario
#
#
# Omni NLP API
#
# predict_intent: Alterar_Conta_Pagamento
# score: 0.79
# right_intent: Alterar_Conta_Pagamento
# is it right?: yes
# quantity of right answers: 28
#
#
# Watson Assistent
#
# predict_intent: Alterar_Conta_Pagamento
# score: 0.75
# right_intent: Alterar_Conta_Pagamento
# is it right?: yes
# quantity of right answers: 30
#
#
# -------------------------------------------
# sentence: mudar o banco
#
#
# Omni NLP API
#
# predict_intent: Alterar_Conta_Pagamento
# score: 0.50
# right_intent: Alterar_Conta_Pagamento
# is it right?: yes
# quantity of right answers: 29
#
#
# Watson Assistent
#
# predict_intent: Verificar_Banco_Horas
# score: 0.59
# right_intent: Alterar_Conta_Pagamento
# is it right?: no
# quantity of right answers: 30
#
#
# -------------------------------------------
# sentence: Como sei quem pode ter um aumento de salário por merecimento?
#
#
# Omni NLP API
#
# predict_intent: Alterar_EnquadramentoMerito
# score: 0.64
# right_intent: Alterar_EnquadramentoMerito
# is it right?: yes
# quantity of right answers: 30
#
#
# Watson Assistent
#
# predict_intent: Alterar_EnquadramentoMerito
# score: 0.65
# right_intent: Alterar_EnquadramentoMerito
# is it right?: yes
# quantity of right answers: 31
#
#
# -------------------------------------------
# sentence: Onde encontro informações sobre o processo para solicitar um aumento salarial?
#
#
# Omni NLP API
#
# predict_intent: Alterar_EnquadramentoMerito
# score: 0.81
# right_intent: Alterar_EnquadramentoMerito
# is it right?: yes
# quantity of right answers: 31
#
#
# Watson Assistent
#
# predict_intent: Alterar_EnquadramentoMerito
# score: 0.91
# right_intent: Alterar_EnquadramentoMerito
# is it right?: yes
# quantity of right answers: 32
#
#
# -------------------------------------------
# sentence: Qual prazo para analise da solicitação de aumento salarial?
#
#
# Omni NLP API
#
# predict_intent: Alterar_EnquadramentoMerito
# score: 0.82
# right_intent: Alterar_EnquadramentoMerito
# is it right?: yes
# quantity of right answers: 32
#
#
# Watson Assistent
#
# predict_intent: Alterar_EnquadramentoMerito
# score: 0.93
# right_intent: Alterar_EnquadramentoMerito
# is it right?: yes
# quantity of right answers: 33
#
#
# -------------------------------------------
# sentence: a colaboradora solicita a alteração de VR para VA.
#
#
# Omni NLP API
#
# predict_intent: Alterar_Vale_RefeicaoAlimentacao
# score: 0.84
# right_intent: Alterar_Vale_RefeicaoAlimentacao
# is it right?: yes
# quantity of right answers: 33
#
#
# Watson Assistent
#
# predict_intent: Alterar_Vale_RefeicaoAlimentacao
# score: 0.44
# right_intent: Alterar_Vale_RefeicaoAlimentacao
# is it right?: yes
# quantity of right answers: 34
#
#
# -------------------------------------------
# sentence: alteração vale reifeição
#
#
# Omni NLP API
#
# predict_intent: Alterar_Vale_RefeicaoAlimentacao
# score: 0.70
# right_intent: Alterar_Vale_RefeicaoAlimentacao
# is it right?: yes
# quantity of right answers: 34
#
#
# Watson Assistent
#
# predict_intent: Agendamento_Alteracao_Ferias
# score: 0.68
# right_intent: Alterar_Vale_RefeicaoAlimentacao
# is it right?: no
# quantity of right answers: 34
#
#
# -------------------------------------------
# sentence: Recebi meu Cartão Alelo Refeição, porém tinha solicitado o Cartão Alelo Alimentação, como devo fazer para realizar a troca dos cartões?
#
#
# Omni NLP API
#
# predict_intent: Esquecer_Senha_Vale_RefeicaoAlimentacao
# score: 0.50
# right_intent: Alterar_Vale_RefeicaoAlimentacao
# is it right?: no
# quantity of right answers: 34
#
#
# Watson Assistent
#
# predict_intent: Valor_Depositado_Vale_RefeicaoAlimentacao_Errado
# score: 0.36
# right_intent: Alterar_Vale_RefeicaoAlimentacao
# is it right?: no
# quantity of right answers: 34
#
#
# -------------------------------------------
# sentence: Gostaria de saber quando será realizado o crédito do vale alimentação
#
#
# Omni NLP API
#
# predict_intent: Data_Pagamento_Vale_RefeicaoAlimentação
# score: 0.47
# right_intent: Data_Pagamento_Vale_RefeicaoAlimentação
# is it right?: yes
# quantity of right answers: 35
#
#
# Watson Assistent
#
# predict_intent: Adiantamento_e_QuandoReceber_13_Salario
# score: 0.34
# right_intent: Data_Pagamento_Vale_RefeicaoAlimentação
# is it right?: no
# quantity of right answers: 34
#
#
# -------------------------------------------
# sentence: Gostaria verificação do que aconteceu para não recebimento do meu saldo de VA (Alelo Alimentação).
#
#
# Omni NLP API
#
# predict_intent: Valor_Depositado_Vale_RefeicaoAlimentacao_Errado
# score: 0.76
# right_intent: Data_Pagamento_Vale_RefeicaoAlimentação
# is it right?: no
# quantity of right answers: 35
#
#
# Watson Assistent
#
# predict_intent: Valor_Depositado_Vale_RefeicaoAlimentacao_Errado
# score: 0.62
# right_intent: Data_Pagamento_Vale_RefeicaoAlimentação
# is it right?: no
# quantity of right answers: 34
#
#
# -------------------------------------------
# sentence: O dinheiro do vale refeição é depositado em qual dia?
#
#
# Omni NLP API
#
# predict_intent: Valor_Depositado_Vale_RefeicaoAlimentacao_Errado
# score: 0.56
# right_intent: Data_Pagamento_Vale_RefeicaoAlimentação
# is it right?: no
# quantity of right answers: 35
#
#
# Watson Assistent
#
# predict_intent: Data_Limite_Ferias
# score: 0.31
# right_intent: Data_Pagamento_Vale_RefeicaoAlimentação
# is it right?: no
# quantity of right answers: 34
#
#
# -------------------------------------------
# sentence: A sua Esposa esta com a data de nascimento incorreta no sistema da Operadora Bradesco Odonto, favor verificar.
#
#
# Omni NLP API
#
# predict_intent: Ajuste_Informacao_Convenio
# score: 0.37
# right_intent: Ajuste_Informacao_Convenio
# is it right?: yes
# quantity of right answers: 36
#
#
# Watson Assistent
#
# predict_intent: Ajuste_Informacao_Convenio
# score: 0.44
# right_intent: Ajuste_Informacao_Convenio
# is it right?: yes
# quantity of right answers: 35
# -------------------------------------------
# sentence: Minha filha precisou usar o plano , porém a clínica, informou que o cadastro está com a data de nascimento errada, favor corrigir.
#
#
# Omni NLP API
#
# predict_intent: Ajuste_Informacao_Convenio
# score: 0.79
# right_intent: Ajuste_Informacao_Convenio
# is it right?: yes
# quantity of right answers: 37
#
#
# Watson Assistent
#
# predict_intent: Ajuste_Informacao_Convenio
# score: 0.32
# right_intent: Ajuste_Informacao_Convenio
# is it right?: yes
# quantity of right answers: 36
#
#
# -------------------------------------------
# sentence: Preciso arrumar meu nome no convenio
#
#
# Omni NLP API
#
# predict_intent: Ajuste_Informacao_Convenio
# score: 0.60
# right_intent: Ajuste_Informacao_Convenio
# is it right?: yes
# quantity of right answers: 38
#
#
# Watson Assistent
#
# predict_intent: Ajuste_Informacao_Convenio
# score: 0.48
# right_intent: Ajuste_Informacao_Convenio
# is it right?: yes
# quantity of right answers: 37
#
#
# -------------------------------------------
# sentence: Estou com o contra-cheque, mas o pagamento ainda não caiu na conta
#
#
# Omni NLP API
#
# predict_intent: Contracheque_Recebido_Sem_Constar_Conta
# score: 0.83
# right_intent: Contracheque_Recebido_Sem_Constar_Conta
# is it right?: yes
# quantity of right answers: 39
#
#
# Watson Assistent
#
# predict_intent: Contracheque_Recebido_Sem_Constar_Conta
# score: 0.98
# right_intent: Contracheque_Recebido_Sem_Constar_Conta
# is it right?: yes
# quantity of right answers: 38
#
#
# -------------------------------------------
# sentence: Fiquei sem salário, por que?
#
#
# Omni NLP API
#
# predict_intent: Alterar_Conta_Pagamento
# score: 0.14
# right_intent: Contracheque_Recebido_Sem_Constar_Conta
# is it right?: no
# quantity of right answers: 39
#
#
# Watson Assistent
#
# predict_intent: Alteracao_CargoSalario
# score: 0.49
# right_intent: Contracheque_Recebido_Sem_Constar_Conta
# is it right?: no
# quantity of right answers: 38
#
#
# -------------------------------------------
# sentence: Por que recebi o recibo de pagamento e o salaraio não?
#
#
# Omni NLP API
#
# predict_intent: Pagamento_Ferias
# score: 0.26
# right_intent: Contracheque_Recebido_Sem_Constar_Conta
# is it right?: no
# quantity of right answers: 39
#
#
# Watson Assistent
#
# predict_intent: Pagamento_Ferias
# score: 0.47
# right_intent: Contracheque_Recebido_Sem_Constar_Conta
# is it right?: no
# quantity of right answers: 38
#
#
# -------------------------------------------
# sentence: Como devolvo o dinheiro do adiantamento pra Yara
#
#
# Omni NLP API
#
# predict_intent: Adiantamento_Duplicado
# score: 0.44
# right_intent: Despesa_Pessoal_Marcado_Relatorio_Concur
# is it right?: no
# quantity of right answers: 39
#
#
# Watson Assistent
#
# predict_intent: Despesa_Pessoal_Marcado_Relatorio_Concur
# score: 0.44
# right_intent: Despesa_Pessoal_Marcado_Relatorio_Concur
# is it right?: yes
# quantity of right answers: 39
#
#
# -------------------------------------------
# sentence: Como faço para prestar contas da devolução de um adiantamento no Concur?
#
#
# Omni NLP API
#
# predict_intent: Despesa_Pessoal_Marcado_Relatorio_Concur
# score: 0.81
# right_intent: Despesa_Pessoal_Marcado_Relatorio_Concur
# is it right?: yes
# quantity of right answers: 40
#
#
# Watson Assistent
#
# predict_intent: Despesa_Pessoal_Marcado_Relatorio_Concur
# score: 0.83
# right_intent: Despesa_Pessoal_Marcado_Relatorio_Concur
# is it right?: yes
# quantity of right answers: 40
#
#
# -------------------------------------------
# sentence: Qual o tipo de Despesa que eu seleciono para Devolução de adiantamento?
#
#
# Omni NLP API
#
# predict_intent: Despesa_Pessoal_Marcado_Relatorio_Concur
# score: 0.61
# right_intent: Despesa_Pessoal_Marcado_Relatorio_Concur
# is it right?: yes
# quantity of right answers: 41
#
#
# Watson Assistent
#
# predict_intent: Despesa_Pessoal_Marcado_Relatorio_Concur
# score: 0.78
# right_intent: Despesa_Pessoal_Marcado_Relatorio_Concur
# is it right?: yes
# quantity of right answers: 41
#
#
# -------------------------------------------
# sentence: Aconteceu um desconto errado no meu contracheque
#
#
# Omni NLP API
#
# predict_intent: Detalhe_Sobre_Desconto
# score: 0.69
# right_intent: Detalhe_Sobre_Desconto
# is it right?: yes
# quantity of right answers: 42
#
#
# Watson Assistent
#
# predict_intent: Detalhe_Sobre_Desconto
# score: 0.61
# right_intent: Detalhe_Sobre_Desconto
# is it right?: yes
# quantity of right answers: 42
#
#
# -------------------------------------------
# sentence: Aconteceu um desconto errado no meu holerite
#
#
# Omni NLP API
#
# predict_intent: Solicitar_Holerite
# score: 0.54
# right_intent: Detalhe_Sobre_Desconto
# is it right?: no
# quantity of right answers: 42
#
#
# Watson Assistent
#
# predict_intent: Detalhe_Sobre_Desconto
# score: 0.62
# right_intent: Detalhe_Sobre_Desconto
# is it right?: yes
# quantity of right answers: 43
#
#
# -------------------------------------------
# sentence: Retenções folha
#
#
# Omni NLP API
#
# predict_intent: Desconto_em_Folha
# score: 0.29
# right_intent: Detalhe_Sobre_Desconto
# is it right?: no
# quantity of right answers: 42
#
#
# Watson Assistent
#
# predict_intent: General_Negative_Feedback
# score: 0.38
# right_intent: Detalhe_Sobre_Desconto
# is it right?: no
# quantity of right answers: 43
#
#
# -------------------------------------------
# sentence: dois colaboradores do meu QL me questionaram de valor que veio diferente neste mês, em qual dos serviços devo abrir chamado?
#
#
# Omni NLP API
#
# predict_intent: Detalhe_Sobre_Desconto
# score: 0.11
# right_intent: Detalhe_Sobre_Desconto
# is it right?: yes
# quantity of right answers: 43
#
#
# Watson Assistent
#
# predict_intent: IncluirRemover_Colaborador
# score: 0.33
# right_intent: Detalhe_Sobre_Desconto
# is it right?: no
# quantity of right answers: 43
#
#
# -------------------------------------------
# sentence: Como é feita a devolução do veiculo?
#
#
# Omni NLP API
#
# predict_intent: Devolucao_Veiculo
# score: 0.84
# right_intent: Devolucao_Veiculo
# is it right?: yes
# quantity of right answers: 44
#
#
# Watson Assistent
#
# predict_intent: Devolucao_Veiculo
# score: 0.86
# right_intent: Devolucao_Veiculo
# is it right?: yes
# quantity of right answers: 44
#
#
# -------------------------------------------
# sentence: Como realizar a devolução do veículo?
#
#
# Omni NLP API
#
# predict_intent: Devolucao_Veiculo
# score: 0.85
# right_intent: Devolucao_Veiculo
# is it right?: yes
# quantity of right answers: 45
#
#
# Watson Assistent
#
# predict_intent: Devolucao_Veiculo
# score: 0.88
# right_intent: Devolucao_Veiculo
# is it right?: yes
# quantity of right answers: 45
#
#
# -------------------------------------------
# sentence: Qual procedimento para a devolução de um veículo?
#
#
# Omni NLP API
#
# predict_intent: Devolucao_Veiculo
# score: 0.84
# right_intent: Devolucao_Veiculo
# is it right?: yes
# quantity of right answers: 46
#
#
# Watson Assistent
#
# predict_intent: Devolucao_Veiculo
# score: 0.70
# right_intent: Devolucao_Veiculo
# is it right?: yes
# quantity of right answers: 46
#
#
# -------------------------------------------
# sentence: divisão ferias
#
#
# Omni NLP API
#
# predict_intent: Divisao_Ferias
# score: 0.81
# right_intent: Divisao_Ferias
# is it right?: yes
# quantity of right answers: 47
#
#
# Watson Assistent
#
# predict_intent: Divisao_Ferias
# score: 0.63
# right_intent: Divisao_Ferias
# is it right?: yes
# quantity of right answers: 47
#
#
# -------------------------------------------
# sentence: Duvidas sobre tirar @sys-number dias de férias e vender @sys-number, no passado já tirou @sys-number.
#
#
# Omni NLP API
#
# predict_intent: Divisao_Ferias
# score: 0.61
# right_intent: Divisao_Ferias
# is it right?: yes
# quantity of right answers: 48
#
#
# Watson Assistent
#
# predict_intent: Abono
# score: 0.66
# right_intent: Divisao_Ferias
# is it right?: no
# quantity of right answers: 47
#
#
# -------------------------------------------
# sentence: Gostaria de tirar uma dúvida referente a programação de férias da colaboradora. Podemos programar @sys-number dias de férias e solicitar abono pecuniário @sys-number dias em @Datas?
#
#
# Omni NLP API
#
# predict_intent: Agendamento_Alteracao_Ferias
# score: 0.74
# right_intent: Divisao_Ferias
# is it right?: no
# quantity of right answers: 48
#
#
# Watson Assistent
#
# predict_intent: Abono
# score: 0.80
# right_intent: Divisao_Ferias
# is it right?: no
# quantity of right answers: 47
#
#
# -------------------------------------------
# sentence: A colaboradora estava com duvidas ao baixar o App do Aplicativo a unimed.
#
#
# Omni NLP API
#
# predict_intent: Download_Aplicativo_Convenio
# score: 0.85
# right_intent: Download_Aplicativo_Convenio
# is it right?: yes
# quantity of right answers: 49
#
#
# Watson Assistent
#
# predict_intent: Download_Aplicativo_Convenio
# score: 0.84
# right_intent: Download_Aplicativo_Convenio
# is it right?: yes
# quantity of right answers: 48
# -------------------------------------------
# sentence: Como faço download do app médico?
#
#
# Omni NLP API
#
# predict_intent: Download_Aplicativo_Convenio
# score: 0.37
# right_intent: Download_Aplicativo_Convenio
# is it right?: yes
# quantity of right answers: 50
#
#
# Watson Assistent
#
# predict_intent: Reembolso_Sem_Cobertura_Convenio
# score: 0.62
# right_intent: Download_Aplicativo_Convenio
# is it right?: no
# quantity of right answers: 48
#
#
# -------------------------------------------
# sentence: Não estou localizando o App, Aplicativo do meu plano
#
#
# Omni NLP API
#
# predict_intent: Download_Aplicativo_Convenio
# score: 0.84
# right_intent: Download_Aplicativo_Convenio
# is it right?: yes
# quantity of right answers: 51
#
#
# Watson Assistent
#
# predict_intent: Download_Aplicativo_Convenio
# score: 0.86
# right_intent: Download_Aplicativo_Convenio
# is it right?: yes
# quantity of right answers: 49
#
#
# -------------------------------------------
# sentence: Ainda não recebi meu auxilio mudança, como faço para pagar as despesas de transporte?
#
#
# Omni NLP API
#
# predict_intent: Procedimentos_Concur
# score: 0.54
# right_intent: Duvidas_Benefícios
# is it right?: no
# quantity of right answers: 51
#
#
# Watson Assistent
#
# predict_intent: Procedimentos_Concur
# score: 0.50
# right_intent: Duvidas_Benefícios
# is it right?: no
# quantity of right answers: 49
#
#
# -------------------------------------------
# sentence: Cartão Combustível
#
#
# Omni NLP API
#
# predict_intent: Solicitar_Cartao_Combustivel
# score: 0.87
# right_intent: Duvidas_Benefícios
# is it right?: no
# quantity of right answers: 51
#
#
# Watson Assistent
#
# predict_intent: Solicitar_Cartao_Combustivel
# score: 0.95
# right_intent: Duvidas_Benefícios
# is it right?: no
# quantity of right answers: 49
#
#
# -------------------------------------------
# sentence: Tenho o plano de saúde Bradesco. Há médicos que não atendem pelo convênio. Sou Gerente Sênior e sei que a Yara reembolsa 80% deste valor. Pergunto: como encaminhar estes recibos aqui pelo portal?
#
#
# Omni NLP API
#
# predict_intent: Procedimentos_Convenio
# score: 0.42
# right_intent: Duvidas_Benefícios
# is it right?: no
# quantity of right answers: 51
#
#
# Watson Assistent
#
# predict_intent: Reembolso_Sem_Cobertura_Convenio
# score: 0.33
# right_intent: Duvidas_Benefícios
# is it right?: no
# quantity of right answers: 49
#
#
# -------------------------------------------
# sentence: Como solicito reembolso para pagar o frete devido a mudança de unidade da Yara?
#
#
# Omni NLP API
#
# predict_intent: Duvidas_Benefícios
# score: 0.83
# right_intent: Duvidas_Benefícios
# is it right?: yes
# quantity of right answers: 52
#
#
# Watson Assistent
#
# predict_intent: Duvidas_Benefícios
# score: 0.57
# right_intent: Duvidas_Benefícios
# is it right?: yes
# quantity of right answers: 50
#
#
# -------------------------------------------
# sentence: Bom dia, recebi um telefone celular da empresa no ano passado. Contudo é um telefone com pouquíssimos recursos, e não está atendendo as demandas. Meu gestor está de acordo com a aprovação do reembolso de R$ 1500,00 para compra de um novo. Tem mais alguém que precisaria estar de acordo?
#
#
# Omni NLP API
#
# predict_intent: Informacoes_Relatorio_Aberto
# score: 0.79
# right_intent: Duvidas_Celular_Corporativo
# is it right?: no
# quantity of right answers: 52
#
#
# Watson Assistent
#
# predict_intent: Informacoes_Relatorio_Aberto
# score: 0.33
# right_intent: Duvidas_Celular_Corporativo
# is it right?: no
# quantity of right answers: 50
#
#
# -------------------------------------------
# sentence: Comprei um aparelho celular com recursos próprios. Como lanço para obter o reemblso dos R$1500,00 .
#
#
# Omni NLP API
#
# predict_intent: Duvidas_Celular_Corporativo
# score: 0.59
# right_intent: Duvidas_Celular_Corporativo
# is it right?: yes
# quantity of right answers: 53
#
#
# Watson Assistent
#
# predict_intent: Duvidas_Celular_Corporativo
# score: 0.62
# right_intent: Duvidas_Celular_Corporativo
# is it right?: yes
# quantity of right answers: 51
#
#
# -------------------------------------------
# sentence: minha gerência autorizou a troca do aparelho celular que eu utilizo, e há uma pessoa nova entrando também para fazer parte da equipe, e não possuímos cartão corporativo, como eu posso efetuar a troca do aparelho? É possível solicitar o adiantamento?
#
#
# Omni NLP API
#
# predict_intent: Duvidas_Celular_Corporativo
# score: 0.52
# right_intent: Duvidas_Celular_Corporativo
# is it right?: yes
# quantity of right answers: 54
#
#
# Watson Assistent
#
# predict_intent: Solicitar_Troca_Veiculo
# score: 0.50
# right_intent: Duvidas_Celular_Corporativo
# is it right?: no
# quantity of right answers: 51
#
#
# -------------------------------------------
# sentence: Estou com dúvidas no lançamento do pedido de reembolso da vacina da gripe. Eu fiz o lançamento via concur, porém não há uma opção clara para reembolso da vacina.
#
#
# Omni NLP API
#
# predict_intent: Informacoes_Relatorio_Aberto
# score: 0.34
# right_intent: Duvidas_Despesas
# is it right?: no
# quantity of right answers: 54
#
#
# Watson Assistent
#
# predict_intent: Reembolso_Sem_Cobertura_Convenio
# score: 0.42
# right_intent: Duvidas_Despesas
# is it right?: no
# quantity of right answers: 51
#
#
# -------------------------------------------
# sentence: Estou solicitando um reembolso da vacina da gripe, mas não encontrei nenhuma opção para este tipo de despesas no concur
#
#
# Omni NLP API
#
# predict_intent: Procedimentos_Concur
# score: 0.76
# right_intent: Duvidas_Despesas
# is it right?: no
# quantity of right answers: 54
#
#
# Watson Assistent
#
# predict_intent: Procedimentos_Concur
# score: 0.58
# right_intent: Duvidas_Despesas
# is it right?: no
# quantity of right answers: 51
#
#
# -------------------------------------------
# sentence: Paguei uma hospedagem com meus proprio recursos e gostaria de solicitar reembolso no Concur.
#
#
# Omni NLP API
#
# predict_intent: Duvidas_Despesas
# score: 0.57
# right_intent: Duvidas_Despesas
# is it right?: yes
# quantity of right answers: 55
#
#
# Watson Assistent
#
# predict_intent: Duvidas_Despesas
# score: 0.69
# right_intent: Duvidas_Despesas
# is it right?: yes
# quantity of right answers: 52
#
#
# -------------------------------------------
# sentence: Estou com uma inconsistência no ERP
#
#
# Omni NLP API
#
# predict_intent: Relatorio_Inconsistencias_Ponto
# score: 0.60
# right_intent: Erros_MercadoEletronico
# is it right?: no
# quantity of right answers: 55
#
#
# Watson Assistent
#
# predict_intent: Inconformidades_Legais
# score: 0.36
# right_intent: Erros_MercadoEletronico
# is it right?: no
# quantity of right answers: 52
#
#
# -------------------------------------------
# sentence: Gerou um erro de "Erro ORD" na criação do pré-pedido
#
#
# Omni NLP API
#
# predict_intent: Erros_MercadoEletronico
# score: 0.92
# right_intent: Erros_MercadoEletronico
# is it right?: yes
# quantity of right answers: 56
#
#
# Watson Assistent
#
# predict_intent: Erros_MercadoEletronico
# score: 0.96
# right_intent: Erros_MercadoEletronico
# is it right?: yes
# quantity of right answers: 53
#
#
# -------------------------------------------
# sentence: Preciso ajustar meu pré pedido mas esta com inconsistencia de ID idioma
#
#
# Omni NLP API
#
# predict_intent: Erros_MercadoEletronico
# score: 0.87
# right_intent: Erros_MercadoEletronico
# is it right?: yes
# quantity of right answers: 57
#
#
# Watson Assistent
#
# predict_intent: Erros_MercadoEletronico
# score: 0.91
# right_intent: Erros_MercadoEletronico
# is it right?: yes
# quantity of right answers: 54
#
#
# -------------------------------------------
# sentence: Minha RC esta com erro no ME devido a um erro de verificação de compromisso
#
#
# Omni NLP API
#
# predict_intent: Erros_MercadoEletronico
# score: 0.91
# right_intent: Erros_MercadoEletronico
# is it right?: yes
# quantity of right answers: 58
#
#
# Watson Assistent
#
# predict_intent: Erros_MercadoEletronico
# score: 0.99
# right_intent: Erros_MercadoEletronico
# is it right?: yes
# quantity of right answers: 55
#
#
# -------------------------------------------
# sentence: A senha do cartão Alelo foi esquecida. Como fazer para ter uma nova senha?
#
#
# Omni NLP API
#
# predict_intent: Cartao_Bloqueado_SenhaInvalida
# score: 0.78
# right_intent: Esquecer_Senha_Vale_RefeicaoAlimentacao
# is it right?: no
# quantity of right answers: 58
#
#
# Watson Assistent
#
# predict_intent: Esquecer_Senha_Vale_RefeicaoAlimentacao
# score: 0.63
# right_intent: Esquecer_Senha_Vale_RefeicaoAlimentacao
# is it right?: yes
# quantity of right answers: 56
#
#
# -------------------------------------------
# sentence: Como conseguir uma nova senha Cartão Aleo VR, VA?
#
#
# Omni NLP API
#
# predict_intent: Esquecer_Senha_Vale_RefeicaoAlimentacao
# score: 0.69
# right_intent: Esquecer_Senha_Vale_RefeicaoAlimentacao
# is it right?: yes
# quantity of right answers: 59
#
#
# Watson Assistent
#
# predict_intent: Cartao_Bloqueado_SenhaInvalida
# score: 0.60
# right_intent: Esquecer_Senha_Vale_RefeicaoAlimentacao
# is it right?: no
# quantity of right answers: 56
# -------------------------------------------
# sentence: O que fazer esqueci a senha do Cartão Alelo Vale Alimentação, Refeição ?
#
#
# Omni NLP API
#
# predict_intent: Esquecer_Senha_Vale_RefeicaoAlimentacao
# score: 0.74
# right_intent: Esquecer_Senha_Vale_RefeicaoAlimentacao
# is it right?: yes
# quantity of right answers: 60
#
#
# Watson Assistent
#
# predict_intent: Esquecer_Senha_Vale_RefeicaoAlimentacao
# score: 0.84
# right_intent: Esquecer_Senha_Vale_RefeicaoAlimentacao
# is it right?: yes
# quantity of right answers: 57
#
#
# -------------------------------------------
# sentence: Estou com erro de aprovador da minha RC
#
#
# Omni NLP API
#
# predict_intent: Erros_MercadoEletronico
# score: 0.73
# right_intent: Estrategia_Aprovar
# is it right?: no
# quantity of right answers: 60
#
#
# Watson Assistent
#
# predict_intent: Erros_MercadoEletronico
# score: 0.48
# right_intent: Estrategia_Aprovar
# is it right?: no
# quantity of right answers: 57
#
#
# -------------------------------------------
# sentence: Estou com erro no workflow de aprovação de uma RC e por isso a mesma está pendente no sistema.
#
#
# Omni NLP API
#
# predict_intent: Estrategia_Aprovar
# score: 0.64
# right_intent: Estrategia_Aprovar
# is it right?: yes
# quantity of right answers: 61
#
#
# Watson Assistent
#
# predict_intent: Estrategia_Aprovar
# score: 0.47
# right_intent: Estrategia_Aprovar
# is it right?: yes
# quantity of right answers: 58
#
#
# -------------------------------------------
# sentence: Minha requisição não esta com o aprovador correto
#
#
# Omni NLP API
#
# predict_intent: Aprovações_YPP
# score: 0.55
# right_intent: Estrategia_Aprovar
# is it right?: no
# quantity of right answers: 61
#
#
# Watson Assistent
#
# predict_intent: Status_Item_Cancelado
# score: 0.72
# right_intent: Estrategia_Aprovar
# is it right?: no
# quantity of right answers: 58
#
#
# -------------------------------------------
# sentence: abono
#
#
# Omni NLP API
#
# predict_intent: Abono
# score: 0.83
# right_intent: Abono
# is it right?: yes
# quantity of right answers: 62
#
#
# Watson Assistent
#
# predict_intent: Abono
# score: 0.92
# right_intent: Abono
# is it right?: yes
# quantity of right answers: 59
#
#
# -------------------------------------------
# sentence: Posso vender as férias?
#
#
# Omni NLP API
#
# predict_intent: Abono
# score: 0.83
# right_intent: Abono
# is it right?: yes
# quantity of right answers: 63
#
#
# Watson Assistent
#
# predict_intent: Abono
# score: 0.64
# right_intent: Abono
# is it right?: yes
# quantity of right answers: 60
#
#
# -------------------------------------------
# sentence: posso vender o féria
#
#
# Omni NLP API
#
# predict_intent: Abono
# score: 0.83
# right_intent: Abono
# is it right?: yes
# quantity of right answers: 64
#
#
# Watson Assistent
#
# predict_intent: Abono
# score: 0.63
# right_intent: Abono
# is it right?: yes
# quantity of right answers: 61
#
#
# -------------------------------------------
# sentence: comprovante de pagamento mensalidade sindical
#
#
# Omni NLP API
#
# predict_intent: Abrir_Chamado_Salario
# score: 0.84
# right_intent: Abrir_Chamado_Salario
# is it right?: yes
# quantity of right answers: 65
#
#
# Watson Assistent
#
# predict_intent: Abrir_Chamado_Salario
# score: 1.00
# right_intent: Abrir_Chamado_Salario
# is it right?: yes
# quantity of right answers: 62
#
#
# -------------------------------------------
# sentence: tenho umar dúvida o meu pagamento
#
#
# Omni NLP API
#
# predict_intent: Abrir_Chamado_Salario
# score: 0.83
# right_intent: Abrir_Chamado_Salario
# is it right?: yes
# quantity of right answers: 66
#
#
# Watson Assistent
#
# predict_intent: Abrir_Chamado_Salario
# score: 0.82
# right_intent: Abrir_Chamado_Salario
# is it right?: yes
# quantity of right answers: 63
#
#
# -------------------------------------------
# sentence: preciso abrir um chamar de salário
#
#
# Omni NLP API
#
# predict_intent: Abrir_Chamado_Salario
# score: 0.83
# right_intent: Abrir_Chamado_Salario
# is it right?: yes
# quantity of right answers: 67
#
#
# Watson Assistent
#
# predict_intent: Abrir_Chamado_Salario
# score: 0.84
# right_intent: Abrir_Chamado_Salario
# is it right?: yes
# quantity of right answers: 64
#
#
# -------------------------------------------
# sentence: o jurídico possuir um sistema de gestão de contrato como fazer parir
#
#
# Omni NLP API
#
# predict_intent: Acessar_CMS
# score: 0.71
# right_intent: Acessar_CMS
# is it right?: yes
# quantity of right answers: 68
#
#
# Watson Assistent
#
# predict_intent: Acessar_CMS
# score: 0.39
# right_intent: Acessar_CMS
# is it right?: yes
# quantity of right answers: 65
#
#
# -------------------------------------------
# sentence: como criar o acesso ao cms
#
#
# Omni NLP API
#
# predict_intent: Acessar_CMS
# score: 0.82
# right_intent: Acessar_CMS
# is it right?: yes
# quantity of right answers: 69
#
#
# Watson Assistent
#
# predict_intent: Acessar_CMS
# score: 1.00
# right_intent: Acessar_CMS
# is it right?: yes
# quantity of right answers: 66
#
#
# -------------------------------------------
# sentence: preciso de acesso o ferramenta eletrônica do jurídico
#
#
# Omni NLP API
#
# predict_intent: Acessar_CMS
# score: 0.82
# right_intent: Acessar_CMS
# is it right?: yes
# quantity of right answers: 70
#
#
# Watson Assistent
#
# predict_intent: Acessar_CMS
# score: 0.95
# right_intent: Acessar_CMS
# is it right?: yes
# quantity of right answers: 67
#
#
# -------------------------------------------
# sentence: o meu documentar não ter valor quem assinar
#
#
# Omni NLP API
#
# predict_intent: Acionista_Yara_GICS
# score: 0.81
# right_intent: Acionista_Yara_GICS
# is it right?: yes
# quantity of right answers: 71
#
#
# Watson Assistent
#
# predict_intent: Acionista_Yara_GICS
# score: 0.52
# right_intent: Acionista_Yara_GICS
# is it right?: yes
# quantity of right answers: 68
#
#
# -------------------------------------------
# sentence: quem ser o acionistas da yara
#
#
# Omni NLP API
#
# predict_intent: Acionista_Yara_GICS
# score: 0.82
# right_intent: Acionista_Yara_GICS
# is it right?: yes
# quantity of right answers: 72
#
#
# Watson Assistent
#
# predict_intent: Acionista_Yara_GICS
# score: 0.91
# right_intent: Acionista_Yara_GICS
# is it right?: yes
# quantity of right answers: 69
#
#
# -------------------------------------------
# sentence: como provar que yara incorporar gics
#
#
# Omni NLP API
#
# ...
# predict_intent: Treinamento_Juridico
# score: 0.85
# right_intent: Treinamento_Juridico
# is it right?: yes
# quantity of right answers: 524
#
#
# Watson Assistent
#
# predict_intent: Treinamento_Juridico
# score: 0.84
# right_intent: Treinamento_Juridico
# is it right?: yes
# quantity of right answers: 525
#
#
# -------------------------------------------
# sentence: temos dúvida sobrar algum procedimento poder solicitar um treinamento
#
#
# Omni NLP API
#
# predict_intent: Treinamento_Juridico
# score: 0.83
# right_intent: Treinamento_Juridico
# is it right?: yes
# quantity of right answers: 525
#
#
# Watson Assistent
#
# predict_intent: Treinamento_Juridico
# score: 0.85
# right_intent: Treinamento_Juridico
# is it right?: yes
# quantity of right answers: 526
#
#
# -------------------------------------------
# sentence: o que ser tributação o previdencia privar
#
#
# Omni NLP API
#
# predict_intent: Tributacao_Previdencia_Privada
# score: 0.84
# right_intent: Tributacao_Previdencia_Privada
# is it right?: yes
# quantity of right answers: 526
#
#
# Watson Assistent
#
# predict_intent: Tributacao_Previdencia_Privada
# score: 0.91
# right_intent: Tributacao_Previdencia_Privada
# is it right?: yes
# quantity of right answers: 527
#
#
# -------------------------------------------
# sentence: qual o tipo de tributação que o previdencia privar ter
#
#
# Omni NLP API
#
# predict_intent: Tributacao_Previdencia_Privada
# score: 0.84
# right_intent: Tributacao_Previdencia_Privada
# is it right?: yes
# quantity of right answers: 527
#
#
# Watson Assistent
#
# predict_intent: Tributacao_Previdencia_Privada
# score: 0.90
# right_intent: Tributacao_Previdencia_Privada
# is it right?: yes
# quantity of right answers: 528
# -------------------------------------------
# sentence: previdencia privar ter tributação
#
#
# Omni NLP API
#
# predict_intent: Tributacao_Previdencia_Privada
# score: 0.84
# right_intent: Tributacao_Previdencia_Privada
# is it right?: yes
# quantity of right answers: 528
#
#
# Watson Assistent
#
# predict_intent: Tributacao_Previdencia_Privada
# score: 0.92
# right_intent: Tributacao_Previdencia_Privada
# is it right?: yes
# quantity of right answers: 529
#
#
# -------------------------------------------
# sentence: quanto ir receber de adiantamento do décimo terceirar salário
#
#
# Omni NLP API
#
# predict_intent: Valor_13
# score: 0.86
# right_intent: Valor_13
# is it right?: yes
# quantity of right answers: 529
#
#
# Watson Assistent
#
# predict_intent: Valor_13
# score: 0.90
# right_intent: Valor_13
# is it right?: yes
# quantity of right answers: 530
#
#
# -------------------------------------------
# sentence: qual o valor do adiantamento do salário
#
#
# Omni NLP API
#
# predict_intent: Valor_13
# score: 0.46
# right_intent: Valor_13
# is it right?: yes
# quantity of right answers: 530
#
#
# Watson Assistent
#
# predict_intent: Valor_13
# score: 0.78
# right_intent: Valor_13
# is it right?: yes
# quantity of right answers: 531
#
#
# -------------------------------------------
# sentence: quanto ir receber de décimo terceirar salário
#
#
# Omni NLP API
#
# predict_intent: Valor_13
# score: 0.86
# right_intent: Valor_13
# is it right?: yes
# quantity of right answers: 531
#
#
# Watson Assistent
#
# predict_intent: Valor_13
# score: 0.85
# right_intent: Valor_13
# is it right?: yes
# quantity of right answers: 532
#
#
# -------------------------------------------
# sentence: valores gerais
#
#
# Omni NLP API
#
# predict_intent: Valores_Geral
# score: 0.84
# right_intent: Valores_Geral
# is it right?: yes
# quantity of right answers: 532
#
#
# Watson Assistent
#
# predict_intent: Valores_Geral
# score: 1.00
# right_intent: Valores_Geral
# is it right?: yes
# quantity of right answers: 533
#
#
# -------------------------------------------
# sentence: quais ser o novo valorar
#
#
# Omni NLP API
#
# predict_intent: Valores_Geral
# score: 0.83
# right_intent: Valores_Geral
# is it right?: yes
# quantity of right answers: 533
#
#
# Watson Assistent
#
# predict_intent: Valores_Geral
# score: 0.35
# right_intent: Valores_Geral
# is it right?: yes
# quantity of right answers: 534
#
#
# -------------------------------------------
# sentence: quais ser o nosso valorar
#
#
# Omni NLP API
#
# predict_intent: Valores_Geral
# score: 0.81
# right_intent: Valores_Geral
# is it right?: yes
# quantity of right answers: 534
#
#
# Watson Assistent
#
# predict_intent: Valores_Geral
# score: 0.38
# right_intent: Valores_Geral
# is it right?: yes
# quantity of right answers: 535
#
#
# -------------------------------------------
# sentence: valores que o ter
#
#
# Omni NLP API
#
# predict_intent: Valores_Geral
# score: 0.76
# right_intent: Valores_Geral
# is it right?: yes
# quantity of right answers: 535
#
#
# Watson Assistent
#
# predict_intent: Valores_Geral
# score: 0.56
# right_intent: Valores_Geral
# is it right?: yes
# quantity of right answers: 536
#
#
# -------------------------------------------
# sentence: o quantum eu poder gastar o meu jantar durante umar viagem
#
#
# Omni NLP API
#
# predict_intent: Valores_Política
# score: 0.82
# right_intent: Valores_Política
# is it right?: yes
# quantity of right answers: 536
#
#
# Watson Assistent
#
# predict_intent: Valores_Política
# score: 0.93
# right_intent: Valores_Política
# is it right?: yes
# quantity of right answers: 537
#
#
# -------------------------------------------
# sentence: qual o valor limitar de umar jantar conformar o política da yara parir reembolsar
#
#
# Omni NLP API
#
# predict_intent: Valores_Política
# score: 0.82
# right_intent: Valores_Política
# is it right?: yes
# quantity of right answers: 537
#
#
# Watson Assistent
#
# predict_intent: Valores_Política
# score: 0.86
# right_intent: Valores_Política
# is it right?: yes
# quantity of right answers: 538
#
#
# -------------------------------------------
# sentence: ganhei umar jantar ser sobrar umar reunião dos valorar yara ministrar pelar nosso coordenador e o colega daniela prestes comer ser indicar por algum colega acabar ganhar umar jantar o qual eu poder pedir reembolsar posterior logo gostar de saber qual o valor que eu poder gastar grata
#
#
# Omni NLP API
#
# predict_intent: Valores_Política
# score: 0.82
# right_intent: Valores_Política
# is it right?: yes
# quantity of right answers: 538
#
#
# Watson Assistent
#
# predict_intent: Valores_Política
# score: 0.90
# right_intent: Valores_Política
# is it right?: yes
# quantity of right answers: 539
#
#
# -------------------------------------------
# sentence: qual o valor que eu poder usar quando ir comer algo durante umar viagem
#
#
# Omni NLP API
#
# predict_intent: Valores_Política
# score: 0.82
# right_intent: Valores_Política
# is it right?: yes
# quantity of right answers: 539
#
#
# Watson Assistent
#
# predict_intent: Valores_Política
# score: 0.93
# right_intent: Valores_Política
# is it right?: yes
# quantity of right answers: 540
#
#
# -------------------------------------------
# sentence: o que ser viver o valorar da yara
#
#
# Omni NLP API
#
# predict_intent: Valores_Yara
# score: 0.83
# right_intent: Valores_Yara
# is it right?: yes
# quantity of right answers: 540
#
#
# Watson Assistent
#
# predict_intent: Valores_Yara
# score: 0.82
# right_intent: Valores_Yara
# is it right?: yes
# quantity of right answers: 541
#
#
# -------------------------------------------
# sentence: quais ser o valorar da yara
#
#
# Omni NLP API
#
# predict_intent: Valores_Yara
# score: 0.80
# right_intent: Valores_Yara
# is it right?: yes
# quantity of right answers: 541
#
#
# Watson Assistent
#
# predict_intent: Valores_Yara
# score: 0.64
# right_intent: Valores_Yara
# is it right?: yes
# quantity of right answers: 542
#
#
# -------------------------------------------
# sentence: valores yara
#
#
# Omni NLP API
#
# predict_intent: Valores_Yara
# score: 0.84
# right_intent: Valores_Yara
# is it right?: yes
# quantity of right answers: 542
#
#
# Watson Assistent
#
# predict_intent: Valores_Yara
# score: 1.00
# right_intent: Valores_Yara
# is it right?: yes
# quantity of right answers: 543
#
#
# -------------------------------------------
# sentence: Após a Admissão, eu solicito o carro definitivo?
#
#
# Omni NLP API
#
# predict_intent: Data_Entrega_Veiculo_Definitivo
# score: 0.55
# right_intent: Veiculo_Definitivo
# is it right?: no
# quantity of right answers: 542
#
#
# Watson Assistent
#
# predict_intent: Veiculo_Definitivo
# score: 0.66
# right_intent: Veiculo_Definitivo
# is it right?: yes
# quantity of right answers: 544
#
#
# -------------------------------------------
# sentence: Quem pode solicitar carro definitivo?
#
#
# Omni NLP API
#
# predict_intent: Veiculo_Definitivo
# score: 0.45
# right_intent: Veiculo_Definitivo
# is it right?: yes
# quantity of right answers: 543
#
#
# Watson Assistent
#
# predict_intent: Veiculo_Definitivo
# score: 0.66
# right_intent: Veiculo_Definitivo
# is it right?: yes
# quantity of right answers: 545
#
#
# -------------------------------------------
# sentence: em quantum tempo o yara entrar em contato parir buscar o veículo definitivo
#
#
# Omni NLP API
#
# predict_intent: Veiculo_Definitivo
# score: 0.83
# right_intent: Veiculo_Definitivo
# is it right?: yes
# quantity of right answers: 544
#
#
# Watson Assistent
#
# predict_intent: Veiculo_Definitivo
# score: 0.93
# right_intent: Veiculo_Definitivo
# is it right?: yes
# quantity of right answers: 546
#
#
# -------------------------------------------
# sentence: Quantos horas foram para meu banco de horas este mês?
#
#
# Omni NLP API
#
# predict_intent: Verificar_Banco_Horas
# score: 0.88
# right_intent: Verificar_Banco_Horas
# is it right?: yes
# quantity of right answers: 545
#
#
# Watson Assistent
#
# predict_intent: Verificar_Banco_Horas
# score: 0.93
# right_intent: Verificar_Banco_Horas
# is it right?: yes
# quantity of right answers: 547
#
#
# -------------------------------------------
# sentence: onde ver meu histórico de banco de horar
#
#
# Omni NLP API
#
# predict_intent: Verificar_Banco_Horas
# score: 0.87
# right_intent: Verificar_Banco_Horas
# is it right?: yes
# quantity of right answers: 546
#
#
# Watson Assistent
#
# predict_intent: Verificar_Banco_Horas
# score: 0.88
# right_intent: Verificar_Banco_Horas
# is it right?: yes
# quantity of right answers: 548
#
#
# -------------------------------------------
# sentence: onde acesso o detalhe do meu banco de horar
#
#
# Omni NLP API
#
# predict_intent: Verificar_Banco_Horas
# score: 0.88
# right_intent: Verificar_Banco_Horas
# is it right?: yes
# quantity of right answers: 547
#
#
# Watson Assistent
#
# predict_intent: Verificar_Banco_Horas
# score: 0.87
# right_intent: Verificar_Banco_Horas
# is it right?: yes
# quantity of right answers: 549
# -------------------------------------------
# sentence: Por gentileza consultar numeração do cartão ativo
#
#
# Omni NLP API
#
# predict_intent: Verificar_Numero_Vale_RefeicaoAlimentacao
# score: 0.80
# right_intent: Verificar_Numero_Vale_RefeicaoAlimentacao
# is it right?: yes
# quantity of right answers: 548
#
#
# Watson Assistent
#
# predict_intent: Verificar_Numero_Vale_RefeicaoAlimentacao
# score: 0.89
# right_intent: Verificar_Numero_Vale_RefeicaoAlimentacao
# is it right?: yes
# quantity of right answers: 550
#
#
# -------------------------------------------
# sentence: como consultar o numeração do va e vr
#
#
# Omni NLP API
#
# predict_intent: Verificar_Numero_Vale_RefeicaoAlimentacao
# score: 0.87
# right_intent: Verificar_Numero_Vale_RefeicaoAlimentacao
# is it right?: yes
# quantity of right answers: 549
#
#
# Watson Assistent
#
# predict_intent: Verificar_Numero_Vale_RefeicaoAlimentacao
# score: 0.96
# right_intent: Verificar_Numero_Vale_RefeicaoAlimentacao
# is it right?: yes
# quantity of right answers: 551
#
#
# -------------------------------------------
# sentence: como conseguir o número do cartão vale alimentação vale refeição
#
#
# Omni NLP API
#
# predict_intent: Verificar_Numero_Vale_RefeicaoAlimentacao
# score: 0.87
# right_intent: Verificar_Numero_Vale_RefeicaoAlimentacao
# is it right?: yes
# quantity of right answers: 550
#
#
# Watson Assistent
#
# predict_intent: Verificar_Numero_Vale_RefeicaoAlimentacao
# score: 1.00
# right_intent: Verificar_Numero_Vale_RefeicaoAlimentacao
# is it right?: yes
# quantity of right answers: 552
#
#
# -------------------------------------------
# sentence: gostaria de confirmar se o gestor lançar meu féria
#
#
# Omni NLP API
#
# predict_intent: Verificar_Status_Ferias
# score: 0.51
# right_intent: Verificar_Status_Ferias
# is it right?: yes
# quantity of right answers: 551
#
#
# Watson Assistent
#
# predict_intent: Status_Ferias_e_Programacao_Sem_Confirmação
# score: 0.88
# right_intent: Verificar_Status_Ferias
# is it right?: no
# quantity of right answers: 552
#
#
# -------------------------------------------
# sentence: onde ver meu programação de féria
#
#
# Omni NLP API
#
# predict_intent: Agendamento_Alteracao_Ferias
# score: 0.41
# right_intent: Verificar_Status_Ferias
# is it right?: no
# quantity of right answers: 551
#
#
# Watson Assistent
#
# predict_intent: Status_Ferias_e_Programacao_Sem_Confirmação
# score: 0.59
# right_intent: Verificar_Status_Ferias
# is it right?: no
# quantity of right answers: 552
#
#
# -------------------------------------------
# sentence: necessito saber qual o período de féria que ter programar e o prazo máximo que ter parir desfrutar
#
#
# Omni NLP API
#
# predict_intent: Verificar_Status_Ferias
# score: 0.77
# right_intent: Verificar_Status_Ferias
# is it right?: yes
# quantity of right answers: 552
#
#
# Watson Assistent
#
# predict_intent: Verificar_Status_Ferias
# score: 0.56
# right_intent: Verificar_Status_Ferias
# is it right?: yes
# quantity of right answers: 553
#
#
# -------------------------------------------
# sentence: Quero a visão geral da previdencia privada
#
#
# Omni NLP API
#
# predict_intent: Visao_Geral_Previdencia_Privada
# score: 0.35
# right_intent: Visao_Geral_Previdencia_Privada
# is it right?: yes
# quantity of right answers: 553
#
#
# Watson Assistent
#
# predict_intent: Nossa_Visao
# score: 0.52
# right_intent: Visao_Geral_Previdencia_Privada
# is it right?: no
# quantity of right answers: 553
#
#
# -------------------------------------------
# sentence: o que planar de previdência privar
#
#
# Omni NLP API
#
# predict_intent: Visao_Geral_Previdencia_Privada
# score: 0.89
# right_intent: Visao_Geral_Previdencia_Privada
# is it right?: yes
# quantity of right answers: 554
#
#
# Watson Assistent
#
# predict_intent: Visao_Geral_Previdencia_Privada
# score: 0.74
# right_intent: Visao_Geral_Previdencia_Privada
# is it right?: yes
# quantity of right answers: 554
#
#
# -------------------------------------------
# sentence: me dar umar visão geral de comer funcionar o planar de previdência privar
#
#
# Omni NLP API
#
# predict_intent: Visao_Geral_Previdencia_Privada
# score: 0.85
# right_intent: Visao_Geral_Previdencia_Privada
# is it right?: yes
# quantity of right answers: 555
#
#
# Watson Assistent
#
# predict_intent: Visao_Geral_Previdencia_Privada
# score: 0.83
# right_intent: Visao_Geral_Previdencia_Privada
# is it right?: yes
# quantity of right answers: 555
#
#
# -------------------------------------------
# sentence: nosso terreno estar ser invadir pelar vizinhar da unidade o que fazer
#
#
# Omni NLP API
#
# predict_intent: Vizinho_Invadindo_Terreno
# score: 0.84
# right_intent: Vizinho_Invadindo_Terreno
# is it right?: yes
# quantity of right answers: 556
#
#
# Watson Assistent
#
# predict_intent: Vizinho_Invadindo_Terreno
# score: 0.80
# right_intent: Vizinho_Invadindo_Terreno
# is it right?: yes
# quantity of right answers: 556
#
#
# -------------------------------------------
# sentence: a unidade estar ser invadir quem poder ajudar
#
#
# Omni NLP API
#
# predict_intent: Vizinho_Invadindo_Terreno
# score: 0.83
# right_intent: Vizinho_Invadindo_Terreno
# is it right?: yes
# quantity of right answers: 557
#
#
# Watson Assistent
#
# predict_intent: Vizinho_Invadindo_Terreno
# score: 0.76
# right_intent: Vizinho_Invadindo_Terreno
# is it right?: yes
# quantity of right answers: 557
#
#
# -------------------------------------------
# sentence: estamos com problema com vizinho da unidade com quem poder falar
#
#
# Omni NLP API
#
# predict_intent: Vizinho_Invadindo_Terreno
# score: 0.85
# right_intent: Vizinho_Invadindo_Terreno
# is it right?: yes
# quantity of right answers: 558
#
#
# Watson Assistent
#
# predict_intent: Vizinho_Invadindo_Terreno
# score: 0.94
# right_intent: Vizinho_Invadindo_Terreno
# is it right?: yes
# quantity of right answers: 558
#
#
# -------------------------------------------
# sentence: o vizinhar da unidade estar invadir umar partir do imóvel da yara o que fazer
#
#
# Omni NLP API
#
# predict_intent: Vizinho_Invadindo_Terreno
# score: 0.85
# right_intent: Vizinho_Invadindo_Terreno
# is it right?: yes
# quantity of right answers: 559
#
#
# Watson Assistent
#
# predict_intent: Vizinho_Invadindo_Terreno
# score: 0.85
# right_intent: Vizinho_Invadindo_Terreno
# is it right?: yes
# quantity of right answers: 559
#
#
# -------------------------------------------
#
# Total of questions: 692
#
# Omni NLP API
#
# Total of right answers: 559
# Accuracy: 81.0
#
# Watson Assistent
#
# Total of right answers: 559
# Accuracy: 81.0
