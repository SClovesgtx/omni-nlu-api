# %% [markdown]
# # Omni NLP API

# %% [markdown]
# ### 1º - Adicionar Conteúdo para Treino

# %%
import os

default_path = "/home/cloves/Desktop/omni_nlp_api"
os.chdir(default_path)

# %%
# LER DADOS
import json

file = open('/home/cloves/Downloads/skill-COE_YARA_PRD.json', "r") 
workspace = json.load(file)
workspace["intents"][-1]
# Out:
# {'intent': 'Vizinho_Invadindo_Terreno',
#  'examples': [{'text': 'A unidade está sendo invadida. Quem pode ajudar?'},
#   {'text': 'Estamos com problema com vizinhos da unidade. Com quem posso falar?'},
#   {'text': 'Nosso terreno está sendo invadido pelo vizinho da unidade. O que fazer?'},
#   {'text': 'O vizinho da unidade está invadindo uma parte do imóvel da Yara. O que fazer?'}],
#  'description': ''}

# %% [markdown]
# ###### Entidades

# %%
import requests

url_api = "http://0.0.0.0:5000/"
params = {'workspace_id': 'dc1e7b3d-9137-4a20-a99c-d0d2029ef170'}
end_point = "nlp_model/entities/"

for entity in workspace["entities"]:
    if "sys" not in entity["entity"].split("-"):
        r = requests.post(url_api+end_point, params=params, json=entity)
        r = r.json()
        if r["result"] == "created":
            print("Entity %s was created with id %s"%(entity["entity"],r["_id"]))
        else:
            print("Entity %s was not created"%entity["entity"])
# Out:
# Entity Actions was created with id fvEbCHgBzcyRzUfgHNGh
# Entity Assistencias was created with id f_EbCHgBzcyRzUfgHNH0
# Entity CEP was created with id gPEbCHgBzcyRzUfgHdET
# Entity ContactInfo was created with id gfEbCHgBzcyRzUfgHdE1
# Entity CulturaPlatacao was created with id gvEbCHgBzcyRzUfgHdFT
# Entity DataProgramada was created with id g_EbCHgBzcyRzUfgHdF2
# Entity Datas was created with id hPEbCHgBzcyRzUfgHdGX
# Entity DecimoTerceiro was created with id hfEbCHgBzcyRzUfgHdG3
# Entity DetalheAgendamentoFerias was created with id hvEbCHgBzcyRzUfgHdHa
# Entity DetalheCartaoAlimentacaoRefeicao was created with id h_EbCHgBzcyRzUfgHtEB
# Entity DetalheDesconto was created with id iPEbCHgBzcyRzUfgHtEf
# Entity EntedidadesGerais was created with id ifEbCHgBzcyRzUfgHtFE
# Entity EntidadeGeral was created with id ivEbCHgBzcyRzUfgHtFl
# Entity ErroMercadoEletronico was created with id i_EbCHgBzcyRzUfgHtGA
# Entity hash was created with id jPEbCHgBzcyRzUfgHtGh
# Entity Institucional was created with id jfEbCHgBzcyRzUfgHtHW
# Entity JornadasYara was created with id jvEbCHgBzcyRzUfgHtH5
# Entity LocalizacaoPlantacao was created with id j_EbCHgBzcyRzUfgH9EX
# Entity Previdencia was created with id kPEbCHgBzcyRzUfgH9E0
# Entity Questao was created with id kfEbCHgBzcyRzUfgH9FT
# Entity ReceberCancelarAdiantamentoSalarial was created with id kvEbCHgBzcyRzUfgH9Fv
# Entity SimNao was created with id k_EbCHgBzcyRzUfgH9Ga
# Entity Tema was created with id lPEbCHgBzcyRzUfgH9G6
# Entity ValidaWhats was created with id lfEbCHgBzcyRzUfgH9Hd

# %% [markdown]
# ##### Intenções

# %%
end_point = "nlp_model/intents/"

for intent in workspace["intents"]:
    r = requests.post(url_api+end_point, params=params, json=intent)
    r = r.json()
    if r["result"] == "created":
        print("Intent %s was created with id %s"%(intent["intent"],r["_id"]))
    else:
        print("Intent %s was not created"%intent["intent"])
# Out:
# Intent Abono was created with id lvEbCHgBzcyRzUfgstGH
# Intent Abrir_Chamado_Salario was created with id l_EbCHgBzcyRzUfgstGo
# Intent Acessar_CMS was created with id mPEbCHgBzcyRzUfgstHJ
# Intent Acessar_Concur was created with id mfEbCHgBzcyRzUfgstHu
# Intent Acessar_MercadoEletronico was created with id mvEbCHgBzcyRzUfgs9EQ
# Intent Acessar_Painel_Colaborador was created with id m_EbCHgBzcyRzUfgs9Es
# Intent Acessar_SAP_MercadoEletronico was created with id nPEbCHgBzcyRzUfgs9FX
# Intent Acionista_Yara_GICS was created with id nfEbCHgBzcyRzUfgs9GP
# Intent Acompanhar_Pedido_MercadoEletronico was created with id nvEbCHgBzcyRzUfgs9Gs
# Intent Acompanhar_Saldo_Previdencia_Privada was created with id n_EbCHgBzcyRzUfgs9HI
# Intent Acompanhar_Solicitacao was created with id oPEbCHgBzcyRzUfgs9Ht
# Intent Aderir_Beneficio_Previdencia_Privada was created with id ofEbCHgBzcyRzUfgtNEM
# Intent Adiantamento_Duplicado was created with id ovEbCHgBzcyRzUfgtNEo
# Intent Adiantamento_e_QuandoReceber_13_Salario was created with id o_EbCHgBzcyRzUfgtNFL
# Intent Aditivar_Contrato was created with id pPEbCHgBzcyRzUfgtNFo
# Intent Agendamento_Alteracao_Ferias was created with id pfEbCHgBzcyRzUfgtNGM
# Intent Agilidade_Negocios was created with id pvEbCHgBzcyRzUfgtNGw
# Intent Ajuda_Manual_CMS was created with id p_EbCHgBzcyRzUfgtNHT
# Intent Ajustar_Ponto was created with id qPEbCHgBzcyRzUfgtNH0
# Intent Ajuste_Informacao_Convenio was created with id qfEbCHgBzcyRzUfgtdEc
# Intent Alteracao_Beneficios_Previdencia was created with id qvEbCHgBzcyRzUfgtdE4
# Intent Alteracao_CargoSalario was created with id q_EbCHgBzcyRzUfgtdFY
# Intent Alteracao_CC was created with id rPEbCHgBzcyRzUfgtdF3
# Intent Alteração_ContratoProrrogacao was created with id rfEbCHgBzcyRzUfgtdGW
# Intent Alteração_Gestor was created with id rvEbCHgBzcyRzUfgtdG0
# Intent Alterar_Aprovador was created with id r_EbCHgBzcyRzUfgtdHT
# Intent Alterar_Cargo was created with id sPEbCHgBzcyRzUfgtdH-
# Intent Alterar_Centro_Custo was created with id sfEbCHgBzcyRzUfgttEb
# Intent Alterar_Conta_Pagamento was created with id svEbCHgBzcyRzUfgttE7
# Intent Alterar_Contrato was created with id s_EbCHgBzcyRzUfgttFZ
# Intent Alterar_EnquadramentoMerito was created with id tPEbCHgBzcyRzUfgttF2
# Intent Alterar_Posicao was created with id tfEbCHgBzcyRzUfgttGT
# Intent Alterar_Promocao was created with id tvEbCHgBzcyRzUfgttG1
# Intent Alterar_Tipo_Registro_Ponto was created with id t_EbCHgBzcyRzUfgttHa
# Intent Alterar_Vale_RefeicaoAlimentacao was created with id uPEbCHgBzcyRzUfgttH1
# Intent Ambicao_CoE was created with id ufEbCHgBzcyRzUfgt9EV
# Intent Ambiente_ConfiancaAgradavel was created with id uvEbCHgBzcyRzUfgt9Fa
# Intent Apresentacao_Institucional was created with id u_EbCHgBzcyRzUfgt9GP
# Intent Aprovações_YPP was created with id vPEbCHgBzcyRzUfgt9G7
# Intent Aprovar_Solicitacao_Pendente_Ponto was created with id vfEbCHgBzcyRzUfgt9Hb
# Intent Arquivar_Contrato was created with id vvEbCHgBzcyRzUfgt9H3
# Intent Assinar_Contrato was created with id v_EbCHgBzcyRzUfguNET
# Intent Assinar_Digitalmente_Contrato was created with id wPEbCHgBzcyRzUfguNEv
# Intent Bem_Estar was created with id wfEbCHgBzcyRzUfguNFK
# Intent Bonus_Mobilidade was created with id wvEbCHgBzcyRzUfguNFm
# Intent Bot_Capabilities was created with id w_EbCHgBzcyRzUfguNGK
# Intent Branding was created with id xPEbCHgBzcyRzUfguNGn
# Intent Cadastro_Concur was created with id xfEbCHgBzcyRzUfguNHD
# Intent Canais_Atendimentos_CoE was created with id xvEbCHgBzcyRzUfguNHi
# Intent Cancelar_Previdencia was created with id x_EbCHgBzcyRzUfgudED
# Intent Cartao_Bloqueado_SenhaInvalida was created with id yPEbCHgBzcyRzUfgudEf
# Intent Cartao_Cancelado was created with id yfEbCHgBzcyRzUfgudE8
# Intent Cartao_Clonado_Cambial was created with id yvEbCHgBzcyRzUfgudFj
# Intent Colaboracao_CoE was created with id y_EbCHgBzcyRzUfgudGB
# Intent Comprovant_CNPJ was created with id zPEbCHgBzcyRzUfgudGc
# Intent Comprovante_Pagamento_Juridico was created with id zfEbCHgBzcyRzUfgudG9
# Intent Concur_Cursos was created with id zvEbCHgBzcyRzUfgudHb
# Intent Concur_Delegacao was created with id z_EbCHgBzcyRzUfgudH_
# Intent Consultar_Procuracao was created with id 0PEbCHgBzcyRzUfgutEb
# Intent Conta_Bancaria was created with id 0fEbCHgBzcyRzUfgutE_
# Intent Contato_Operadora_Previdencia_Privada was created with id 0vEbCHgBzcyRzUfgutFe
# Intent Contracheque_Recebido_Sem_Constar_Conta was created with id 0_EbCHgBzcyRzUfgutF8
# Intent Contracheque_Sem_Constar_Dependente_IRRF was created with id 1PEbCHgBzcyRzUfgutHJ
# Intent Contrato_Aprovado_Proximo_Passo was created with id 1fEbCHgBzcyRzUfgutHm
# Intent Contrato_Devolvido_Juridico was created with id 1vEbCHgBzcyRzUfgu9EL
# Intent Contrato_Social_ou_Estatuto_Empresa was created with id 1_EbCHgBzcyRzUfgu9Ey
# Intent Contribuicoes_Previdencia_Privada was created with id 2PEbCHgBzcyRzUfgu9FV
# Intent Controladoria_Juridica was created with id 2fEbCHgBzcyRzUfgu9F3
# Intent Criar_Posição was created with id 2vEbCHgBzcyRzUfgu9GU
# Intent Curiosidade_CoE was created with id 2_EbCHgBzcyRzUfgu9Gt
# Intent Custo_Movimentação_Estado was created with id 3PEbCHgBzcyRzUfgu9HK
# Intent Data_Entrega_Veiculo_Definitivo was created with id 3fEbCHgBzcyRzUfgu9Hq
# Intent Data_Envio_Vale_RefeicaoAlimentacao was created with id 3vEbCHgBzcyRzUfgvNEI
# Intent Data_Limite_Ferias was created with id 3_EbCHgBzcyRzUfgvNEj
# Intent Data_Pagamento_Salario was created with id 4PEbCHgBzcyRzUfgvNFD
# Intent Data_Pagamento_Vale_RefeicaoAlimentação was created with id 4fEbCHgBzcyRzUfgvNFh
# Intent Desconto_em_Folha was created with id 4vEbCHgBzcyRzUfgvNGA
# Intent Despesa_Pessoal_Marcado_Relatorio_Concur was created with id 4_EbCHgBzcyRzUfgvNGe
# Intent Detalhe_Sobre_Desconto was created with id 5PEbCHgBzcyRzUfgvNHG
# Intent Devolucao_Veiculo was created with id 5fEbCHgBzcyRzUfgvNHi
# Intent Diferenca_Previdencia_Privada was created with id 5vEbCHgBzcyRzUfgvNH8
# Intent Direcao_Defensiva was created with id 5_EbCHgBzcyRzUfgvdEd
# Intent Direito_ao_13 was created with id 6PEbCHgBzcyRzUfgvdE8
# Intent Divisao_Ferias was created with id 6fEbCHgBzcyRzUfgvdFV
# Intent Documento_Oficial_Justica was created with id 6vEbCHgBzcyRzUfgvdF0
# Intent Documento_Sem_Carimbo_Juridico was created with id 6_EbCHgBzcyRzUfgvdGU
# Intent Download_Aplicativo_Convenio was created with id 7PEbCHgBzcyRzUfgvdGw
# Intent Duvida_Formularo_Adesao_Previdencia was created with id 7fEbCHgBzcyRzUfgvdHN
# Intent Duvidas_Benefícios was created with id 7vEbCHgBzcyRzUfgvdHs
# Intent Duvidas_Celular_Corporativo was created with id 7_EbCHgBzcyRzUfgvtEu
# Intent Duvidas_Despesas was created with id 8PEbCHgBzcyRzUfgvtFJ
# Intent Duvidas_Funcoes_Cartao was created with id 8fEbCHgBzcyRzUfgvtFu
# Intent Duvidas_Outro_CC was created with id 8vEbCHgBzcyRzUfgvtGJ
# Intent Elegibilidade_Previdencia_Privada was created with id 8_EbCHgBzcyRzUfgvtGj
# Intent Emissoes_Cartao was created with id 9PEbCHgBzcyRzUfgvtG9
# Intent Empresa_Seguro_Frota was created with id 9fEbCHgBzcyRzUfgvtHb
# Intent Erros_MercadoEletronico was created with id 9vEbCHgBzcyRzUfgvtH2
# Intent Espirito_Servir was created with id 9_EbCHgBzcyRzUfgv9EY
# Intent Esquecer_Senha_Vale_RefeicaoAlimentacao was created with id -PEbCHgBzcyRzUfgv9E7
# Intent Estrategia_Aprovar was created with id -fEbCHgBzcyRzUfgv9Fc
# Intent Exclusoes_Concur was created with id -vEbCHgBzcyRzUfgv9F6
# Intent Ex_Colaborador_Resgate_Previdencia was created with id -_EbCHgBzcyRzUfgv9GY
# Intent Extensao_Contrato was created with id _PEbCHgBzcyRzUfgv9G-
# Intent Extrair_Relatorio_Ponto_Todos_Colaboradores was created with id _fEbCHgBzcyRzUfgv9Hc
# Intent Extrato_Plano was created with id _vEbCHgBzcyRzUfgv9H8
# Intent Fazer_Contrato was created with id __EbCHgBzcyRzUfgwNEZ
# Intent Foco_Cliente was created with id APEbCHgBzcyRzUfgwNI7
# Intent Fornecedor_ME was created with id AfEbCHgBzcyRzUfgwNJY
# Intent Funcoes_Cartao_Corporativo was created with id AvEbCHgBzcyRzUfgwNJ0
# Intent Fundacao_Valores was created with id A_EbCHgBzcyRzUfgwNKT
# Intent General_Ending was created with id BPEbCHgBzcyRzUfgwNKy
# Intent General_Greetings was created with id BfEbCHgBzcyRzUfgwNLN
# Intent General_Negative_Feedback was created with id BvEbCHgBzcyRzUfgwNL1
# Intent General_Positive_Feedback was created with id B_EbCHgBzcyRzUfgwdIg
# Intent Gestor_Responsavel_Departamento_Juridico was created with id CPEbCHgBzcyRzUfgwdI9
# Intent Hora_Extra was created with id CfEbCHgBzcyRzUfgwdJc
# Intent Imposto_Renda_Previdencia_Privada was created with id CvEbCHgBzcyRzUfgwdJ3
# Intent Inativar_Posição was created with id C_EbCHgBzcyRzUfgwdKV
# Intent Incluir_Colaborador_Convenio was created with id DPEbCHgBzcyRzUfgwdK7
# Intent Incluir_Dependente_Plano_Saude was created with id DfEbCHgBzcyRzUfgwdLX
# Intent IncluirRemover_Colaborador was created with id DvEbCHgBzcyRzUfgwdLy
# Intent Inconformidades_Legais was created with id D_EbCHgBzcyRzUfgwtIR
# Intent Info_Concur_SAP was created with id EPEbCHgBzcyRzUfgwtIt
# Intent Informacao_Geral_Sistemas was created with id EfEbCHgBzcyRzUfgwtJJ
# Intent Informacoes_Relatorio_Aberto was created with id EvEbCHgBzcyRzUfgwtJm
# Intent Informacoes_Relatorio_Gerais was created with id E_EbCHgBzcyRzUfgwtKC
# Intent Informacoes_Relatorio_Nao_Aprovado was created with id FPEbCHgBzcyRzUfgwtKi
# Intent Licenca_Mais_Ferias was created with id FfEbCHgBzcyRzUfgwtLB
# Intent Localizar_Veiculo was created with id FvEbCHgBzcyRzUfgwtLe
# Intent Manutencoes was created with id F_EbCHgBzcyRzUfgwtL5
# Intent Marcar_Falta_Colaborador was created with id GPEbCHgBzcyRzUfgw9IY
# Intent ME_Conta_Contábil was created with id GfEbCHgBzcyRzUfgw9Jd
# Intent Mistura_Cartao_Reembolso was created with id GvEbCHgBzcyRzUfgw9KW
# Intent Modelo_Contrato was created with id G_EbCHgBzcyRzUfgw9K_
# Intent Nossa_Missao was created with id HPEbCHgBzcyRzUfgw9Le
# Intent Nossa_Visao was created with id HfEbCHgBzcyRzUfgxNIE
# Intent Novo_Colaborador was created with id HvEbCHgBzcyRzUfgxNI6
# Intent Novo_Portal_CoE_Gostou was created with id H_EbCHgBzcyRzUfgxNJw
# Intent Novo_Portal_CoE_NãoGostou was created with id IPEbCHgBzcyRzUfgxNKd
# Intent Orientacoes_PTP was created with id IfEbCHgBzcyRzUfgxNK_
# Intent Pagamento_Ferias was created with id IvEbCHgBzcyRzUfgxNLh
# Intent Pagamento_Licenca_Maternidade was created with id I_EbCHgBzcyRzUfgxdIB
# Intent Periodo_Amamentacao_Licenca_Maternidade was created with id JPEbCHgBzcyRzUfgxdIf
# Intent Periodo_Licenca_Maternidade was created with id JfEbCHgBzcyRzUfgxdI-
# Intent Pessoas_Focadas_Excelencia was created with id JvEbCHgBzcyRzUfgxdJl
# Intent Pessoas_Responsaveis_Juridico was created with id J_EbCHgBzcyRzUfgxdKI
# Intent Ponto_Colaborar_Não_Aparece was created with id KPEbCHgBzcyRzUfgxdKr
# Intent Prazo_Ajuste_Ponto was created with id KfEbCHgBzcyRzUfgxdLN
# Intent Prazo_Atendimento_Juridico was created with id KvEbCHgBzcyRzUfgxdLr
# Intent Prazo_Juridico_Responder was created with id K_EbCHgBzcyRzUfgxtIH
# Intent Previdencia_Privada_Desconto was created with id LPEbCHgBzcyRzUfgxtIi
# Intent Priorizar_Criacao_Pedidos was created with id LfEbCHgBzcyRzUfgxtJB
# Intent Procedimento_Contrato_Assinado was created with id LvEbCHgBzcyRzUfgxtJe
# Intent Procedimento_Recusado_Convenio was created with id L_EbCHgBzcyRzUfgxtJ6
# Intent Procedimentos_Concur was created with id MPEbCHgBzcyRzUfgxtKc
# Intent Procedimentos_Convenio was created with id MfEbCHgBzcyRzUfgxtK4
# Intent Proposito_CoE was created with id MvEbCHgBzcyRzUfgxtLV
# Intent Proposta_Comercial_Juridico was created with id M_EbCHgBzcyRzUfgxtL1
# Intent Proposta_Rubricada was created with id NPEbCHgBzcyRzUfgx9Ig
# Intent Prorrogacao_Licenca_Maternidade was created with id NfEbCHgBzcyRzUfgx9JC
# Intent ReceberCancelar_Adiantamento_Salarial was created with id NvEbCHgBzcyRzUfgx9Jf
# Intent Receber_Cartao_Convenio was created with id N_EbCHgBzcyRzUfgx9J-
# Intent Receber_Oficio was created with id OPEbCHgBzcyRzUfgx9Kc
# Intent Recebimento_Beneficio_Previdencia_Privada was created with id OfEbCHgBzcyRzUfgx9K6
# Intent Reconhecer_Firma_Contrato was created with id OvEbCHgBzcyRzUfgx9LY
# Intent Reembolso_Janta_HomeOffice was created with id O_EbCHgBzcyRzUfgx9L0
# Intent Reembolso_Sem_Cobertura_Convenio was created with id PPEbCHgBzcyRzUfgyNIa
# Intent Relatorio_Inconsistencias_Ponto was created with id PfEbCHgBzcyRzUfgyNJQ
# Intent Relatorio_Old was created with id PvEbCHgBzcyRzUfgyNJ5
# Intent Relatorio_Programacao_Ferias was created with id P_EbCHgBzcyRzUfgyNKk
# Intent Renovacao_Contrato_Veiculo was created with id QPEbCHgBzcyRzUfgyNLL
# Intent Repassar_Gestao_Colaborador was created with id QfEbCHgBzcyRzUfgyNLu
# Intent Representantes_Legais was created with id QvEbCHgBzcyRzUfgydIP
# Intent Resgatar_Previdencia was created with id Q_EbCHgBzcyRzUfgydIu
# Intent Responsabilidade_CoE was created with id RPEbCHgBzcyRzUfgydJM
# Intent Retorno_Contrato_CMS_Não_Entendi was created with id RfEbCHgBzcyRzUfgydJp
# Intent SegundaVia_Cartao_Ticketlog was created with id RvEbCHgBzcyRzUfgydKG
# Intent SegundaVia_Vale_RefeicaoAlimentacao was created with id R_EbCHgBzcyRzUfgydKq
# Intent Solicitacao_Aprovada_Proximo_Passo was created with id SPEbCHgBzcyRzUfgydLJ
# Intent Solicitacao_Negada_Documento_Aprovado was created with id SfEbCHgBzcyRzUfgydLn
# Intent Solicitar_Cartao_Combustivel was created with id SvEbCHgBzcyRzUfgytIF
# Intent Solicitar_Holerite was created with id S_EbCHgBzcyRzUfgytIl
# Intent Solicitar_IRPF was created with id TPEbCHgBzcyRzUfgytJE
# Intent Solicitar_Ponto_Pos_FechamentoReembolso was created with id TfEbCHgBzcyRzUfgytJj
# Intent Solicitar_Procuracao was created with id TvEbCHgBzcyRzUfgytKI
# Intent Solicitar_Troca_Veiculo was created with id T_EbCHgBzcyRzUfgytKu
# Intent Status_Ferias_e_Programacao_Sem_Confirmação was created with id UPEbCHgBzcyRzUfgytLW
# Intent Status_Item_Cancelado was created with id UfEbCHgBzcyRzUfgy9II
# Intent Tecnologia_Facilitadora_Eficiencia was created with id UvEbCHgBzcyRzUfgy9I6
# Intent Testemunha_Contrato was created with id U_EbCHgBzcyRzUfgy9Jc
# Intent Tipos_Reembolso was created with id VPEbCHgBzcyRzUfgy9KD
# Intent Transferencia_Veiculo was created with id VfEbCHgBzcyRzUfgy9Kk
# Intent Transferir_Colaborador_Filial was created with id VvEbCHgBzcyRzUfgy9LK
# Intent Treinamento_Juridico was created with id V_EbCHgBzcyRzUfgy9Ln
# Intent Tributacao_Previdencia_Privada was created with id WPEbCHgBzcyRzUfgzNID
# Intent TrocaDevolucao_Ticketlog was created with id WfEbCHgBzcyRzUfgzNIg
# Intent Usuario_Invalido_NaoCadastrado was created with id WvEbCHgBzcyRzUfgzNJE
# Intent Valor_13 was created with id W_EbCHgBzcyRzUfgzNJi
# Intent Valor_Depositado_Vale_RefeicaoAlimentacao_Errado was created with id XPEbCHgBzcyRzUfgzNJ_
# Intent Valores_Geral was created with id XfEbCHgBzcyRzUfgzNKd
# Intent Valores_Política was created with id XvEbCHgBzcyRzUfgzNLC
# Intent Valores_Yara was created with id X_EbCHgBzcyRzUfgzNLp
# Intent Veiculo_Definitivo was created with id YPEbCHgBzcyRzUfgzdIH
# Intent Veiculo_Disponiveis was created with id YfEbCHgBzcyRzUfgzdIq
# Intent Veiculo_Problema was created with id YvEbCHgBzcyRzUfgzdJb
# Intent Veiculo_Provisorio was created with id Y_EbCHgBzcyRzUfgzdJ_
# Intent Verificar_Banco_Horas was created with id ZPEbCHgBzcyRzUfgzdKh
# Intent Verificar_Colaborador_Convenio was created with id ZfEbCHgBzcyRzUfgzdLB
# Intent Verificar_Historico_Previdencia was created with id ZvEbCHgBzcyRzUfgzdLf
# Intent Verificar_Numero_Carteirinha_Convenio was created with id Z_EbCHgBzcyRzUfgzdL7
# Intent Verificar_Numero_Vale_RefeicaoAlimentacao was created with id aPEbCHgBzcyRzUfgztIY
# Intent Verificar_Status_Ferias was created with id afEbCHgBzcyRzUfgztI3
# Intent Verificar_Valor_Locacao_Veiculo was created with id avEbCHgBzcyRzUfgztJU
# Intent Visao_Geral_Previdencia_Privada was created with id a_EbCHgBzcyRzUfgztJw
# Intent Vizinho_Invadindo_Terreno was created with id bPEbCHgBzcyRzUfgztKM

# %%
r = requests.get(url_api+end_point, params={"workspace_id": "dc1e7b3d-9137-4a20-a99c-d0d2029ef170",
                                            "intent_name": "Relatorio_Inconsistencias_Ponto"})
r = r.json()
r
# Out:
# {'_id': 'PfEbCHgBzcyRzUfgyNJQ',
#  '_index': 'nlp_model-dc1e7b3d-9137-4a20-a99c-d0d2029ef170-06032021151307',
#  '_score': 4.9698133,
#  '_source': {'description': '',
#   'doc_type': 'intent',
#   'examples': [{'text': 'Como faço para ver os erros do meu ponto?'},
#    {'text': 'Devo abrir um chamado para solicitar um relatório de inconsistências do ponto?'},
#    {'text': 'Gostaria de saber quantas inconsistências de ponto existe na minha equipe?'},
#    {'text': 'Necessito de um relatório de inconsistências, onde posso obter?'},
#    {'text': 'preciso de um relatorio de inconsistencias do ponto dos meus colaboradores, onde eu acho isso?'},
#    {'text': 'Quantas marcações ímpares há na minha equipe?'}],
#   'intent': 'Relatorio_Inconsistencias_Ponto'},
#  '_type': '_doc'}

# %%
r = requests.get(url_api+end_point, params={"workspace_id": "dc1e7b3d-9137-4a20-a99c-d0d2029ef170",
                                            "intent_name": "Relatorio_Inconsistencias_Ponto"})
r = r.json()
r
# Out:
# {'_id': 'OlaxuncBF8yx_zbJF05a',
#  '_index': 'nlp_model-dc1e7b3d-9137-4a20-a99c-d0d2029ef170-19022021142434',
#  '_score': 5.2747073,
#  '_source': {'artificial_examples': [{'constructed': 'devo abrir um chamar parir solicitar um relatório de inconsistência do pontar',
#     'original': 'Devo abrir um chamado para solicitar um relatório de inconsistências do ponto?'},
#    {'constructed': 'necessito de um relatório de inconsistência onde poder obter',
#     'original': 'Necessito de um relatório de inconsistências, onde posso obter?'}],
#   'description': '',
#   'doc_type': 'intent',
#   'examples': [{'text': 'Como faço para ver os erros do meu ponto?'},
#    {'text': 'Devo abrir um chamado para solicitar um relatório de inconsistências do ponto?'},
#    {'text': 'Gostaria de saber quantas inconsistências de ponto existe na minha equipe?'},
#    {'text': 'Necessito de um relatório de inconsistências, onde posso obter?'},
#    {'text': 'preciso de um relatorio de inconsistencias do ponto dos meus colaboradores, onde eu acho isso?'},
#    {'text': 'Quantas marcações ímpares há na minha equipe?'}],
#   'for_test': [{'text': 'Quantas marcações ímpares há na minha equipe?'},
#    {'text': 'devo abrir um chamar parir solicitar um relatório de inconsistência do pontar'},
#    {'text': 'necessito de um relatório de inconsistência onde poder obter'}],
#   'for_train': [{'text': 'Como faço para ver os erros do meu ponto?'},
#    {'text': 'Devo abrir um chamado para solicitar um relatório de inconsistências do ponto?'},
#    {'text': 'Gostaria de saber quantas inconsistências de ponto existe na minha equipe?'},
#    {'text': 'Necessito de um relatório de inconsistências, onde posso obter?'},
#    {'text': 'preciso de um relatorio de inconsistencias do ponto dos meus colaboradores, onde eu acho isso?'}],
#   'intent': 'Relatorio_Inconsistencias_Ponto'},
#  '_type': '_doc'}

# %% [markdown]
# # Watson Assistant

# %% [markdown]
# #### 1º - Se Conectar ao Watson

# %%
import os
import json
from ibm_watson import AssistantV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

API_KEY = "nA36HqlqQkQSDf0EywIeYGPl0qI_nNvLqvBUI_zhhUmR" # os.environ['API_KEY']
SERVICE_URL = "https://api.us-south.assistant.watson.cloud.ibm.com/instances/12c017ac-1bb4-4364-8493-9cc9ba98aa26" # os.environ['SERVICE_URL']
# ASSISTANT_ID = "11cdca6b-e73e-48fc-8523-13d9ee68df8b" # os.environ['ASSISTANT_ID']

# %% [markdown]
# #### 2º - Criar Skill

# %%
# criar skill
authenticator = IAMAuthenticator(API_KEY)
assistant = AssistantV1(
    version='2020-04-01',
    authenticator = authenticator
)

# %%
def create_skill_for_test():
    response=assistant.create_workspace(
        name='teste-com-api-omni-06-03-2021',
        language="pt-br",
        description='Skill para teste de acurácia'
    ).get_result()
    print(json.dumps(response, indent=2))
    return response["workspace_id"]
    
skill_id_test = create_skill_for_test()
# Out:
# {
#   "name": "teste-com-api-omni-06-03-2021",
#   "language": "pt-br",
#   "metadata": {
#     "api_version": {
#       "major_version": "v1",
#       "minor_version": "2020-04-01"
#     }
#   },
#   "description": "Skill para teste de acur\u00e1cia",
#   "workspace_id": "4f0e89bb-cdb6-4ad5-88c1-d080f95a04e7",
#   "learning_opt_out": false
# }

# %% [markdown]
# #### 3º - Adicionar Conteúdo (intents e entities)

# %%
from elastic_db.elasticsearch import elastic_conection, NLPmodelIndex

es = elastic_conection()
index = NLPmodelIndex(es=es, workspace_id="dc1e7b3d-9137-4a20-a99c-d0d2029ef170")
index.index_alias
# Out:
# 'nlp_model-dc1e7b3d-9137-4a20-a99c-d0d2029ef170'

# %%
def add_intents(intents, skill_id_test):
    for intent in intents:
        response=assistant.create_intent(
            workspace_id=skill_id_test,
            intent=intent["intent"],
            examples=intent["for_train"]
        ).get_result()
        print("Intenção %s criada!"%response["intent"])
        
query = {
  "size": 1000, 
  "query": {
    "term": {
      "doc_type.keyword": "intent"
    }
  }
}

intents = es.search(index=index.index_alias, body=query)
intents = [result["_source"] for result in intents["hits"]["hits"]]
add_intents(intents, skill_id_test)
# Out:
# Intenção Data_Pagamento_Vale_RefeicaoAlimentação criada!
# Intenção Despesa_Pessoal_Marcado_Relatorio_Concur criada!
# Intenção Detalhe_Sobre_Desconto criada!
# Intenção Devolucao_Veiculo criada!
# Intenção Divisao_Ferias criada!
# Intenção Download_Aplicativo_Convenio criada!
# Intenção Duvidas_Benefícios criada!
# Intenção Duvidas_Celular_Corporativo criada!
# Intenção Duvidas_Despesas criada!
# Intenção Erros_MercadoEletronico criada!
# Intenção Acessar_SAP_MercadoEletronico criada!
# Intenção Acompanhar_Pedido_MercadoEletronico criada!
# Intenção Adiantamento_e_QuandoReceber_13_Salario criada!
# Intenção Agendamento_Alteracao_Ferias criada!
# Intenção Ajustar_Ponto criada!
# Intenção Ajuste_Informacao_Convenio criada!
# Intenção Alterar_Aprovador criada!
# Intenção Alterar_Conta_Pagamento criada!
# Intenção Alterar_EnquadramentoMerito criada!
# Intenção Alterar_Vale_RefeicaoAlimentacao criada!
# Intenção Bem_Estar criada!
# Intenção Bot_Capabilities criada!
# Intenção Cartao_Clonado_Cambial criada!
# Intenção Contracheque_Recebido_Sem_Constar_Conta criada!
# Intenção Acessar_Concur criada!
# Intenção Acessar_MercadoEletronico criada!
# Intenção Acessar_Painel_Colaborador criada!
# Intenção Exclusoes_Concur criada!
# Intenção Ex_Colaborador_Resgate_Previdencia criada!
# Intenção Extensao_Contrato criada!
# Intenção Extrato_Plano criada!
# Intenção Fazer_Contrato criada!
# Intenção Funcoes_Cartao_Corporativo criada!
# Intenção Gestor_Responsavel_Departamento_Juridico criada!
# Intenção Hora_Extra criada!
# Intenção Imposto_Renda_Previdencia_Privada criada!
# Intenção Inativar_Posição criada!
# Intenção Inconformidades_Legais criada!
# Intenção Info_Concur_SAP criada!
# Intenção Informacao_Geral_Sistemas criada!
# Intenção Informacoes_Relatorio_Gerais criada!
# Intenção Informacoes_Relatorio_Nao_Aprovado criada!
# Intenção Licenca_Mais_Ferias criada!
# Intenção Localizar_Veiculo criada!
# Intenção Manutencoes criada!
# Intenção Marcar_Falta_Colaborador criada!
# Intenção Mistura_Cartao_Reembolso criada!
# Intenção Modelo_Contrato criada!
# Intenção Nossa_Missao criada!
# Intenção Nossa_Visao criada!
# Intenção Novo_Colaborador criada!
# Intenção Novo_Portal_CoE_NãoGostou criada!
# Intenção Orientacoes_PTP criada!
# Intenção Pagamento_Licenca_Maternidade criada!
# Intenção Periodo_Amamentacao_Licenca_Maternidade criada!
# Intenção Duvidas_Funcoes_Cartao criada!
# Intenção Duvidas_Outro_CC criada!
# Intenção Elegibilidade_Previdencia_Privada criada!
# Intenção Emissoes_Cartao criada!
# Intenção Empresa_Seguro_Frota criada!
# Intenção Acionista_Yara_GICS criada!
# Intenção Acompanhar_Saldo_Previdencia_Privada criada!
# Intenção Acompanhar_Solicitacao criada!
# Intenção Aderir_Beneficio_Previdencia_Privada criada!
# Intenção Adiantamento_Duplicado criada!
# Intenção Aditivar_Contrato criada!
# Intenção Agilidade_Negocios criada!
# Intenção Ajuda_Manual_CMS criada!
# Intenção Alteracao_Beneficios_Previdencia criada!
# Intenção Alteracao_CargoSalario criada!
# Intenção Alteracao_CC criada!
# Intenção Alteração_ContratoProrrogacao criada!
# Intenção Alteração_Gestor criada!
# Intenção Alterar_Cargo criada!
# Intenção Alterar_Centro_Custo criada!
# Intenção Alterar_Contrato criada!
# Intenção Alterar_Posicao criada!
# Intenção Alterar_Promocao criada!
# Intenção Alterar_Tipo_Registro_Ponto criada!
# Intenção Ambicao_CoE criada!
# Intenção Ambiente_ConfiancaAgradavel criada!
# Intenção Apresentacao_Institucional criada!
# Intenção Aprovações_YPP criada!
# Intenção Aprovar_Solicitacao_Pendente_Ponto criada!
# Intenção Arquivar_Contrato criada!
# Intenção Assinar_Contrato criada!
# Intenção Assinar_Digitalmente_Contrato criada!
# Intenção Bonus_Mobilidade criada!
# Intenção Branding criada!
# Intenção Cadastro_Concur criada!
# Intenção Canais_Atendimentos_CoE criada!
# Intenção Cancelar_Previdencia criada!
# Intenção Cartao_Bloqueado_SenhaInvalida criada!
# Intenção Cartao_Cancelado criada!
# Intenção Colaboracao_CoE criada!
# Intenção Comprovant_CNPJ criada!
# Intenção Comprovante_Pagamento_Juridico criada!
# Intenção Concur_Cursos criada!
# Intenção Concur_Delegacao criada!
# Intenção Consultar_Procuracao criada!
# Intenção Conta_Bancaria criada!
# Intenção Contato_Operadora_Previdencia_Privada criada!
# Intenção Contracheque_Sem_Constar_Dependente_IRRF criada!
# Intenção Contrato_Aprovado_Proximo_Passo criada!
# Intenção Contrato_Devolvido_Juridico criada!
# Intenção Abono criada!
# Intenção Abrir_Chamado_Salario criada!
# Intenção Acessar_CMS criada!
# Intenção Contrato_Social_ou_Estatuto_Empresa criada!
# Intenção Espirito_Servir criada!
# Intenção Esquecer_Senha_Vale_RefeicaoAlimentacao criada!
# Intenção Estrategia_Aprovar criada!
# Intenção Extrair_Relatorio_Ponto_Todos_Colaboradores criada!
# Intenção Foco_Cliente criada!
# Intenção Fornecedor_ME criada!
# Intenção Fundacao_Valores criada!
# Intenção General_Ending criada!
# Intenção General_Greetings criada!
# Intenção General_Negative_Feedback criada!
# Intenção General_Positive_Feedback criada!
# Intenção Incluir_Colaborador_Convenio criada!
# Intenção Incluir_Dependente_Plano_Saude criada!
# Intenção IncluirRemover_Colaborador criada!
# Intenção Informacoes_Relatorio_Aberto criada!
# Intenção Contribuicoes_Previdencia_Privada criada!
# Intenção Controladoria_Juridica criada!
# Intenção Criar_Posição criada!
# Intenção Curiosidade_CoE criada!
# Intenção Custo_Movimentação_Estado criada!
# Intenção Data_Entrega_Veiculo_Definitivo criada!
# Intenção Data_Envio_Vale_RefeicaoAlimentacao criada!
# Intenção Data_Limite_Ferias criada!
# Intenção Data_Pagamento_Salario criada!
# Intenção Desconto_em_Folha criada!
# Intenção Diferenca_Previdencia_Privada criada!
# Intenção Direcao_Defensiva criada!
# Intenção Direito_ao_13 criada!
# Intenção Documento_Oficial_Justica criada!
# Intenção Documento_Sem_Carimbo_Juridico criada!
# Intenção Duvida_Formularo_Adesao_Previdencia criada!
# Intenção ME_Conta_Contábil criada!
# Intenção Novo_Portal_CoE_Gostou criada!
# Intenção Pagamento_Ferias criada!
# Intenção Ponto_Colaborar_Não_Aparece criada!
# Intenção Priorizar_Criacao_Pedidos criada!
# Intenção Procedimento_Recusado_Convenio criada!
# Intenção Procedimentos_Concur criada!
# Intenção Procedimentos_Convenio criada!
# Intenção Receber_Cartao_Convenio criada!
# Intenção Repassar_Gestao_Colaborador criada!
# Intenção SegundaVia_Cartao_Ticketlog criada!
# Intenção SegundaVia_Vale_RefeicaoAlimentacao criada!
# Intenção Solicitar_Cartao_Combustivel criada!
# Intenção Solicitar_Holerite criada!
# Intenção Solicitar_Ponto_Pos_FechamentoReembolso criada!
# Intenção Solicitar_Troca_Veiculo criada!
# Intenção Status_Ferias_e_Programacao_Sem_Confirmação criada!
# Intenção Transferencia_Veiculo criada!
# Intenção TrocaDevolucao_Ticketlog criada!
# Intenção Usuario_Invalido_NaoCadastrado criada!
# Intenção Valor_Depositado_Vale_RefeicaoAlimentacao_Errado criada!
# Intenção Veiculo_Disponiveis criada!
# Intenção Veiculo_Problema criada!
# Intenção Veiculo_Provisorio criada!
# Intenção Verificar_Colaborador_Convenio criada!
# Intenção Verificar_Historico_Previdencia criada!
# Intenção Verificar_Numero_Carteirinha_Convenio criada!
# Intenção Verificar_Valor_Locacao_Veiculo criada!
# Intenção Periodo_Licenca_Maternidade criada!
# Intenção Pessoas_Focadas_Excelencia criada!
# Intenção Pessoas_Responsaveis_Juridico criada!
# Intenção Prazo_Ajuste_Ponto criada!
# Intenção Prazo_Atendimento_Juridico criada!
# Intenção Prazo_Juridico_Responder criada!
# Intenção Previdencia_Privada_Desconto criada!
# Intenção Procedimento_Contrato_Assinado criada!
# Intenção Proposito_CoE criada!
# Intenção Proposta_Comercial_Juridico criada!
# Intenção Proposta_Rubricada criada!
# Intenção Prorrogacao_Licenca_Maternidade criada!
# Intenção ReceberCancelar_Adiantamento_Salarial criada!
# Intenção Receber_Oficio criada!
# Intenção Recebimento_Beneficio_Previdencia_Privada criada!
# Intenção Reconhecer_Firma_Contrato criada!
# Intenção Reembolso_Janta_HomeOffice criada!
# Intenção Reembolso_Sem_Cobertura_Convenio criada!
# Intenção Relatorio_Inconsistencias_Ponto criada!
# Intenção Relatorio_Old criada!
# Intenção Relatorio_Programacao_Ferias criada!
# Intenção Renovacao_Contrato_Veiculo criada!
# Intenção Representantes_Legais criada!
# Intenção Resgatar_Previdencia criada!
# Intenção Responsabilidade_CoE criada!
# Intenção Retorno_Contrato_CMS_Não_Entendi criada!
# Intenção Solicitacao_Aprovada_Proximo_Passo criada!
# Intenção Solicitacao_Negada_Documento_Aprovado criada!
# Intenção Solicitar_IRPF criada!
# Intenção Solicitar_Procuracao criada!
# Intenção Status_Item_Cancelado criada!
# Intenção Tecnologia_Facilitadora_Eficiencia criada!
# Intenção Testemunha_Contrato criada!
# Intenção Tipos_Reembolso criada!
# Intenção Transferir_Colaborador_Filial criada!
# Intenção Treinamento_Juridico criada!
# Intenção Tributacao_Previdencia_Privada criada!
# Intenção Valor_13 criada!
# Intenção Valores_Geral criada!
# Intenção Valores_Política criada!
# Intenção Valores_Yara criada!
# Intenção Veiculo_Definitivo criada!
# Intenção Verificar_Banco_Horas criada!
# Intenção Verificar_Numero_Vale_RefeicaoAlimentacao criada!
# Intenção Verificar_Status_Ferias criada!
# Intenção Visao_Geral_Previdencia_Privada criada!
# Intenção Vizinho_Invadindo_Terreno criada!

# %% [markdown]
# #### 4º - Função para se comunicar com Skill criada

# %%
skill_id_test = "8b1f8007-c5dd-4366-b48a-34bf295a929c"

# %%
import json
from ibm_watson import AssistantV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

authenticator = IAMAuthenticator(API_KEY)
assistant = AssistantV1(
    version='2020-04-01',
    authenticator = authenticator
)

assistant.set_service_url(SERVICE_URL)

def watson_predict(sentence):
    response = assistant.message(
        workspace_id=skill_id_test,
        input={
            'message_type': 'text',
            'text': sentence
        }
    ).get_result()
    if response.get("intents") and response["intents"]:
        return (response["intents"][0]["intent"], response["intents"][0]["confidence"])
    else:
        return "failed to identify", -1.0

# %% [markdown]
# # Battle Omni NLP API vs. Watson Assistent

# %%
from elasticsearch import Elasticsearch

query = {
      "size": 1000,
      "query": {
        "term": {
          "doc_type.keyword": "intent"
        }
      }
    }

es = Elasticsearch([{'host':"localhost",'port':9200}])

intents = es.search(index="nlp_model-dc1e7b3d-9137-4a20-a99c-d0d2029ef170", body=query)
intents = [result["_source"] for result in intents["hits"]["hits"]]
train_examples = []
test_examples = []
for intent in intents:
    intent_name = intent["intent"]
    train_examples += [(example["text"], intent_name) for example in intent["for_train"]]
    test_examples += [(example["text"], intent_name) for example in intent["for_test"]]

# %%
print(len(train_examples), len(test_examples))
# Out:
# 1039 692

# %%
692/(1039+692)
# Out:
# 0.3997689196995956

# %%
url = url_api+"nlp_model/resources/classify/"
omni_right_answer = 0
watson_right_answer = 0
for test in test_examples:
    params["sentence"] = test[0]
    r = requests.get(url, params=params)
    omni_result = r.json()
    watson_result = watson_predict(test[0])
    print("-------------------------------------------")
    print("sentence: %s"%test[0])
    print("\n")
    print("Omni NLP API\n")
    print("predict_intent: %s"%omni_result["intents"][0]["intent"])
    print("score: %.2f"%omni_result["intents"][0]["confidence"])
    print("right_intent: %s"%test[1])
    if omni_result["intents"][0]["intent"] == test[1]:
        omni_right_answer += 1
        print("is it right?: yes")
    else:
         print("is it right?: no")
    print("quantity of right answers: %s" %omni_right_answer)
    print("\n")
    
    print("Watson Assistent\n")
    print("predict_intent: %s"%watson_result[0])
    print("score: %.2f"%watson_result[1])
    print("right_intent: %s"%test[1])
    if watson_result[0] == test[1]:
        watson_right_answer += 1
        print("is it right?: yes")
    else:
         print("is it right?: no")
    print("quantity of right answers: %s" %watson_right_answer)
    print("\n")

print("-------------------------------------------\n")
print("Total of questions: %d\n"%len(test_examples))
print("Omni NLP API\n") 
print("Total of right answers: %d"%omni_right_answer)
omni_acc = round(omni_right_answer/len(test_examples), 2)*100
print("Accuracy: %s\n"%omni_acc)

print("Watson Assistent\n") 
print("Total of right answers: %d"%watson_right_answer)
watson_acc = round(watson_right_answer/len(test_examples), 2)*100
print("Accuracy: %s"%watson_acc)
# Out:
# -------------------------------------------
# sentence: Gostaria de saber quando será realizado o crédito do vale alimentação
#
#
# Omni NLP API
#
# predict_intent: Data_Pagamento_Vale_RefeicaoAlimentação
# score: 0.50
# right_intent: Data_Pagamento_Vale_RefeicaoAlimentação
# is it right?: yes
# quantity of right answers: 1
#
#
# Watson Assistent
#
# predict_intent: Adiantamento_e_QuandoReceber_13_Salario
# score: 0.34
# right_intent: Data_Pagamento_Vale_RefeicaoAlimentação
# is it right?: no
# quantity of right answers: 0
#
#
# -------------------------------------------
# sentence: Gostaria verificação do que aconteceu para não recebimento do meu saldo de VA (Alelo Alimentação).
#
#
# Omni NLP API
#
# predict_intent: Valor_Depositado_Vale_RefeicaoAlimentacao_Errado
# score: 0.54
# right_intent: Data_Pagamento_Vale_RefeicaoAlimentação
# is it right?: no
# quantity of right answers: 1
#
#
# Watson Assistent
#
# predict_intent: Valor_Depositado_Vale_RefeicaoAlimentacao_Errado
# score: 0.62
# right_intent: Data_Pagamento_Vale_RefeicaoAlimentação
# is it right?: no
# quantity of right answers: 0
#
#
# -------------------------------------------
# sentence: O dinheiro do vale refeição é depositado em qual dia?
#
#
# Omni NLP API
#
# predict_intent: Valor_Depositado_Vale_RefeicaoAlimentacao_Errado
# score: 0.49
# right_intent: Data_Pagamento_Vale_RefeicaoAlimentação
# is it right?: no
# quantity of right answers: 1
#
#
# Watson Assistent
#
# predict_intent: Data_Limite_Ferias
# score: 0.31
# right_intent: Data_Pagamento_Vale_RefeicaoAlimentação
# is it right?: no
# quantity of right answers: 0
#
#
# -------------------------------------------
# sentence: Como devolvo o dinheiro do adiantamento pra Yara
#
#
# Omni NLP API
#
# predict_intent: Adiantamento_Duplicado
# score: 0.39
# right_intent: Despesa_Pessoal_Marcado_Relatorio_Concur
# is it right?: no
# quantity of right answers: 1
#
#
# Watson Assistent
#
# predict_intent: Despesa_Pessoal_Marcado_Relatorio_Concur
# score: 0.44
# right_intent: Despesa_Pessoal_Marcado_Relatorio_Concur
# is it right?: yes
# quantity of right answers: 1
#
#
# -------------------------------------------
# sentence: Como faço para prestar contas da devolução de um adiantamento no Concur?
#
#
# Omni NLP API
#
# predict_intent: Despesa_Pessoal_Marcado_Relatorio_Concur
# score: 0.55
# right_intent: Despesa_Pessoal_Marcado_Relatorio_Concur
# is it right?: yes
# quantity of right answers: 2
#
#
# Watson Assistent
#
# predict_intent: Despesa_Pessoal_Marcado_Relatorio_Concur
# score: 0.83
# right_intent: Despesa_Pessoal_Marcado_Relatorio_Concur
# is it right?: yes
# quantity of right answers: 2
#
#
# -------------------------------------------
# sentence: Qual o tipo de Despesa que eu seleciono para Devolução de adiantamento?
#
#
# Omni NLP API
#
# predict_intent: Despesa_Pessoal_Marcado_Relatorio_Concur
# score: 0.52
# right_intent: Despesa_Pessoal_Marcado_Relatorio_Concur
# is it right?: yes
# quantity of right answers: 3
#
#
# Watson Assistent
#
# predict_intent: Despesa_Pessoal_Marcado_Relatorio_Concur
# score: 0.78
# right_intent: Despesa_Pessoal_Marcado_Relatorio_Concur
# is it right?: yes
# quantity of right answers: 3
#
#
# -------------------------------------------
# sentence: Aconteceu um desconto errado no meu contracheque
#
#
# Omni NLP API
#
# predict_intent: Detalhe_Sobre_Desconto
# score: 0.56
# right_intent: Detalhe_Sobre_Desconto
# is it right?: yes
# quantity of right answers: 4
#
#
# Watson Assistent
#
# predict_intent: Detalhe_Sobre_Desconto
# score: 0.61
# right_intent: Detalhe_Sobre_Desconto
# is it right?: yes
# quantity of right answers: 4
#
#
# -------------------------------------------
# sentence: Aconteceu um desconto errado no meu holerite
#
#
# Omni NLP API
#
# predict_intent: Detalhe_Sobre_Desconto
# score: 0.48
# right_intent: Detalhe_Sobre_Desconto
# is it right?: yes
# quantity of right answers: 5
#
#
# Watson Assistent
#
# predict_intent: Detalhe_Sobre_Desconto
# score: 0.62
# right_intent: Detalhe_Sobre_Desconto
# is it right?: yes
# quantity of right answers: 5
#
#
# -------------------------------------------
# sentence: Retenções folha
#
#
# Omni NLP API
#
# predict_intent: Desconto_em_Folha
# score: 0.35
# right_intent: Detalhe_Sobre_Desconto
# is it right?: no
# quantity of right answers: 5
#
#
# Watson Assistent
#
# predict_intent: General_Negative_Feedback
# score: 0.38
# right_intent: Detalhe_Sobre_Desconto
# is it right?: no
# quantity of right answers: 5
#
#
# -------------------------------------------
# sentence: dois colaboradores do meu QL me questionaram de valor que veio diferente neste mês, em qual dos serviços devo abrir chamado?
#
#
# Omni NLP API
#
# predict_intent: Detalhe_Sobre_Desconto
# score: 0.32
# right_intent: Detalhe_Sobre_Desconto
# is it right?: yes
# quantity of right answers: 6
#
#
# Watson Assistent
#
# predict_intent: IncluirRemover_Colaborador
# score: 0.33
# right_intent: Detalhe_Sobre_Desconto
# is it right?: no
# quantity of right answers: 5
#
#
# -------------------------------------------
# sentence: Como é feita a devolução do veiculo?
#
#
# Omni NLP API
#
# predict_intent: Devolucao_Veiculo
# score: 0.56
# right_intent: Devolucao_Veiculo
# is it right?: yes
# quantity of right answers: 7
#
#
# Watson Assistent
#
# predict_intent: Devolucao_Veiculo
# score: 0.86
# right_intent: Devolucao_Veiculo
# is it right?: yes
# quantity of right answers: 6
#
#
# -------------------------------------------
# sentence: Como realizar a devolução do veículo?
#
#
# Omni NLP API
#
# predict_intent: Devolucao_Veiculo
# score: 0.56
# right_intent: Devolucao_Veiculo
# is it right?: yes
# quantity of right answers: 8
#
#
# Watson Assistent
#
# predict_intent: Devolucao_Veiculo
# score: 0.88
# right_intent: Devolucao_Veiculo
# is it right?: yes
# quantity of right answers: 7
#
#
# -------------------------------------------
# sentence: Qual procedimento para a devolução de um veículo?
#
#
# Omni NLP API
#
# predict_intent: Devolucao_Veiculo
# score: 0.56
# right_intent: Devolucao_Veiculo
# is it right?: yes
# quantity of right answers: 9
#
#
# Watson Assistent
#
# predict_intent: Devolucao_Veiculo
# score: 0.70
# right_intent: Devolucao_Veiculo
# is it right?: yes
# quantity of right answers: 8
#
#
# -------------------------------------------
# sentence: divisão ferias
#
#
# Omni NLP API
#
# predict_intent: Divisao_Ferias
# score: 0.51
# right_intent: Divisao_Ferias
# is it right?: yes
# quantity of right answers: 10
#
#
# Watson Assistent
#
# predict_intent: Divisao_Ferias
# score: 0.63
# right_intent: Divisao_Ferias
# is it right?: yes
# quantity of right answers: 9
#
#
# -------------------------------------------
# sentence: Duvidas sobre tirar @sys-number dias de férias e vender @sys-number, no passado já tirou @sys-number.
#
#
# Omni NLP API
#
# predict_intent: Divisao_Ferias
# score: 0.52
# right_intent: Divisao_Ferias
# is it right?: yes
# quantity of right answers: 11
#
#
# Watson Assistent
#
# predict_intent: Abono
# score: 0.66
# right_intent: Divisao_Ferias
# is it right?: no
# quantity of right answers: 9
#
#
# -------------------------------------------
# sentence: Gostaria de tirar uma dúvida referente a programação de férias da colaboradora. Podemos programar @sys-number dias de férias e solicitar abono pecuniário @sys-number dias em @Datas?
#
#
# Omni NLP API
#
# predict_intent: Agendamento_Alteracao_Ferias
# score: 0.49
# right_intent: Divisao_Ferias
# is it right?: no
# quantity of right answers: 11
#
#
# Watson Assistent
#
# predict_intent: Abono
# score: 0.80
# right_intent: Divisao_Ferias
# is it right?: no
# quantity of right answers: 9
#
#
# -------------------------------------------
# sentence: A colaboradora estava com duvidas ao baixar o App do Aplicativo a unimed.
#
#
# Omni NLP API
#
# predict_intent: Download_Aplicativo_Convenio
# score: 0.57
# right_intent: Download_Aplicativo_Convenio
# is it right?: yes
# quantity of right answers: 12
#
#
# Watson Assistent
#
# predict_intent: Download_Aplicativo_Convenio
# score: 0.84
# right_intent: Download_Aplicativo_Convenio
# is it right?: yes
# quantity of right answers: 10
#
#
# -------------------------------------------
# sentence: Como faço download do app médico?
#
#
# Omni NLP API
#
# predict_intent: Download_Aplicativo_Convenio
# score: 0.34
# right_intent: Download_Aplicativo_Convenio
# is it right?: yes
# quantity of right answers: 13
#
#
# Watson Assistent
#
# predict_intent: Reembolso_Sem_Cobertura_Convenio
# score: 0.62
# right_intent: Download_Aplicativo_Convenio
# is it right?: no
# quantity of right answers: 10
#
#
# -------------------------------------------
# sentence: Não estou localizando o App, Aplicativo do meu plano
#
#
# Omni NLP API
#
# predict_intent: Download_Aplicativo_Convenio
# score: 0.56
# right_intent: Download_Aplicativo_Convenio
# is it right?: yes
# quantity of right answers: 14
#
#
# Watson Assistent
#
# predict_intent: Download_Aplicativo_Convenio
# score: 0.86
# right_intent: Download_Aplicativo_Convenio
# is it right?: yes
# quantity of right answers: 11
# -------------------------------------------
# sentence: Ainda não recebi meu auxilio mudança, como faço para pagar as despesas de transporte?
#
#
# Omni NLP API
#
# predict_intent: Novo_Colaborador
# score: 0.30
# right_intent: Duvidas_Benefícios
# is it right?: no
# quantity of right answers: 14
#
#
# Watson Assistent
#
# predict_intent: Procedimentos_Concur
# score: 0.50
# right_intent: Duvidas_Benefícios
# is it right?: no
# quantity of right answers: 11
#
#
# -------------------------------------------
# sentence: Cartão Combustível
#
#
# Omni NLP API
#
# predict_intent: Solicitar_Cartao_Combustivel
# score: 0.51
# right_intent: Duvidas_Benefícios
# is it right?: no
# quantity of right answers: 14
#
#
# Watson Assistent
#
# predict_intent: Solicitar_Cartao_Combustivel
# score: 0.95
# right_intent: Duvidas_Benefícios
# is it right?: no
# quantity of right answers: 11
#
#
# -------------------------------------------
# sentence: Tenho o plano de saúde Bradesco. Há médicos que não atendem pelo convênio. Sou Gerente Sênior e sei que a Yara reembolsa 80% deste valor. Pergunto: como encaminhar estes recibos aqui pelo portal?
#
#
# Omni NLP API
#
# predict_intent: Incluir_Colaborador_Convenio
# score: 0.37
# right_intent: Duvidas_Benefícios
# is it right?: no
# quantity of right answers: 14
#
#
# Watson Assistent
#
# predict_intent: Reembolso_Sem_Cobertura_Convenio
# score: 0.33
# right_intent: Duvidas_Benefícios
# is it right?: no
# quantity of right answers: 11
#
#
# -------------------------------------------
# sentence: Como solicito reembolso para pagar o frete devido a mudança de unidade da Yara?
#
#
# Omni NLP API
#
# predict_intent: Duvidas_Benefícios
# score: 0.57
# right_intent: Duvidas_Benefícios
# is it right?: yes
# quantity of right answers: 15
#
#
# Watson Assistent
#
# predict_intent: Duvidas_Benefícios
# score: 0.57
# right_intent: Duvidas_Benefícios
# is it right?: yes
# quantity of right answers: 12
#
#
# -------------------------------------------
# sentence: Bom dia, recebi um telefone celular da empresa no ano passado. Contudo é um telefone com pouquíssimos recursos, e não está atendendo as demandas. Meu gestor está de acordo com a aprovação do reembolso de R$ 1500,00 para compra de um novo. Tem mais alguém que precisaria estar de acordo?
#
#
# Omni NLP API
#
# predict_intent: Informacoes_Relatorio_Aberto
# score: 0.51
# right_intent: Duvidas_Celular_Corporativo
# is it right?: no
# quantity of right answers: 15
#
#
# Watson Assistent
#
# predict_intent: Informacoes_Relatorio_Aberto
# score: 0.33
# right_intent: Duvidas_Celular_Corporativo
# is it right?: no
# quantity of right answers: 12
#
#
# -------------------------------------------
# sentence: Comprei um aparelho celular com recursos próprios. Como lanço para obter o reemblso dos R$1500,00 .
#
#
# Omni NLP API
#
# predict_intent: Informacoes_Relatorio_Aberto
# score: 0.43
# right_intent: Duvidas_Celular_Corporativo
# is it right?: no
# quantity of right answers: 15
#
#
# Watson Assistent
#
# predict_intent: Duvidas_Celular_Corporativo
# score: 0.62
# right_intent: Duvidas_Celular_Corporativo
# is it right?: yes
# quantity of right answers: 13
#
#
# -------------------------------------------
# sentence: minha gerência autorizou a troca do aparelho celular que eu utilizo, e há uma pessoa nova entrando também para fazer parte da equipe, e não possuímos cartão corporativo, como eu posso efetuar a troca do aparelho? É possível solicitar o adiantamento?
#
#
# Omni NLP API
#
# predict_intent: Solicitar_Troca_Veiculo
# score: 0.37
# right_intent: Duvidas_Celular_Corporativo
# is it right?: no
# quantity of right answers: 15
#
#
# Watson Assistent
#
# predict_intent: Solicitar_Troca_Veiculo
# score: 0.50
# right_intent: Duvidas_Celular_Corporativo
# is it right?: no
# quantity of right answers: 13
#
#
# -------------------------------------------
# sentence: Estou com dúvidas no lançamento do pedido de reembolso da vacina da gripe. Eu fiz o lançamento via concur, porém não há uma opção clara para reembolso da vacina.
#
#
# Omni NLP API
#
# predict_intent: Informacoes_Relatorio_Aberto
# score: 0.52
# right_intent: Duvidas_Despesas
# is it right?: no
# quantity of right answers: 15
#
#
# Watson Assistent
#
# predict_intent: Reembolso_Sem_Cobertura_Convenio
# score: 0.42
# right_intent: Duvidas_Despesas
# is it right?: no
# quantity of right answers: 13
#
#
# -------------------------------------------
# sentence: Estou solicitando um reembolso da vacina da gripe, mas não encontrei nenhuma opção para este tipo de despesas no concur
#
#
# Omni NLP API
#
# predict_intent: Procedimentos_Concur
# score: 0.52
# right_intent: Duvidas_Despesas
# is it right?: no
# quantity of right answers: 15
#
#
# Watson Assistent
#
# predict_intent: Procedimentos_Concur
# score: 0.58
# right_intent: Duvidas_Despesas
# is it right?: no
# quantity of right answers: 13
#
#
# -------------------------------------------
# sentence: Paguei uma hospedagem com meus proprio recursos e gostaria de solicitar reembolso no Concur.
#
#
# Omni NLP API
#
# predict_intent: Duvidas_Despesas
# score: 0.44
# right_intent: Duvidas_Despesas
# is it right?: yes
# quantity of right answers: 16
#
#
# Watson Assistent
#
# predict_intent: Duvidas_Despesas
# score: 0.69
# right_intent: Duvidas_Despesas
# is it right?: yes
# quantity of right answers: 14
#
#
# -------------------------------------------
# sentence: Estou com uma inconsistência no ERP
#
#
# Omni NLP API
#
# predict_intent: Erros_MercadoEletronico
# score: 0.25
# right_intent: Erros_MercadoEletronico
# is it right?: yes
# quantity of right answers: 17
#
#
# Watson Assistent
#
# predict_intent: Inconformidades_Legais
# score: 0.36
# right_intent: Erros_MercadoEletronico
# is it right?: no
# quantity of right answers: 14
#
#
# -------------------------------------------
# sentence: Gerou um erro de "Erro ORD" na criação do pré-pedido
#
#
# Omni NLP API
#
# predict_intent: Erros_MercadoEletronico
# score: 0.59
# right_intent: Erros_MercadoEletronico
# is it right?: yes
# quantity of right answers: 18
#
#
# Watson Assistent
#
# predict_intent: Erros_MercadoEletronico
# score: 0.96
# right_intent: Erros_MercadoEletronico
# is it right?: yes
# quantity of right answers: 15
#
#
# -------------------------------------------
# sentence: Preciso ajustar meu pré pedido mas esta com inconsistencia de ID idioma
#
#
# Omni NLP API
#
# predict_intent: Erros_MercadoEletronico
# score: 0.58
# right_intent: Erros_MercadoEletronico
# is it right?: yes
# quantity of right answers: 19
#
#
# Watson Assistent
#
# predict_intent: Erros_MercadoEletronico
# score: 0.91
# right_intent: Erros_MercadoEletronico
# is it right?: yes
# quantity of right answers: 16
#
#
# -------------------------------------------
# sentence: Minha RC esta com erro no ME devido a um erro de verificação de compromisso
#
#
# Omni NLP API
#
# predict_intent: Erros_MercadoEletronico
# score: 0.59
# right_intent: Erros_MercadoEletronico
# is it right?: yes
# quantity of right answers: 20
#
#
# Watson Assistent
#
# predict_intent: Erros_MercadoEletronico
# score: 0.99
# right_intent: Erros_MercadoEletronico
# is it right?: yes
# quantity of right answers: 17
#
#
# -------------------------------------------
# sentence: Como faço pra ter acesso ao SAP e criar requisições de compras
#
#
# Omni NLP API
#
# predict_intent: Acessar_SAP_MercadoEletronico
# score: 0.57
# right_intent: Acessar_SAP_MercadoEletronico
# is it right?: yes
# quantity of right answers: 21
#
#
# Watson Assistent
#
# predict_intent: Acessar_SAP_MercadoEletronico
# score: 0.95
# right_intent: Acessar_SAP_MercadoEletronico
# is it right?: yes
# quantity of right answers: 18
#
#
# -------------------------------------------
# sentence: Como saber se posso ter acesso ao SAP?
#
#
# Omni NLP API
#
# predict_intent: Acessar_SAP_MercadoEletronico
# score: 0.57
# right_intent: Acessar_SAP_MercadoEletronico
# is it right?: yes
# quantity of right answers: 22
#
#
# Watson Assistent
#
# predict_intent: Acessar_SAP_MercadoEletronico
# score: 0.86
# right_intent: Acessar_SAP_MercadoEletronico
# is it right?: yes
# quantity of right answers: 19
#
#
# -------------------------------------------
# sentence: Preciso de login e senha do SAP.
#
#
# Omni NLP API
#
# predict_intent: Acessar_SAP_MercadoEletronico
# score: 0.55
# right_intent: Acessar_SAP_MercadoEletronico
# is it right?: yes
# quantity of right answers: 23
#
#
# Watson Assistent
#
# predict_intent: Esquecer_Senha_Vale_RefeicaoAlimentacao
# score: 0.53
# right_intent: Acessar_SAP_MercadoEletronico
# is it right?: no
# quantity of right answers: 19
#
#
# -------------------------------------------
# sentence: A entrega do meu pedido está atrasada
#
#
# Omni NLP API
#
# predict_intent: Acompanhar_Pedido_MercadoEletronico
# score: 0.43
# right_intent: Acompanhar_Pedido_MercadoEletronico
# is it right?: yes
# quantity of right answers: 24
#
#
# Watson Assistent
#
# predict_intent: Acompanhar_Pedido_MercadoEletronico
# score: 0.46
# right_intent: Acompanhar_Pedido_MercadoEletronico
# is it right?: yes
# quantity of right answers: 20
# -------------------------------------------
# sentence: Até o momento não recebi o material que solicitei.
#
#
# Omni NLP API
#
# predict_intent: Acompanhar_Pedido_MercadoEletronico
# score: 0.26
# right_intent: Acompanhar_Pedido_MercadoEletronico
# is it right?: yes
# quantity of right answers: 25
#
#
# Watson Assistent
#
# predict_intent: Pagamento_Ferias
# score: 0.39
# right_intent: Acompanhar_Pedido_MercadoEletronico
# is it right?: no
# quantity of right answers: 20
#
#
# -------------------------------------------
# sentence: Preciso de urgência na entrega do meu pedido.
#
#
# Omni NLP API
#
# predict_intent: Priorizar_Criacao_Pedidos
# score: 0.56
# right_intent: Acompanhar_Pedido_MercadoEletronico
# is it right?: no
# quantity of right answers: 25
#
#
# Watson Assistent
#
# predict_intent: Priorizar_Criacao_Pedidos
# score: 0.54
# right_intent: Acompanhar_Pedido_MercadoEletronico
# is it right?: no
# quantity of right answers: 20
#
#
# -------------------------------------------
# sentence: adiantamento @DecimoTerceiro
#
#
# Omni NLP API
#
# predict_intent: Adiantamento_e_QuandoReceber_13_Salario
# score: 0.57
# right_intent: Adiantamento_e_QuandoReceber_13_Salario
# is it right?: yes
# quantity of right answers: 26
#
#
# Watson Assistent
#
# predict_intent: Adiantamento_e_QuandoReceber_13_Salario
# score: 0.93
# right_intent: Adiantamento_e_QuandoReceber_13_Salario
# is it right?: yes
# quantity of right answers: 21
#
#
# -------------------------------------------
# sentence: Excluir o adiantamento de @DecimoTerceiro das férias programadas
#
#
# Omni NLP API
#
# predict_intent: Adiantamento_e_QuandoReceber_13_Salario
# score: 0.57
# right_intent: Adiantamento_e_QuandoReceber_13_Salario
# is it right?: yes
# quantity of right answers: 27
#
#
# Watson Assistent
#
# predict_intent: Adiantamento_e_QuandoReceber_13_Salario
# score: 0.92
# right_intent: Adiantamento_e_QuandoReceber_13_Salario
# is it right?: yes
# quantity of right answers: 22
#
#
# -------------------------------------------
# sentence: Gostaria de pedir adiantamento do meu @DecimoTerceiro das minhas férias
#
#
# Omni NLP API
#
# predict_intent: Adiantamento_e_QuandoReceber_13_Salario
# score: 0.59
# right_intent: Adiantamento_e_QuandoReceber_13_Salario
# is it right?: yes
# quantity of right answers: 28
#
#
# Watson Assistent
#
# predict_intent: Adiantamento_e_QuandoReceber_13_Salario
# score: 0.91
# right_intent: Adiantamento_e_QuandoReceber_13_Salario
# is it right?: yes
# quantity of right answers: 23
#
#
# -------------------------------------------
# sentence: Inserir o adiantamento de @DecimoTerceiro nas férias programada
#
#
# Omni NLP API
#
# predict_intent: Adiantamento_e_QuandoReceber_13_Salario
# score: 0.56
# right_intent: Adiantamento_e_QuandoReceber_13_Salario
# is it right?: yes
# quantity of right answers: 29
#
#
# Watson Assistent
#
# predict_intent: Adiantamento_e_QuandoReceber_13_Salario
# score: 0.92
# right_intent: Adiantamento_e_QuandoReceber_13_Salario
# is it right?: yes
# quantity of right answers: 24
#
#
# -------------------------------------------
# sentence: Quando receberei o adiantamento do @DecimoTerceiro salário?
#
#
# Omni NLP API
#
# predict_intent: Adiantamento_e_QuandoReceber_13_Salario
# score: 0.60
# right_intent: Adiantamento_e_QuandoReceber_13_Salario
# is it right?: yes
# quantity of right answers: 30
#
#
# Watson Assistent
#
# predict_intent: Adiantamento_e_QuandoReceber_13_Salario
# score: 0.98
# right_intent: Adiantamento_e_QuandoReceber_13_Salario
# is it right?: yes
# quantity of right answers: 25
#
#
# -------------------------------------------
# sentence: agendamento de férias
#
#
# Omni NLP API
#
# predict_intent: Agendamento_Alteracao_Ferias
# score: 0.56
# right_intent: Agendamento_Alteracao_Ferias
# is it right?: yes
# quantity of right answers: 31
#
#
# Watson Assistent
#
# predict_intent: Agendamento_Alteracao_Ferias
# score: 0.85
# right_intent: Agendamento_Alteracao_Ferias
# is it right?: yes
# quantity of right answers: 26
#
#
# -------------------------------------------
# sentence: alterar férias
#
#
# Omni NLP API
#
# predict_intent: Agendamento_Alteracao_Ferias
# score: 0.60
# right_intent: Agendamento_Alteracao_Ferias
# is it right?: yes
# quantity of right answers: 32
#
#
# Watson Assistent
#
# predict_intent: Agendamento_Alteracao_Ferias
# score: 0.79
# right_intent: Agendamento_Alteracao_Ferias
# is it right?: yes
# quantity of right answers: 27
#
#
# -------------------------------------------
# sentence: como agendo minhas férias?
#
#
# Omni NLP API
#
# predict_intent: Agendamento_Alteracao_Ferias
# score: 0.58
# right_intent: Agendamento_Alteracao_Ferias
# is it right?: yes
# quantity of right answers: 33
#
#
# Watson Assistent
#
# predict_intent: Agendamento_Alteracao_Ferias
# score: 0.90
# right_intent: Agendamento_Alteracao_Ferias
# is it right?: yes
# quantity of right answers: 28
#
#
# -------------------------------------------
# sentence: minhas férias foram agendadas para o começar dia @sys-date mas quero mudar para o dia @sys-date
#
#
# Omni NLP API
#
# predict_intent: Licenca_Mais_Ferias
# score: 0.44
# right_intent: Agendamento_Alteracao_Ferias
# is it right?: no
# quantity of right answers: 33
#
#
# Watson Assistent
#
# predict_intent: Agendamento_Alteracao_Ferias
# score: 0.51
# right_intent: Agendamento_Alteracao_Ferias
# is it right?: yes
# quantity of right answers: 29
#
#
# -------------------------------------------
# sentence: Tem algum lugar no portal do CoE onde consigo solicitar minhas férias?
#
#
# Omni NLP API
#
# predict_intent: Status_Ferias_e_Programacao_Sem_Confirmação
# score: 0.35
# right_intent: Agendamento_Alteracao_Ferias
# is it right?: no
# quantity of right answers: 33
#
#
# Watson Assistent
#
# predict_intent: Pagamento_Ferias
# score: 0.36
# right_intent: Agendamento_Alteracao_Ferias
# is it right?: no
# quantity of right answers: 29
#
#
# -------------------------------------------
# sentence: Como devo solicitar o ajuste do ponto?
#
#
# Omni NLP API
#
# predict_intent: Solicitar_Ponto_Pos_FechamentoReembolso
# score: 0.49
# right_intent: Ajustar_Ponto
# is it right?: no
# quantity of right answers: 33
#
#
# Watson Assistent
#
# predict_intent: Ajustar_Ponto
# score: 0.40
# right_intent: Ajustar_Ponto
# is it right?: yes
# quantity of right answers: 30
#
#
# -------------------------------------------
# sentence: Como eu faço pra arrumar meus pontos?
#
#
# Omni NLP API
#
# predict_intent: Ajustar_Ponto
# score: 0.56
# right_intent: Ajustar_Ponto
# is it right?: yes
# quantity of right answers: 34
#
#
# Watson Assistent
#
# predict_intent: Ajustar_Ponto
# score: 0.74
# right_intent: Ajustar_Ponto
# is it right?: yes
# quantity of right answers: 31
#
#
# -------------------------------------------
# sentence: estou com inconsistências no ponto, quem realiza o ajuste
#
#
# Omni NLP API
#
# predict_intent: Ajustar_Ponto
# score: 0.53
# right_intent: Ajustar_Ponto
# is it right?: yes
# quantity of right answers: 35
#
#
# Watson Assistent
#
# predict_intent: Ajustar_Ponto
# score: 0.64
# right_intent: Ajustar_Ponto
# is it right?: yes
# quantity of right answers: 32
#
#
# -------------------------------------------
# sentence: o COE ou RH pode realizar os ajustes no meu ponto
#
#
# Omni NLP API
#
# predict_intent: Aprovar_Solicitacao_Pendente_Ponto
# score: 0.54
# right_intent: Ajustar_Ponto
# is it right?: no
# quantity of right answers: 35
#
#
# Watson Assistent
#
# predict_intent: Ajustar_Ponto
# score: 0.53
# right_intent: Ajustar_Ponto
# is it right?: yes
# quantity of right answers: 33
#
#
# -------------------------------------------
# sentence: O que fazer esqueci de registrar o ponto?
#
#
# Omni NLP API
#
# predict_intent: Ajustar_Ponto
# score: 0.59
# right_intent: Ajustar_Ponto
# is it right?: yes
# quantity of right answers: 36
#
#
# Watson Assistent
#
# predict_intent: Ajustar_Ponto
# score: 0.95
# right_intent: Ajustar_Ponto
# is it right?: yes
# quantity of right answers: 34
#
#
# -------------------------------------------
# sentence: A sua Esposa esta com a data de nascimento incorreta no sistema da Operadora Bradesco Odonto, favor verificar.
#
#
# Omni NLP API
#
# predict_intent: Ajuste_Informacao_Convenio
# score: 0.34
# right_intent: Ajuste_Informacao_Convenio
# is it right?: yes
# quantity of right answers: 37
#
#
# Watson Assistent
#
# predict_intent: Ajuste_Informacao_Convenio
# score: 0.44
# right_intent: Ajuste_Informacao_Convenio
# is it right?: yes
# quantity of right answers: 35
#
#
# -------------------------------------------
# sentence: Minha filha precisou usar o plano , porém a clínica, informou que o cadastro está com a data de nascimento errada, favor corrigir.
#
#
# Omni NLP API
#
# predict_intent: Ajuste_Informacao_Convenio
# score: 0.55
# right_intent: Ajuste_Informacao_Convenio
# is it right?: yes
# quantity of right answers: 38
#
#
# Watson Assistent
#
# predict_intent: Ajuste_Informacao_Convenio
# score: 0.32
# right_intent: Ajuste_Informacao_Convenio
# is it right?: yes
# quantity of right answers: 36
# -------------------------------------------
# sentence: Preciso arrumar meu nome no convenio
#
#
# Omni NLP API
#
# predict_intent: Ajuste_Informacao_Convenio
# score: 0.43
# right_intent: Ajuste_Informacao_Convenio
# is it right?: yes
# quantity of right answers: 39
#
#
# Watson Assistent
#
# predict_intent: Ajuste_Informacao_Convenio
# score: 0.48
# right_intent: Ajuste_Informacao_Convenio
# is it right?: yes
# quantity of right answers: 37
#
#
# -------------------------------------------
# sentence: Alteração de workflow dos centro de custos TRV2MT001 & TRV1MT027 para minha aprovação.
#
#
# Omni NLP API
#
# predict_intent: Alterar_Centro_Custo
# score: 0.53
# right_intent: Alterar_Aprovador
# is it right?: no
# quantity of right answers: 39
#
#
# Watson Assistent
#
# predict_intent: Alterar_Centro_Custo
# score: 0.74
# right_intent: Alterar_Aprovador
# is it right?: no
# quantity of right answers: 37
#
#
# -------------------------------------------
# sentence: a minha solicitação de adiantamento feito no concur, não está indo para o meu Gerente Fabiano Biasutti
#
#
# Omni NLP API
#
# predict_intent: Procedimentos_Concur
# score: 0.40
# right_intent: Alterar_Aprovador
# is it right?: no
# quantity of right answers: 39
#
#
# Watson Assistent
#
# predict_intent: Acessar_Concur
# score: 0.33
# right_intent: Alterar_Aprovador
# is it right?: no
# quantity of right answers: 37
#
#
# -------------------------------------------
# sentence: Estamos com novo gerente e as despesas do CONCUR não esta caindo para o novo gerente, necessito que regularize para as despesas ir para aprovação do GC-TAN Diego Zacarin.
#
#
# Omni NLP API
#
# predict_intent: Informacoes_Relatorio_Aberto
# score: 0.35
# right_intent: Alterar_Aprovador
# is it right?: no
# quantity of right answers: 39
#
#
# Watson Assistent
#
# predict_intent: Duvidas_Funcoes_Cartao
# score: 0.39
# right_intent: Alterar_Aprovador
# is it right?: no
# quantity of right answers: 37
#
#
# -------------------------------------------
# sentence: Estou tentando fazer uma prestação de contas, mas não foi possível pois é necessário a atualização do aprovador. Fui orientada a atualizar meus dados cadastrais, mas o sistema não reconhece o meu centro de custo. Favor verificar.
#
#
# Omni NLP API
#
# predict_intent: Informacoes_Relatorio_Aberto
# score: 0.46
# right_intent: Alterar_Aprovador
# is it right?: no
# quantity of right answers: 39
#
#
# Watson Assistent
#
# predict_intent: Info_Concur_SAP
# score: 0.27
# right_intent: Alterar_Aprovador
# is it right?: no
# quantity of right answers: 37
#
#
# -------------------------------------------
# sentence: Meus relatórios estão indo para uma pessoa porém ele não é mais meu gestor tem como corrigir para o meu gestor?
#
#
# Omni NLP API
#
# predict_intent: Alterar_Aprovador
# score: 0.51
# right_intent: Alterar_Aprovador
# is it right?: yes
# quantity of right answers: 40
#
#
# Watson Assistent
#
# predict_intent: Alterar_Aprovador
# score: 0.36
# right_intent: Alterar_Aprovador
# is it right?: yes
# quantity of right answers: 38
#
#
# -------------------------------------------
# sentence: alterar minha conta
#
#
# Omni NLP API
#
# predict_intent: Alterar_Conta_Pagamento
# score: 0.33
# right_intent: Alterar_Conta_Pagamento
# is it right?: yes
# quantity of right answers: 41
#
#
# Watson Assistent
#
# predict_intent: ME_Conta_Contábil
# score: 0.47
# right_intent: Alterar_Conta_Pagamento
# is it right?: no
# quantity of right answers: 38
#
#
# -------------------------------------------
# sentence: Como eu faço pra mudar a o banco onde é feito o deposito do meu salario
#
#
# Omni NLP API
#
# predict_intent: Alterar_Conta_Pagamento
# score: 0.53
# right_intent: Alterar_Conta_Pagamento
# is it right?: yes
# quantity of right answers: 42
#
#
# Watson Assistent
#
# predict_intent: Alterar_Conta_Pagamento
# score: 0.75
# right_intent: Alterar_Conta_Pagamento
# is it right?: yes
# quantity of right answers: 39
#
#
# -------------------------------------------
# sentence: mudar o banco
#
#
# Omni NLP API
#
# predict_intent: Alterar_Conta_Pagamento
# score: 0.39
# right_intent: Alterar_Conta_Pagamento
# is it right?: yes
# quantity of right answers: 43
#
#
# Watson Assistent
#
# predict_intent: Verificar_Banco_Horas
# score: 0.59
# right_intent: Alterar_Conta_Pagamento
# is it right?: no
# quantity of right answers: 39
#
#
# -------------------------------------------
# sentence: Como sei quem pode ter um aumento de salário por merecimento?
#
#
# Omni NLP API
#
# predict_intent: Alterar_EnquadramentoMerito
# score: 0.54
# right_intent: Alterar_EnquadramentoMerito
# is it right?: yes
# quantity of right answers: 44
#
#
# Watson Assistent
#
# predict_intent: Alterar_EnquadramentoMerito
# score: 0.65
# right_intent: Alterar_EnquadramentoMerito
# is it right?: yes
# quantity of right answers: 40
#
#
# -------------------------------------------
# sentence: Onde encontro informações sobre o processo para solicitar um aumento salarial?
#
#
# Omni NLP API
#
# predict_intent: Alterar_EnquadramentoMerito
# score: 0.54
# right_intent: Alterar_EnquadramentoMerito
# is it right?: yes
# quantity of right answers: 45
#
#
# Watson Assistent
#
# predict_intent: Alterar_EnquadramentoMerito
# score: 0.91
# right_intent: Alterar_EnquadramentoMerito
# is it right?: yes
# quantity of right answers: 41
#
#
# -------------------------------------------
# sentence: Qual prazo para analise da solicitação de aumento salarial?
#
#
# Omni NLP API
#
# predict_intent: Alterar_EnquadramentoMerito
# score: 0.56
# right_intent: Alterar_EnquadramentoMerito
# is it right?: yes
# quantity of right answers: 46
#
#
# Watson Assistent
#
# predict_intent: Alterar_EnquadramentoMerito
# score: 0.93
# right_intent: Alterar_EnquadramentoMerito
# is it right?: yes
# quantity of right answers: 42
#
#
# -------------------------------------------
# sentence: a colaboradora solicita a alteração de VR para VA.
#
#
# Omni NLP API
#
# predict_intent: Alterar_Vale_RefeicaoAlimentacao
# score: 0.57
# right_intent: Alterar_Vale_RefeicaoAlimentacao
# is it right?: yes
# quantity of right answers: 47
#
#
# Watson Assistent
#
# predict_intent: Alterar_Vale_RefeicaoAlimentacao
# score: 0.44
# right_intent: Alterar_Vale_RefeicaoAlimentacao
# is it right?: yes
# quantity of right answers: 43
#
#
# -------------------------------------------
# sentence: alteração vale reifeição
#
#
# Omni NLP API
#
# predict_intent: Alterar_Vale_RefeicaoAlimentacao
# score: 0.52
# right_intent: Alterar_Vale_RefeicaoAlimentacao
# is it right?: yes
# quantity of right answers: 48
#
#
# Watson Assistent
#
# predict_intent: Agendamento_Alteracao_Ferias
# score: 0.68
# right_intent: Alterar_Vale_RefeicaoAlimentacao
# is it right?: no
# quantity of right answers: 43
#
#
# -------------------------------------------
# sentence: Recebi meu Cartão Alelo Refeição, porém tinha solicitado o Cartão Alelo Alimentação, como devo fazer para realizar a troca dos cartões?
#
#
# Omni NLP API
#
# predict_intent: Valor_Depositado_Vale_RefeicaoAlimentacao_Errado
# score: 0.50
# right_intent: Alterar_Vale_RefeicaoAlimentacao
# is it right?: no
# quantity of right answers: 48
#
#
# Watson Assistent
#
# predict_intent: Valor_Depositado_Vale_RefeicaoAlimentacao_Errado
# score: 0.36
# right_intent: Alterar_Vale_RefeicaoAlimentacao
# is it right?: no
# quantity of right answers: 43
#
#
# -------------------------------------------
# sentence: como vai?
#
#
# Omni NLP API
#
# predict_intent: General_Negative_Feedback
# score: 0.52
# right_intent: Bem_Estar
# is it right?: no
# quantity of right answers: 48
#
#
# Watson Assistent
#
# predict_intent: General_Negative_Feedback
# score: 0.39
# right_intent: Bem_Estar
# is it right?: no
# quantity of right answers: 43
#
#
# -------------------------------------------
# sentence: como vão as coisas?
#
#
# Omni NLP API
#
# predict_intent: Consultar_Procuracao
# score: 0.21
# right_intent: Bem_Estar
# is it right?: no
# quantity of right answers: 48
#
#
# Watson Assistent
#
# predict_intent: Bem_Estar
# score: 0.36
# right_intent: Bem_Estar
# is it right?: yes
# quantity of right answers: 44
#
#
# -------------------------------------------
# sentence: tudo bem contigo?
#
#
# Omni NLP API
#
# predict_intent: Bem_Estar
# score: 0.54
# right_intent: Bem_Estar
# is it right?: yes
# quantity of right answers: 49
#
#
# Watson Assistent
#
# predict_intent: Bem_Estar
# score: 0.97
# right_intent: Bem_Estar
# is it right?: yes
# quantity of right answers: 45
#
#
# -------------------------------------------
# sentence: do que você sabe falar
#
#
# Omni NLP API
#
# predict_intent: Bot_Capabilities
# score: 0.57
# right_intent: Bot_Capabilities
# is it right?: yes
# quantity of right answers: 50
#
#
# Watson Assistent
#
# predict_intent: Bot_Capabilities
# score: 0.95
# right_intent: Bot_Capabilities
# is it right?: yes
# quantity of right answers: 46
# -------------------------------------------
# sentence: em que você pode me ajudar
#
#
# Omni NLP API
#
# predict_intent: Bot_Capabilities
# score: 0.56
# right_intent: Bot_Capabilities
# is it right?: yes
# quantity of right answers: 51
#
#
# Watson Assistent
#
# predict_intent: Bot_Capabilities
# score: 0.74
# right_intent: Bot_Capabilities
# is it right?: yes
# quantity of right answers: 47
#
#
# -------------------------------------------
# sentence: vc sabe falar do que
#
#
# Omni NLP API
#
# predict_intent: Bot_Capabilities
# score: 0.43
# right_intent: Bot_Capabilities
# is it right?: yes
# quantity of right answers: 52
#
#
# Watson Assistent
#
# predict_intent: Bot_Capabilities
# score: 0.63
# right_intent: Bot_Capabilities
# is it right?: yes
# quantity of right answers: 48
#
#
# -------------------------------------------
# sentence: quais os assuntos você trata
#
#
# Omni NLP API
#
# predict_intent: Bot_Capabilities
# score: 0.44
# right_intent: Bot_Capabilities
# is it right?: yes
# quantity of right answers: 53
#
#
# Watson Assistent
#
# predict_intent: Bot_Capabilities
# score: 0.57
# right_intent: Bot_Capabilities
# is it right?: yes
# quantity of right answers: 49
#
#
# -------------------------------------------
# sentence: Ao efetuar uma compra, a empresa prestadora de serviços passou a despesa errada para meu cartão. Ela estornou a compra, mas ainda aparece no concur. Como proceder.
#
#
# Omni NLP API
#
# predict_intent: Informacoes_Relatorio_Aberto
# score: 0.43
# right_intent: Cartao_Clonado_Cambial
# is it right?: no
# quantity of right answers: 53
#
#
# Watson Assistent
#
# predict_intent: Receber_Cartao_Convenio
# score: 0.29
# right_intent: Cartao_Clonado_Cambial
# is it right?: no
# quantity of right answers: 49
#
#
# -------------------------------------------
# sentence: Como carregar diferencias cambiais e iOF
#
#
# Omni NLP API
#
# predict_intent: General_Positive_Feedback
# score: 0.15
# right_intent: Cartao_Clonado_Cambial
# is it right?: no
# quantity of right answers: 53
#
#
# Watson Assistent
#
# predict_intent: Pessoas_Focadas_Excelencia
# score: 0.31
# right_intent: Cartao_Clonado_Cambial
# is it right?: no
# quantity of right answers: 49
#
#
# -------------------------------------------
# sentence: Não reconheço o débito no cartão corporativo abaixo
#
#
# Omni NLP API
#
# predict_intent: Emissoes_Cartao
# score: 0.36
# right_intent: Cartao_Clonado_Cambial
# is it right?: no
# quantity of right answers: 53
#
#
# Watson Assistent
#
# predict_intent: Emissoes_Cartao
# score: 0.72
# right_intent: Cartao_Clonado_Cambial
# is it right?: no
# quantity of right answers: 49
#
#
# -------------------------------------------
# sentence: Estou com o contra-cheque, mas o pagamento ainda não caiu na conta
#
#
# Omni NLP API
#
# predict_intent: Contracheque_Recebido_Sem_Constar_Conta
# score: 0.57
# right_intent: Contracheque_Recebido_Sem_Constar_Conta
# is it right?: yes
# quantity of right answers: 54
#
#
# Watson Assistent
#
# predict_intent: Contracheque_Recebido_Sem_Constar_Conta
# score: 0.98
# right_intent: Contracheque_Recebido_Sem_Constar_Conta
# is it right?: yes
# quantity of right answers: 50
#
#
# -------------------------------------------
# sentence: Fiquei sem salário, por que?
#
#
# Omni NLP API
#
# predict_intent: Alterar_Conta_Pagamento
# score: 0.30
# right_intent: Contracheque_Recebido_Sem_Constar_Conta
# is it right?: no
# quantity of right answers: 54
#
#
# Watson Assistent
#
# predict_intent: Alteracao_CargoSalario
# score: 0.49
# right_intent: Contracheque_Recebido_Sem_Constar_Conta
# is it right?: no
# quantity of right answers: 50
#
#
# -------------------------------------------
# sentence: Por que recebi o recibo de pagamento e o salaraio não?
#
#
# Omni NLP API
#
# predict_intent: Abrir_Chamado_Salario
# score: 0.38
# right_intent: Contracheque_Recebido_Sem_Constar_Conta
# is it right?: no
# quantity of right answers: 54
#
#
# Watson Assistent
#
# predict_intent: Pagamento_Ferias
# score: 0.47
# right_intent: Contracheque_Recebido_Sem_Constar_Conta
# is it right?: no
# quantity of right answers: 50
#
#
# -------------------------------------------
# sentence: Bom dia, não estou conseguindo acessar o Concur. Quando solicito alteração de senha, coloco meu email Yara e não recebo nada.
#
#
# Omni NLP API
#
# predict_intent: Acessar_Concur
# score: 0.57
# right_intent: Acessar_Concur
# is it right?: yes
# quantity of right answers: 55
#
#
# Watson Assistent
#
# predict_intent: Acessar_Concur
# score: 0.80
# right_intent: Acessar_Concur
# is it right?: yes
# quantity of right answers: 51
#
#
# -------------------------------------------
# sentence: Colaborador ligou e Informa que não está conseguindo acessar o Concur.
#
#
# Omni NLP API
#
# predict_intent: Acessar_Concur
# score: 0.56
# right_intent: Acessar_Concur
# is it right?: yes
# quantity of right answers: 56
#
#
# Watson Assistent
#
# predict_intent: Acessar_Concur
# score: 0.43
# right_intent: Acessar_Concur
# is it right?: yes
# quantity of right answers: 52
#
#
# -------------------------------------------
# sentence: Meu concur está bloqueado. Como Faço?
#
#
# Omni NLP API
#
# predict_intent: Cadastro_Concur
# score: 0.31
# right_intent: Acessar_Concur
# is it right?: no
# quantity of right answers: 56
#
#
# Watson Assistent
#
# predict_intent: Alteracao_CC
# score: 0.42
# right_intent: Acessar_Concur
# is it right?: no
# quantity of right answers: 52
#
#
# -------------------------------------------
# sentence: Como posso solicitar acesso ao ME?
#
#
# Omni NLP API
#
# predict_intent: Acessar_MercadoEletronico
# score: 0.31
# right_intent: Acessar_MercadoEletronico
# is it right?: yes
# quantity of right answers: 57
#
#
# Watson Assistent
#
# predict_intent: Acessar_MercadoEletronico
# score: 0.54
# right_intent: Acessar_MercadoEletronico
# is it right?: yes
# quantity of right answers: 53
#
#
# -------------------------------------------
# sentence: Onde solicito o acesso ao ME?
#
#
# Omni NLP API
#
# predict_intent: Acessar_MercadoEletronico
# score: 0.31
# right_intent: Acessar_MercadoEletronico
# is it right?: yes
# quantity of right answers: 58
#
#
# Watson Assistent
#
# predict_intent: Acessar_MercadoEletronico
# score: 0.67
# right_intent: Acessar_MercadoEletronico
# is it right?: yes
# quantity of right answers: 54
#
#
# -------------------------------------------
# sentence: Preciso de login e senha pro Mercado Eletrônico
#
#
# Omni NLP API
#
# predict_intent: Usuario_Invalido_NaoCadastrado
# score: 0.33
# right_intent: Acessar_MercadoEletronico
# is it right?: no
# quantity of right answers: 58
#
#
# Watson Assistent
#
# predict_intent: Usuario_Invalido_NaoCadastrado
# score: 0.37
# right_intent: Acessar_MercadoEletronico
# is it right?: no
# quantity of right answers: 54
#
#
# -------------------------------------------
# sentence: Como eu faço pra entrar no painel do colaborador?
#
#
# Omni NLP API
#
# predict_intent: Acessar_Painel_Colaborador
# score: 0.55
# right_intent: Acessar_Painel_Colaborador
# is it right?: yes
# quantity of right answers: 59
#
#
# Watson Assistent
#
# predict_intent: Acessar_Painel_Colaborador
# score: 0.72
# right_intent: Acessar_Painel_Colaborador
# is it right?: yes
# quantity of right answers: 55
#
#
# -------------------------------------------
# sentence: Estou sem acesso aos colaboradores do meu time no ponto mais.
#
#
# Omni NLP API
#
# predict_intent: IncluirRemover_Colaborador
# score: 0.57
# right_intent: Acessar_Painel_Colaborador
# is it right?: no
# quantity of right answers: 59
#
#
# Watson Assistent
#
# predict_intent: IncluirRemover_Colaborador
# score: 0.85
# right_intent: Acessar_Painel_Colaborador
# is it right?: no
# quantity of right answers: 55
#
#
# -------------------------------------------
# sentence: Não estou conseguindo acessar a gestão de ponto.
#
#
# Omni NLP API
#
# predict_intent: Ponto_Colaborar_Não_Aparece
# score: 0.48
# right_intent: Acessar_Painel_Colaborador
# is it right?: no
# quantity of right answers: 59
#
#
# Watson Assistent
#
# predict_intent: Ponto_Colaborar_Não_Aparece
# score: 0.44
# right_intent: Acessar_Painel_Colaborador
# is it right?: no
# quantity of right answers: 55
#
#
# -------------------------------------------
# sentence: tenho algum prestação o concur de ano atro comer eu fazer pra remover ele
#
#
# Omni NLP API
#
# predict_intent: Exclusoes_Concur
# score: 0.52
# right_intent: Exclusoes_Concur
# is it right?: yes
# quantity of right answers: 60
#
#
# Watson Assistent
#
# predict_intent: Exclusoes_Concur
# score: 0.55
# right_intent: Exclusoes_Concur
# is it right?: yes
# quantity of right answers: 56
#
#
# -------------------------------------------
# sentence: tenho pendenciar de prestação de contar de que já ser finalizar e aparecer o concur precisar
#
#
# Omni NLP API
#
# predict_intent: Exclusoes_Concur
# score: 0.39
# right_intent: Exclusoes_Concur
# is it right?: yes
# quantity of right answers: 61
#
#
# Watson Assistent
#
# predict_intent: Exclusoes_Concur
# score: 0.43
# right_intent: Exclusoes_Concur
# is it right?: yes
# quantity of right answers: 57
# -------------------------------------------
# sentence: como excluir umar prestação de contar antigo o o concur
#
#
# Omni NLP API
#
# predict_intent: Exclusoes_Concur
# score: 0.55
# right_intent: Exclusoes_Concur
# is it right?: yes
# quantity of right answers: 62
#
#
# Watson Assistent
#
# predict_intent: Exclusoes_Concur
# score: 0.79
# right_intent: Exclusoes_Concur
# is it right?: yes
# quantity of right answers: 58
#
#
# -------------------------------------------
# sentence: ex colaborador solicitar informação de resgatar
#
#
# Omni NLP API
#
# predict_intent: Ex_Colaborador_Resgate_Previdencia
# score: 0.54
# right_intent: Ex_Colaborador_Resgate_Previdencia
# is it right?: yes
# quantity of right answers: 63
#
#
# Watson Assistent
#
# predict_intent: Ex_Colaborador_Resgate_Previdencia
# score: 0.80
# right_intent: Ex_Colaborador_Resgate_Previdencia
# is it right?: yes
# quantity of right answers: 59
#
#
# -------------------------------------------
# sentence: ex colaborador desejar saber se poder passar o planar de previdência antigo da yara parir o empresar novo
#
#
# Omni NLP API
#
# predict_intent: Ex_Colaborador_Resgate_Previdencia
# score: 0.56
# right_intent: Ex_Colaborador_Resgate_Previdencia
# is it right?: yes
# quantity of right answers: 64
#
#
# Watson Assistent
#
# predict_intent: Ex_Colaborador_Resgate_Previdencia
# score: 0.92
# right_intent: Ex_Colaborador_Resgate_Previdencia
# is it right?: yes
# quantity of right answers: 60
#
#
# -------------------------------------------
# sentence: duvidar sobrar resgatar da previdência
#
#
# Omni NLP API
#
# predict_intent: Ex_Colaborador_Resgate_Previdencia
# score: 0.26
# right_intent: Ex_Colaborador_Resgate_Previdencia
# is it right?: yes
# quantity of right answers: 65
#
#
# Watson Assistent
#
# predict_intent: Resgatar_Previdencia
# score: 0.45
# right_intent: Ex_Colaborador_Resgate_Previdencia
# is it right?: no
# quantity of right answers: 60
#
#
# -------------------------------------------
# sentence: preciso solicitar o prorrogação de contratar de trabalhar
#
#
# Omni NLP API
#
# predict_intent: Extensao_Contrato
# score: 0.53
# right_intent: Extensao_Contrato
# is it right?: yes
# quantity of right answers: 66
#
#
# Watson Assistent
#
# predict_intent: Extensao_Contrato
# score: 0.80
# right_intent: Extensao_Contrato
# is it right?: yes
# quantity of right answers: 61
#
#
# -------------------------------------------
# sentence: quando poder fazer o solicitação de prorrogação de um contratar de trabalhar
#
#
# Omni NLP API
#
# predict_intent: Extensao_Contrato
# score: 0.56
# right_intent: Extensao_Contrato
# is it right?: yes
# quantity of right answers: 67
#
#
# Watson Assistent
#
# predict_intent: Extensao_Contrato
# score: 0.83
# right_intent: Extensao_Contrato
# is it right?: yes
# quantity of right answers: 62
#
#
# -------------------------------------------
# sentence: quem poder solicitar o prorrogação de contratar de trabalhar
#
#
# Omni NLP API
#
# predict_intent: Extensao_Contrato
# score: 0.53
# right_intent: Extensao_Contrato
# is it right?: yes
# quantity of right answers: 68
#
#
# Watson Assistent
#
# predict_intent: Extensao_Contrato
# score: 0.77
# right_intent: Extensao_Contrato
# is it right?: yes
# quantity of right answers: 63
#
#
# -------------------------------------------
# sentence: Necessito ter acesso as despesas do plano odonto de meses anteriores, como faço?
#
#
# Omni NLP API
#
# predict_intent: Extrato_Plano
# score: 0.31
# right_intent: Extrato_Plano
# is it right?: yes
# quantity of right answers: 69
#
#
# Watson Assistent
#
# predict_intent: Extrato_Plano
# score: 0.38
# right_intent: Extrato_Plano
# is it right?: yes
# quantity of right answers: 64
#
#
# -------------------------------------------
# sentence: como obter o detalhamento dos custo de despesa médico
#
#
# Omni NLP API
#
# predict_intent: Extrato_Plano
# score: 0.55
# right_intent: Extrato_Plano
# is it right?: yes
# quantity of right answers: 70
#
#
# Watson Assistent
#
# predict_intent: Extrato_Plano
# score: 0.83
# right_intent: Extrato_Plano
# is it right?: yes
# quantity of right answers: 65
#
#
# -------------------------------------------
# sentence: a que se o despesa médico em meu contracheque
#
#
# Omni NLP API
#
# predict_intent: Extrato_Plano
# score: 0.54
# right_intent: Extrato_Plano
# is it right?: yes
# quantity of right answers: 71
#
#
# Watson Assistent
#
# predict_intent: Extrato_Plano
# score: 0.58
# right_intent: Extrato_Plano
# is it right?: yes
# quantity of right answers: 66
#
#
# -------------------------------------------
# sentence: gostaria de contratar umar empresar um serviço como comedir
#
#
# Omni NLP API
#
# predict_intent: Fazer_Contrato
# score: 0.49
# right_intent: Fazer_Contrato
# is it right?: yes
# quantity of right answers: 72
#
#
# Watson Assistent
#
# predict_intent: Fazer_Contrato
# score: 0.63
# right_intent: Fazer_Contrato
# is it right?: yes
# quantity of right answers: 67
#
#
# -------------------------------------------
# sentence: para quem pedir um contratar
#
#
# Omni NLP API
#
# predict_intent: Fazer_Contrato
# score: 0.27
# right_intent: Fazer_Contrato
# is it right?: yes
# quantity of right answers: 73
#
#
# Watson Assistent
#
# predict_intent: Fazer_Contrato
# score: 0.47
# right_intent: Fazer_Contrato
# is it right?: yes
# quantity of right answers: 68
#
#
# -------------------------------------------
# sentence: gostaria de fazer um contratar como comedir
#
#
# Omni NLP API
#
# predict_intent: Fazer_Contrato
# score: 0.42
# right_intent: Fazer_Contrato
# is it right?: yes
# quantity of right answers: 74
#
#
# Watson Assistent
#
# predict_intent: Fazer_Contrato
# score: 0.63
# right_intent: Fazer_Contrato
# is it right?: yes
# quantity of right answers: 69
#
#
# -------------------------------------------
# sentence: tenho um documentar que preciso de revisão do jurídico como fazer
#
#
# Omni NLP API
#
# predict_intent: Fazer_Contrato
# score: 0.55
# right_intent: Fazer_Contrato
# is it right?: yes
# quantity of right answers: 75
#
#
# Watson Assistent
#
# predict_intent: Fazer_Contrato
# score: 0.91
# right_intent: Fazer_Contrato
# is it right?: yes
# quantity of right answers: 70
#
#
# -------------------------------------------
# sentence: existe umar maneiro de controlar o transções do meu cartão corporativo
#
#
# Omni NLP API
#
# predict_intent: Funcoes_Cartao_Corporativo
# score: 0.55
# right_intent: Funcoes_Cartao_Corporativo
# ...
#
#
# Omni NLP API
#
# predict_intent: Treinamento_Juridico
# score: 0.56
# right_intent: Treinamento_Juridico
# is it right?: yes
# quantity of right answers: 531
#
#
# Watson Assistent
#
# predict_intent: Treinamento_Juridico
# score: 0.85
# right_intent: Treinamento_Juridico
# is it right?: yes
# quantity of right answers: 526
# -------------------------------------------
# sentence: o jurídico fazer treinamento
#
#
# Omni NLP API
#
# predict_intent: Treinamento_Juridico
# score: 0.56
# right_intent: Treinamento_Juridico
# is it right?: yes
# quantity of right answers: 532
#
#
# Watson Assistent
#
# predict_intent: Treinamento_Juridico
# score: 0.83
# right_intent: Treinamento_Juridico
# is it right?: yes
# quantity of right answers: 527
#
#
# -------------------------------------------
# sentence: qual o tipo de tributação que o previdencia privar ter
#
#
# Omni NLP API
#
# predict_intent: Tributacao_Previdencia_Privada
# score: 0.53
# right_intent: Tributacao_Previdencia_Privada
# is it right?: yes
# quantity of right answers: 533
#
#
# Watson Assistent
#
# predict_intent: Tributacao_Previdencia_Privada
# score: 0.90
# right_intent: Tributacao_Previdencia_Privada
# is it right?: yes
# quantity of right answers: 528
#
#
# -------------------------------------------
# sentence: o que ser tributação o previdencia privar
#
#
# Omni NLP API
#
# predict_intent: Tributacao_Previdencia_Privada
# score: 0.53
# right_intent: Tributacao_Previdencia_Privada
# is it right?: yes
# quantity of right answers: 534
#
#
# Watson Assistent
#
# predict_intent: Tributacao_Previdencia_Privada
# score: 0.91
# right_intent: Tributacao_Previdencia_Privada
# is it right?: yes
# quantity of right answers: 529
#
#
# -------------------------------------------
# sentence: previdencia privar ter tributação
#
#
# Omni NLP API
#
# predict_intent: Tributacao_Previdencia_Privada
# score: 0.52
# right_intent: Tributacao_Previdencia_Privada
# is it right?: yes
# quantity of right answers: 535
#
#
# Watson Assistent
#
# predict_intent: Tributacao_Previdencia_Privada
# score: 0.92
# right_intent: Tributacao_Previdencia_Privada
# is it right?: yes
# quantity of right answers: 530
#
#
# -------------------------------------------
# sentence: qual o valor do décimo terceirar salário
#
#
# Omni NLP API
#
# predict_intent: Valor_13
# score: 0.56
# right_intent: Valor_13
# is it right?: yes
# quantity of right answers: 536
#
#
# Watson Assistent
#
# predict_intent: Valor_13
# score: 0.87
# right_intent: Valor_13
# is it right?: yes
# quantity of right answers: 531
#
#
# -------------------------------------------
# sentence: qual o valor do adiantamento do salário
#
#
# Omni NLP API
#
# predict_intent: Valor_13
# score: 0.49
# right_intent: Valor_13
# is it right?: yes
# quantity of right answers: 537
#
#
# Watson Assistent
#
# predict_intent: Valor_13
# score: 0.78
# right_intent: Valor_13
# is it right?: yes
# quantity of right answers: 532
#
#
# -------------------------------------------
# sentence: quanto ir receber de décimo terceirar salário
#
#
# Omni NLP API
#
# predict_intent: Valor_13
# score: 0.57
# right_intent: Valor_13
# is it right?: yes
# quantity of right answers: 538
#
#
# Watson Assistent
#
# predict_intent: Valor_13
# score: 0.85
# right_intent: Valor_13
# is it right?: yes
# quantity of right answers: 533
#
#
# -------------------------------------------
# sentence: quais ser o nosso valorar
#
#
# Omni NLP API
#
# predict_intent: Valores_Geral
# score: 0.50
# right_intent: Valores_Geral
# is it right?: yes
# quantity of right answers: 539
#
#
# Watson Assistent
#
# predict_intent: Valores_Geral
# score: 0.38
# right_intent: Valores_Geral
# is it right?: yes
# quantity of right answers: 534
#
#
# -------------------------------------------
# sentence: quais ser o novo valorar
#
#
# Omni NLP API
#
# predict_intent: Valores_Geral
# score: 0.50
# right_intent: Valores_Geral
# is it right?: yes
# quantity of right answers: 540
#
#
# Watson Assistent
#
# predict_intent: Valores_Geral
# score: 0.35
# right_intent: Valores_Geral
# is it right?: yes
# quantity of right answers: 535
#
#
# -------------------------------------------
# sentence: valores que o ter
#
#
# Omni NLP API
#
# predict_intent: Valores_Geral
# score: 0.52
# right_intent: Valores_Geral
# is it right?: yes
# quantity of right answers: 541
#
#
# Watson Assistent
#
# predict_intent: Valores_Geral
# score: 0.56
# right_intent: Valores_Geral
# is it right?: yes
# quantity of right answers: 536
#
#
# -------------------------------------------
# sentence: valores gerais
#
#
# Omni NLP API
#
# predict_intent: Valores_Geral
# score: 0.54
# right_intent: Valores_Geral
# is it right?: yes
# quantity of right answers: 542
#
#
# Watson Assistent
#
# predict_intent: Valores_Geral
# score: 1.00
# right_intent: Valores_Geral
# is it right?: yes
# quantity of right answers: 537
#
#
# -------------------------------------------
# sentence: qual o valor que eu poder usar quando ir comer algo durante umar viagem
#
#
# Omni NLP API
#
# predict_intent: Valores_Política
# score: 0.56
# right_intent: Valores_Política
# is it right?: yes
# quantity of right answers: 543
#
#
# Watson Assistent
#
# predict_intent: Valores_Política
# score: 0.93
# right_intent: Valores_Política
# is it right?: yes
# quantity of right answers: 538
#
#
# -------------------------------------------
# sentence: o quantum eu poder gastar o meu jantar durante umar viagem
#
#
# Omni NLP API
#
# predict_intent: Valores_Política
# score: 0.53
# right_intent: Valores_Política
# is it right?: yes
# quantity of right answers: 544
#
#
# Watson Assistent
#
# predict_intent: Valores_Política
# score: 0.93
# right_intent: Valores_Política
# is it right?: yes
# quantity of right answers: 539
#
#
# -------------------------------------------
# sentence: qual o valor limitar de umar jantar conformar o política da yara parir reembolsar
#
#
# Omni NLP API
#
# predict_intent: Valores_Política
# score: 0.55
# right_intent: Valores_Política
# is it right?: yes
# quantity of right answers: 545
#
#
# Watson Assistent
#
# predict_intent: Valores_Política
# score: 0.86
# right_intent: Valores_Política
# is it right?: yes
# quantity of right answers: 540
#
#
# -------------------------------------------
# sentence: ganhei umar jantar ser sobrar umar reunião dos valorar yara ministrar pelar nosso coordenador e o colega daniela prestes comer ser indicar por algum colega acabar ganhar umar jantar o qual eu poder pedir reembolsar posterior logo gostar de saber qual o valor que eu poder gastar grata
#
#
# Omni NLP API
#
# predict_intent: Valores_Política
# score: 0.56
# right_intent: Valores_Política
# is it right?: yes
# quantity of right answers: 546
#
#
# Watson Assistent
#
# predict_intent: Valores_Política
# score: 0.90
# right_intent: Valores_Política
# is it right?: yes
# quantity of right answers: 541
#
#
# -------------------------------------------
# sentence: o que ser viver o valorar da yara
#
#
# Omni NLP API
#
# predict_intent: Valores_Yara
# score: 0.53
# right_intent: Valores_Yara
# is it right?: yes
# quantity of right answers: 547
#
#
# Watson Assistent
#
# predict_intent: Valores_Yara
# score: 0.82
# right_intent: Valores_Yara
# is it right?: yes
# quantity of right answers: 542
#
#
# -------------------------------------------
# sentence: valores yara
#
#
# Omni NLP API
#
# predict_intent: Valores_Yara
# score: 0.55
# right_intent: Valores_Yara
# is it right?: yes
# quantity of right answers: 548
#
#
# Watson Assistent
#
# predict_intent: Valores_Yara
# score: 1.00
# right_intent: Valores_Yara
# is it right?: yes
# quantity of right answers: 543
#
#
# -------------------------------------------
# sentence: quais ser o valorar da yara
#
#
# Omni NLP API
#
# predict_intent: Valores_Yara
# score: 0.53
# right_intent: Valores_Yara
# is it right?: yes
# quantity of right answers: 549
#
#
# Watson Assistent
#
# predict_intent: Valores_Yara
# score: 0.64
# right_intent: Valores_Yara
# is it right?: yes
# quantity of right answers: 544
#
#
# -------------------------------------------
# sentence: Após a Admissão, eu solicito o carro definitivo?
#
#
# Omni NLP API
#
# predict_intent: Data_Entrega_Veiculo_Definitivo
# score: 0.45
# right_intent: Veiculo_Definitivo
# is it right?: no
# quantity of right answers: 549
#
#
# Watson Assistent
#
# predict_intent: Veiculo_Definitivo
# score: 0.66
# right_intent: Veiculo_Definitivo
# is it right?: yes
# quantity of right answers: 545
#
#
# -------------------------------------------
# sentence: Quem pode solicitar carro definitivo?
#
#
# Omni NLP API
#
# predict_intent: Veiculo_Definitivo
# score: 0.47
# right_intent: Veiculo_Definitivo
# is it right?: yes
# quantity of right answers: 550
#
#
# Watson Assistent
#
# predict_intent: Veiculo_Definitivo
# score: 0.66
# right_intent: Veiculo_Definitivo
# is it right?: yes
# quantity of right answers: 546
#
#
# -------------------------------------------
# sentence: quantos dia eu poder ficar com o veículo definitivo
#
#
# Omni NLP API
#
# predict_intent: Veiculo_Definitivo
# score: 0.55
# right_intent: Veiculo_Definitivo
# is it right?: yes
# quantity of right answers: 551
#
#
# Watson Assistent
#
# predict_intent: Veiculo_Definitivo
# score: 0.92
# right_intent: Veiculo_Definitivo
# is it right?: yes
# quantity of right answers: 547
# -------------------------------------------
# sentence: Quantos horas foram para meu banco de horas este mês?
#
#
# Omni NLP API
#
# predict_intent: Verificar_Banco_Horas
# score: 0.58
# right_intent: Verificar_Banco_Horas
# is it right?: yes
# quantity of right answers: 552
#
#
# Watson Assistent
#
# predict_intent: Verificar_Banco_Horas
# score: 0.93
# right_intent: Verificar_Banco_Horas
# is it right?: yes
# quantity of right answers: 548
#
#
# -------------------------------------------
# sentence: onde acesso o detalhe do meu banco de horar
#
#
# Omni NLP API
#
# predict_intent: Verificar_Banco_Horas
# score: 0.57
# right_intent: Verificar_Banco_Horas
# is it right?: yes
# quantity of right answers: 553
#
#
# Watson Assistent
#
# predict_intent: Verificar_Banco_Horas
# score: 0.87
# right_intent: Verificar_Banco_Horas
# is it right?: yes
# quantity of right answers: 549
#
#
# -------------------------------------------
# sentence: quantos horar ser parir meu banco de horar este mês
#
#
# Omni NLP API
#
# predict_intent: Verificar_Banco_Horas
# score: 0.57
# right_intent: Verificar_Banco_Horas
# is it right?: yes
# quantity of right answers: 554
#
#
# Watson Assistent
#
# predict_intent: Verificar_Banco_Horas
# score: 0.79
# right_intent: Verificar_Banco_Horas
# is it right?: yes
# quantity of right answers: 550
#
#
# -------------------------------------------
# sentence: Por gentileza consultar numeração do cartão ativo
#
#
# Omni NLP API
#
# predict_intent: Verificar_Numero_Vale_RefeicaoAlimentacao
# score: 0.54
# right_intent: Verificar_Numero_Vale_RefeicaoAlimentacao
# is it right?: yes
# quantity of right answers: 555
#
#
# Watson Assistent
#
# predict_intent: Verificar_Numero_Vale_RefeicaoAlimentacao
# score: 0.89
# right_intent: Verificar_Numero_Vale_RefeicaoAlimentacao
# is it right?: yes
# quantity of right answers: 551
#
#
# -------------------------------------------
# sentence: através do app aplicativo conseguir visualizar o numerar do cartão mesmo não ter receber o mesmo
#
#
# Omni NLP API
#
# predict_intent: Verificar_Numero_Vale_RefeicaoAlimentacao
# score: 0.57
# right_intent: Verificar_Numero_Vale_RefeicaoAlimentacao
# is it right?: yes
# quantity of right answers: 556
#
#
# Watson Assistent
#
# predict_intent: Verificar_Numero_Vale_RefeicaoAlimentacao
# score: 0.85
# right_intent: Verificar_Numero_Vale_RefeicaoAlimentacao
# is it right?: yes
# quantity of right answers: 552
#
#
# -------------------------------------------
# sentence: como consultar o numeração do va e vr
#
#
# Omni NLP API
#
# predict_intent: Verificar_Numero_Vale_RefeicaoAlimentacao
# score: 0.56
# right_intent: Verificar_Numero_Vale_RefeicaoAlimentacao
# is it right?: yes
# quantity of right answers: 557
#
#
# Watson Assistent
#
# predict_intent: Verificar_Numero_Vale_RefeicaoAlimentacao
# score: 0.96
# right_intent: Verificar_Numero_Vale_RefeicaoAlimentacao
# is it right?: yes
# quantity of right answers: 553
#
#
# -------------------------------------------
# sentence: necessito saber qual o período de féria que ter programar e o prazo máximo que ter parir desfrutar
#
#
# Omni NLP API
#
# predict_intent: Verificar_Status_Ferias
# score: 0.53
# right_intent: Verificar_Status_Ferias
# is it right?: yes
# quantity of right answers: 558
#
#
# Watson Assistent
#
# predict_intent: Verificar_Status_Ferias
# score: 0.56
# right_intent: Verificar_Status_Ferias
# is it right?: yes
# quantity of right answers: 554
#
#
# -------------------------------------------
# sentence: onde ver meu programação de féria
#
#
# Omni NLP API
#
# predict_intent: Status_Ferias_e_Programacao_Sem_Confirmação
# score: 0.39
# right_intent: Verificar_Status_Ferias
# is it right?: no
# quantity of right answers: 558
#
#
# Watson Assistent
#
# predict_intent: Status_Ferias_e_Programacao_Sem_Confirmação
# score: 0.59
# right_intent: Verificar_Status_Ferias
# is it right?: no
# quantity of right answers: 554
#
#
# -------------------------------------------
# sentence: gostaria de confirmar se o gestor lançar meu féria
#
#
# Omni NLP API
#
# predict_intent: Status_Ferias_e_Programacao_Sem_Confirmação
# score: 0.41
# right_intent: Verificar_Status_Ferias
# is it right?: no
# quantity of right answers: 558
#
#
# Watson Assistent
#
# predict_intent: Status_Ferias_e_Programacao_Sem_Confirmação
# score: 0.88
# right_intent: Verificar_Status_Ferias
# is it right?: no
# quantity of right answers: 554
#
#
# -------------------------------------------
# sentence: Quero a visão geral da previdencia privada
#
#
# Omni NLP API
#
# predict_intent: Visao_Geral_Previdencia_Privada
# score: 0.47
# right_intent: Visao_Geral_Previdencia_Privada
# is it right?: yes
# quantity of right answers: 559
#
#
# Watson Assistent
#
# predict_intent: Nossa_Visao
# score: 0.52
# right_intent: Visao_Geral_Previdencia_Privada
# is it right?: no
# quantity of right answers: 554
#
#
# -------------------------------------------
# sentence: comer funcionar o planar de previdência privar
#
#
# Omni NLP API
#
# predict_intent: Visao_Geral_Previdencia_Privada
# score: 0.54
# right_intent: Visao_Geral_Previdencia_Privada
# is it right?: yes
# quantity of right answers: 560
#
#
# Watson Assistent
#
# predict_intent: Visao_Geral_Previdencia_Privada
# score: 0.35
# right_intent: Visao_Geral_Previdencia_Privada
# is it right?: yes
# quantity of right answers: 555
#
#
# -------------------------------------------
# sentence: quero o visão geral da previdencia privar
#
#
# Omni NLP API
#
# predict_intent: Visao_Geral_Previdencia_Privada
# score: 0.46
# right_intent: Visao_Geral_Previdencia_Privada
# is it right?: yes
# quantity of right answers: 561
#
#
# Watson Assistent
#
# predict_intent: failed to identify
# score: -1.00
# right_intent: Visao_Geral_Previdencia_Privada
# is it right?: no
# quantity of right answers: 555
#
#
# -------------------------------------------
# sentence: nosso terreno estar ser invadir pelar vizinhar da unidade o que fazer
#
#
# Omni NLP API
#
# predict_intent: Vizinho_Invadindo_Terreno
# score: 0.55
# right_intent: Vizinho_Invadindo_Terreno
# is it right?: yes
# quantity of right answers: 562
#
#
# Watson Assistent
#
# predict_intent: Vizinho_Invadindo_Terreno
# score: 0.80
# right_intent: Vizinho_Invadindo_Terreno
# is it right?: yes
# quantity of right answers: 556
#
#
# -------------------------------------------
# sentence: a unidade estar ser invadir quem poder ajudar
#
#
# Omni NLP API
#
# predict_intent: Vizinho_Invadindo_Terreno
# score: 0.55
# right_intent: Vizinho_Invadindo_Terreno
# is it right?: yes
# quantity of right answers: 563
#
#
# Watson Assistent
#
# predict_intent: Vizinho_Invadindo_Terreno
# score: 0.76
# right_intent: Vizinho_Invadindo_Terreno
# is it right?: yes
# quantity of right answers: 557
#
#
# -------------------------------------------
# sentence: estamos com problema com vizinho da unidade com quem poder falar
#
#
# Omni NLP API
#
# predict_intent: Vizinho_Invadindo_Terreno
# score: 0.57
# right_intent: Vizinho_Invadindo_Terreno
# is it right?: yes
# quantity of right answers: 564
#
#
# Watson Assistent
#
# predict_intent: Vizinho_Invadindo_Terreno
# score: 0.94
# right_intent: Vizinho_Invadindo_Terreno
# is it right?: yes
# quantity of right answers: 558
#
#
# -------------------------------------------
# sentence: o vizinhar da unidade estar invadir umar partir do imóvel da yara o que fazer
#
#
# Omni NLP API
#
# predict_intent: Vizinho_Invadindo_Terreno
# score: 0.56
# right_intent: Vizinho_Invadindo_Terreno
# is it right?: yes
# quantity of right answers: 565
#
#
# Watson Assistent
#
# predict_intent: Vizinho_Invadindo_Terreno
# score: 0.85
# right_intent: Vizinho_Invadindo_Terreno
# is it right?: yes
# quantity of right answers: 559
#
#
# -------------------------------------------
#
# Total of questions: 692
#
# Omni NLP API
#
# Total of right answers: 565
# Accuracy: 82.0
#
# Watson Assistent
#
# Total of right answers: 559
# Accuracy: 81.0
